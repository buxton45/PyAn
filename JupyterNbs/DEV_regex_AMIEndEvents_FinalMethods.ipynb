# %%
from importlib import reload
#reload(Utilities)
# NOTE: To reload a class imported as, e.g., 
# from module import class
# One must call:
#   1. import module
#   2. reload module
#   3. from module import class

import sys, os
import re
from pathlib import Path
import json
import pickle

import pandas as pd
import numpy as np
from pandas.api.types import is_numeric_dtype, is_datetime64_dtype, is_timedelta64_dtype
from scipy import stats
import datetime
import time
from natsort import natsorted, ns, natsort_keygen
from packaging import version
import copy

import itertools

import pyodbc
#---------------------------------------------------------------------
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
import matplotlib.ticker as ticker
from matplotlib import dates
import matplotlib.colors as mcolors
import matplotlib.cm as cm #e.g. for cmap=cm.jet
#---------------------------------------------------------------------
sys.path.insert(0, os.path.realpath('..'))
import Utilities_config
#-----
from MeterPremise import MeterPremise
#-----
from AMI_SQL import AMI_SQL
from AMINonVee_SQL import AMINonVee_SQL
from AMIEndEvents_SQL import AMIEndEvents_SQL
from AMIUsgInst_SQL import AMIUsgInst_SQL
from DOVSOutages_SQL import DOVSOutages_SQL
#-----
from GenAn import GenAn
from AMINonVee import AMINonVee
from AMIEndEvents import AMIEndEvents
from MECPODf import MECPODf
from MECPOAn import MECPOAn
from AMIUsgInst import AMIUsgInst
from DOVSOutages import DOVSOutages
#---------------------------------------------------------------------
sys.path.insert(0, Utilities_config.get_sql_aids_dir())
import Utilities_sql
import TableInfos
from TableInfos import TableInfo
from SQLElement import SQLElement
from SQLElementsCollection import SQLElementsCollection
from SQLSelect import SQLSelectElement, SQLSelect
from SQLFrom import SQLFrom
from SQLWhere import SQLWhereElement, SQLWhere
from SQLJoin import SQLJoin, SQLJoinCollection
from SQLGroupBy import SQLGroupByElement, SQLGroupBy
from SQLHaving import SQLHaving
from SQLOrderBy import SQLOrderByElement, SQLOrderBy
from SQLQuery import SQLQuery
from SQLQueryGeneric import SQLQueryGeneric
#---------------------------------------------------------------------
#sys.path.insert(0, os.path.join(os.path.realpath('..'), 'Utilities'))
sys.path.insert(0, Utilities_config.get_utilities_dir())
import Utilities
import Utilities_df
from Utilities_df import DFConstructType
import Utilities_dt
import Plot_General
import Plot_Box_sns
import Plot_Hist
import Plot_Bar
import GrubbsTest
import DataFrameSubsetSlicer
from DataFrameSubsetSlicer import DataFrameSubsetSlicer as DFSlicer

# %%
def build_sample_dfs(
    distinct_ids,
    save_dir, 
    years = [2020, 2021, 2022, 2023], 
    limit_per_month=10000, 
    conn_db=Utilities.get_athena_prod_aws_connection()
):
    r"""
    """
    #-------------------------
    general_sql = r"""
    SELECT
        EDE.issuertracking_id,
        EDE.serialnumber,
        EDE.enddeviceeventtypeid,
        EDE.valuesinterval,
        EDE.aep_premise_nb,
        EDE.reason,
        EDE.event_type,
        EDE.aep_opco,
        EDE.aep_event_dt
    FROM meter_events.end_device_event EDE
    WHERE EDE.aep_event_dt BETWEEN '{dt_0}' AND '{dt_1}'
    AND   EDE.enddeviceeventtypeid = '{ede_typeid}'
    LIMIT {limit}
    """
    #-------------------------
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    #-------------------------
    for i,distinct_id in enumerate(distinct_ids):
        print(f"distinct_id = {distinct_id} ({i+1}/{len(distinct_ids)})")
        dfs_for_id = []
        save_name_for_id = 'df_'+distinct_id.replace('.', '_')+'.pkl'
        #-----
        for year in years:
            # No harm in assuming all months have 31 days
            for month in range(1,13):
                dt_0 = "{year}-{month:02d}-01".format(year=year, month=month)
                dt_1 = "{year}-{month:02d}-31".format(year=year, month=month)
                sql_i = general_sql.format(
                    dt_0=dt_0, 
                    dt_1=dt_1, 
                    ede_typeid=distinct_id, 
                    limit=limit_per_month
                )
                df_i = pd.read_sql_query(sql_i, conn_db)
                dfs_for_id.append(df_i)
        assert(len(dfs_for_id) == 12*len(years))
        df_for_id = pd.concat(dfs_for_id)
        df_for_id.to_pickle((os.path.join(save_dir, save_name_for_id)))

# %%
def get_std_patterns_to_replace_by_typeid_EXPLICIT_V0():
    r"""
    Returns the standard patterns_to_replace_by_typeid.
    Function exists essentially to keep reduce_end_event_reasons_in_df from being too cluttered
    
    NOTE: Multi-line strings have more parentheses than absolutely necessary for clarity.
    NOTE: In (r'\s{2,}', ' '), the second element ' ' has a space between the quotes! So, multiple white-space characters
            are to be replaced with a single-space.
          This is different from many other cases, where ther is no space between the quotes, and in which case the match
            is to be removed (by replacing it with an empty character, e.g., (r'\s+([0-9a-zA-Z]+)(\:[0-9a-zA-Z]+)+', ''))  
    """
    #-------------------------
    patterns_to_replace_by_typeid = {
        #-------------------------
        # Examples
        # 'Power Loss cleared for meter 00:13:50:05:ff:0d:dd:17'
        '3.2.0.28':    [
            #-----
            (r'(Power Loss cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1')
#             #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],  
        
        #-------------------------
        # Examples
        # 'Power loss detected on meter 00:13:50:05:ff:0d:dd:17'
        '3.2.0.85':    [
            #-----
            (r'(Power loss detected)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1')
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Low Battery cleared for meter 00:13:50:02:00:0a:9e:1e.'
        '3.2.22.28':    [
            #-----
            (r'(Low Battery cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1')
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Low Battery (C1219 Table 3) occurred for meter 00:13:50:02:00:0a:9e:1e.'
        '3.2.22.150':    [
            #-----
            (r'(Low Battery\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Test Mode Started occurred for meter 00:13:50:05:ff:1d:2d:4a.'
        # 'Meter event Test Mode Started  Time event occurred on meter = 01/20/2020 12:56:50  Sequence number = 56  User id = 1  Event argument = 00-00'
        # SEEMS RARE, BUT HAVE SEEN:
        # 'Meter is currently in test mode.'
        '3.7.19.242':    [
            #-----
            (r'(Test Mode Started)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'(Meter event Test Mode Started)\s*Time event occurred on meter = .* Sequence number = .* User id = .*  Event argument = .*', r'\1'), 
            #-----
            (r'(Meter event Test Mode Started).*', 'Test Mode Started'), 
            #-----
            (r'(Meter is currently in test mode)[\s\.]*', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Test Mode Stopped occurred for meter 00:13:50:03:ff:06:20:96.'
        # 'Meter event Test Mode Stopped  Time event occurred on meter = 01/02/2020 08:25:04  Sequence number = 573  User id = 1  Event argument = 00-00'
        '3.7.19.243':    [
            #-----
            (r'(Test Mode Stopped)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'(Meter event Test Mode Stopped)\s*Time event occurred on meter = .* Sequence number = .* User id = .*  Event argument = .*', r'\1'), 
            #-----
            (r'(Meter event Test Mode Stopped).*', 'Test Mode Stopped')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'NIC operating on backup battery: 00:13:50:ff:fe:70:96:ac, Reboot Count: 6, NIC timestamp: 2021-01-14T10:17:54.000-05:00, Received timestamp: 2021-01-14T10:17:55.728-05:00'
        '3.7.22.4':    [
            #-----
            (r'(NIC operating on backup battery)\:(\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?), Reboot Count: .*, NIC timestamp: .*, Received timestamp: .*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # All seem to be: 'NIC backup battery inactive'
        # So, don't need to run any regex, but should still so no flags raised
        '3.7.22.19':    [
            #-----
            (r'(NIC backup battery inactive).*', r'\1')
            #-----
        ],      
        
        #-------------------------
        # Examples
        # 'Demand Reset occurred for meter 00:13:50:05:ff:18:b3:c1.'
        '3.8.0.215':    [
            #-----
            (r'(Demand Reset)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1') 
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter Program Seal mismatch for Device [Device ID, MAC Id] = [1ND785727916NMD06, 00:13:50:05:ff:1d:16:96] - program seal = 0bda0569c8e6ad375375eaa177034d3f61a80478 vs. UIQ program seal = e2dbe1ccbeef1f2df38adffeeafdb86fbd8fb006 at 2021-01-08T06:16:49.116-05:00.'
        '3.9.83.159':    [
            #-----
            (r'(Meter Program Seal mismatch for Device)\s*\[Device ID, MAC Id\]\s*=\s*.*', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Requested operation JOB_OP_TYPE_ARB_METER_COMMAND could not be applied to the given device type and firmware version. Device: 00:13:50:05:ff:2d:ff:34, DeviceType: DID_SUBTYPE_I210CRD_HAN, Firmware Version: 3.12.5c'
        '3.11.63.161':  [
            #-----
            # Below, Device sometimes blank, sometime MAC-esque
            (r'(Requested operation)\s*(.*?)\s*(could not be applied) to the given device type and firmware version.\s*Device\:?(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)?,\s*DeviceType\:?.*,\s*Firmware Version\:?.*', r'\1 \3: \2')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Tamper Attempt Suspected  Time event occurred on meter = 01/10/2020 10:03:37  Sequence number = 1189  User id = 0  Event argument = 00-00'
        # 'Meter detected a Tamper Attempt.'
        # 'Tamper attempt detected.'
        '3.12.0.257':   [
            #-----
            (r'(Meter event Tamper Attempt Suspected)\s*Time event occurred on meter = .* Sequence number = .* User id = .*  Event argument = .*', r'\1'), 
            #-----
            (r'(Meter event Tamper Attempt Suspected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a Tamper Attempt|Tamper attempt detected).*', 'Meter detected a Tamper Attempt'), 
            #-----
        ],    
        
        #-------------------------
        # Examples:
        # 'Tamper (Meter Inversion) detected on meter 00:13:50:05:ff:27:3f:a0.'
        '3.12.17.257':  [
            #-----
            (r'(Tamper\s*(?:\(.*\))?\s*detected)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\.?', '') 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Diag1 Condition cleared for meter 00:13:50:05:ff:04:55:a1.'
        # SEEMS RARE, BUT HAVE SEEN:
        # Reverse energy cleared for meter 00:13:50:05:ff:0d:dd:17.
        '3.12.48.28':    [
            #-----
            (r'((?:Diag1 Condition|Reverse energy) cleared)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Diag1: Polarity, Cross Phase, Reverse Energy Flow occurred for meter 00:13:50:03:00:34:b7:e9. Angle out of tolerance [Voltage - Phase  B].'
        # 'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase A Current'
        # 'Service disconnect operation occurred with status: Close operation started'
        # 'Reverse energy (C1219 Table 3) occurred for meter 00:13:50:05:ff:0d:dd:17.'
        '3.12.48.219':  [
            #-----
            (r'(Diag1: Polarity, Cross Phase, Reverse Energy Flow)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)\s*(Angle out of tolerance) \[.*\]', r'\1: \2'), 
            #-----
            (r'(KV2c meter event Polarity, Cross Phase, Reverse Energy Flow) Diagnostic flags:.*', r'\1'), 
            #-----
            (r'(Service disconnect operation occurred with status:) (Open|Close) operation (started|succeeded)\s*', r'\1 \2 \3'), 
            #-----
            (r'((?:Diag1 Condition|Reverse energy)\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
        ],
        
        #-------------------------
        # Examples
        # 'Cleared: Meter00:13:50:05:ff:07:88:4b, cleared tamper detection (C1219 Table 3)'
        '3.12.93.28': [
            #-----
            (r'(Cleared: Meter)(?:\s*(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?), (cleared tamper detection.*)', r'\1 \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Meter event Reverse Rotation Detected  Time event occurred on meter = 01/28/2020 15:31:34  Sequence number = 854  User id = 0  Event argument = 00-00'
        # 'Meter detected a Reverse Rotation.'
        # 'Meter 00:13:50:05:ff:0b:ae:84, detected tampering (C1219 Table 3)'
        # SEEMS RARE, BUT HAVE SEEN:
        # Meter event Demand Reset Occurred  Time event occurred on meter = 10/25/2020 10:07:33  Sequence number = 1256  User id = 1  Event argument = 00-00
        '3.12.93.219':    [
            #-----
            (r'(Meter)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\.,]?)\s*(detected tampering\s*(?:\(.*\))?)\s*', r'\1 \2'), 
            #-----
            (r'(Meter event (?:Reverse Rotation Detected|Demand Reset Occurred))\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'),
            #-----
            (r'(Meter event Reverse Rotation Detected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a Reverse Rotation).*', 'Meter event Reverse Rotation Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbc0:250:56ff:feb5:91c7 with a key that has insufficient privileges to execute it. ID: 53 READ SUBID: 65535 ASSOC_ID: 8448'
        # 'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbc0:a6ba:99ff:fe12:1b0e with a key that has insufficient privileges to execute it. ID: 207 WRITE SUBID: 65535 ASSOC_ID: 768'
        '3.12.136.38':  [
            #-----
            # BELOW, ID seemed meter-specific (or, at least, not general), as READ/WRITE SUBID and ASSOC_ID seem to only take on a few different values
            # Therefore, group 3, for ID, is not included in output
            (r'A?\s+?(.*command was sent) from(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(with a key that has insufficient privileges) to execute it.*(ID:\s*[0-9]+)\s*((?:READ|WRITE)\s*SUBID:\s*[0-9]+)\s*(ASSOC_ID:\s*[0-9]+).*', r'\1 \2: \4 \5'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'NET_MGMT command failed consecutively for 1 times for fd37:ec90:20c2:5c58:250:56ff:feb5:1010. WRITE'
        # 'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 16270'
        # 'failed consecutively for 1 times for 0:0:0:0:0:0:0:0.'
        # 'N/A failed consecutively for 1 times for 0:0:0:0:0:0:0:0. N/A'
        '3.12.136.85':  [
            #-----
            (r'(.*) failed consecutively for [0-9]+ times?(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1 failed consecutively for 1 or more times'), 
            #-----
            (r'^failed consecutively for [0-9]+ times? for 0:0:0:0:0:0:0:0.$', 'N/A failed consecutively for 1 or more times'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Meter detected a RAM failure.'
        # So, don't need to run any regex, but should still so no flags raised
        '3.18.1.199':    [
            #-----
            (r'(Meter detected a RAM failure).*', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # All seem to be: 'Meter detected a ROM failure.'
        # So, don't need to run any regex, but should still so no flags raised
        '3.18.1.220':    [
            #-----
            (r'(Meter detected a ROM failure).*', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'NVRAM Error cleared for meter 00:13:50:05:ff:0d:7e:64.'
        '3.18.72.28':   [
            #-----
            (r'(NVRAM Error )(cleared?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'NVRAM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:20:91:6c.'
        '3.18.72.79':   [
            #-----
            (r'(NVRAM Error\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 01/21/2020 09:45:01  Sequence number = 3335  User id = 0  Event argument = 00-00'
        # 'null'????????????
        # SEEMS RARE, BUT HAVE SEEN:
        # 'Meter event Demand Reset Occurred  Time event occurred on meter = 01/29/2023  Sequence number = 711  User id = 1  Event argument = 00-00 '
        # 'Meter event Reset List Pointers  Time event occurred on meter = 09/07/2021  Sequence number = 227  User id = 0  Event argument = 03-00'
        # 'KV2c meter event Received kWh Caution Diagnostic flags:Phase A Voltage'
        # 'Universal event Unsupported Event(41) with priority Alarm. '
        '3.18.72.85':   [
            #-----
#             (r'(Meter event (?:Nonvolatile Memory Failure Detected|Demand Reset Occurred|Reset List Pointers))\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'),
            (r'(Meter event.*?)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            # FAILSAFE in case Sequence number etc. not found above
            # NOTE: Cannot do (Meter event.*).*, as that will reduce everything altered above donw to simply 'Meter event'
            #       Also, if any additional info (e.g, Sequence number) is to be extracted using above, this must be removed
            (r'(Meter event (?:Nonvolatile Memory Failure Detected|Demand Reset Occurred|Reset List Pointers)).*', r'\1'),
            #-----
            (r'(Meter detected a nonvolatile memory failure).*', 'Meter event Nonvolatile Memory Failure Detected'), 
            #-----
            (r'(KV2c meter event .*?)\s*(Diagnostic flags)\s*\:\s*(.*?)\s*$', r'\1 (\2 = \3)'),
            #-----
            (r'(Universal event Unsupported Event\s*(?:\(.*\))?\s*with priority Alarm)[\s*\.]*', r'\1'), 
            #-----
            ('null', 'Reason is null, ID=3.18.72.85')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'RAM Error cleared for meter 00:13:50:05:ff:0d:dd:17.'
        '3.18.85.28':    [
            #-----
            (r'(RAM Error cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'RAM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:0d:dd:17.'
        '3.18.85.79':   [
            #-----
            (r'(RAM Error\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a RAM failure.'
        # 'Meter event Ram Failure Detected  Time event occurred on meter = 7/27/2021 12:45:53 PM  Sequence number = 89  User id = 34891  Event argument = 7D-75'
        '3.18.85.85':   [
            #-----
            (r'(Meter event Ram Failure Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Ram Failure Detected).*', r'\1'),
            #-----
            (r'(Meter detected a RAM failure).*', 'Meter event Ram Failure Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1f:ba:d0.'
        '3.18.92.28':   [
            #-----
            (r'(ROM Error cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1f:ba:d0.'
        '3.18.92.79':   [
            #-----
            (r'(ROM Error\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Rom Failure Detected  Time event occurred on meter = 03/16/2020 07:00:51  Sequence number = 1983  User id = 1024  Event argument = 00-00'
        # 'Meter detected a ROM failure.'
        # 'ROM failure detected.'
        '3.18.92.85':    [
            #-----
            (r'(Meter event Rom Failure Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Rom Failure Detected).*', r'\1'),
            #-----
            (r'^(?:Meter detected a ROM failure|ROM failure detected).*$', 'Meter event Rom Failure Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Measurement Error Detected  Time event occurred on meter = 08/26/2021 08:27:25  Sequence number = 307  User id = 0  Event argument = 00-00 '
        '3.21.1.79':    [
            #-----
            (r'(Meter event Measurement Error Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Measurement Error Detected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a measurement error).*', 'Meter event Measurement Error Detected')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 08/30/2021 04:00:11  Sequence number = 3256  User id = 0  Event argument = 00-00 '
        '3.21.1.173':    [
            #-----
            (r'(Meter event Nonvolatile Memory Failure Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Nonvolatile Memory Failure Detected).*', r'\1'),
            #-----
            (r'(Meter detected a nonvolatile memory failure).*', 'Meter event Nonvolatile Memory Failure Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'System Error cleared for meter 00:13:50:05:ff:11:2d:23.'
        '3.21.3.28':    [
            #-----
            (r'(System Error cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0f:17:ba.'
        '3.21.3.79':    [
            #-----
            (r'(System Error\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a self check error.'
        '3.21.17.28':    [
            #-----
            (r'(Meter detected a self check error).', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a self check error.'
        '3.21.18.79':    [
            #-----
            (r'(Meter detected a self check error).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Detected end of voltage sag on meter 00:13:50:05:ff:32:66:22 on one or several phases. Duration: 21 cycles (less than a second), Min RMS Voltage: Phase A 118.1 V, Phase B 95.4 V, Phase C 120.3 V, RMS Current (at min voltage): Phase A 1.0 A, Phase B 0.2 A, Phase C 1.2 A'
        '3.21.38.223':  [
            #-----
            (r'(Detected end of voltage sag)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*Duration:.*, Min RMS Voltage: Phase A .*, Phase B .*, Phase C .*, RMS Current \(at min voltage\): Phase A .*, Phase B .*, Phase C .*', r'\1'), 
            #-----
            # Failsafe
            (r'(Detected end of voltage sag)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Detected end of voltage swell on meter 00:13:50:05:ff:1b:49:b0 on one or several phases. Duration: 5 cycles (less than a second), Max RMS Voltage: Phase A 111.2 V, Phase B 133.2 V, Phase C 216.1 V, RMS Current (at max voltage): Phase A 2.8 A, Phase B 1.3 A, Phase C 0.8 A'
        '3.21.38.248':  [
            #-----
            (r'(Detected end of voltage swell)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*Duration: .*, Min RMS Voltage: .*, RMS Current \(at min voltage\): .*', r'\1'), 
            #-----
            # Failsafe
            (r'(Detected end of voltage swell)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1')  
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Detected end of voltage sag on meter 00:13:50:03:ff:01:a6:36. Duration: 2 seconds, Min RMS Voltage: Phase A 227.9 V, RMS Current (at min voltage): Phase A 0.0 A'
        '3.21.43.223':  [
            #-----
            (r'(Detected end of voltage sag)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*Duration: .*, Min RMS Voltage: .*, RMS Current \(at min voltage\): .*', r'\1'), 
            #-----
            (r'(Detected end of voltage sag)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1'), # failsafe  
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Detected end of voltage swell on meter 00:13:50:05:ff:2d:2c:25. Duration: 195 seconds, Max RMS Voltage: Phase A 265.7 V, RMS Current (at max voltage): Phase A 0.0 A'
        '3.21.43.248':  [
            #-----
            (r'(Detected end of voltage swell)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*Duration: .*, Min RMS Voltage: .*, RMS Current \(at min voltage\): .*', r'\1'), 
            #-----
            (r'(Detected end of voltage swell)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1'), # failsafe  
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Measurement Error cleared for meter 00:13:50:05:ff:07:c0:55.'
        '3.21.67.28':    [
            #-----
            (r'(Measurement Error.*cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Measurement Error Detected  Time event occurred on meter = 01/26/2020 19:47:00  Sequence number = 284  User id = 0  Event argument = 00-00'
        # 'Measurement Error (C1219 Table 3) occurred for meter 00:13:50:03:ff:06:d6:d5.'
        '3.21.67.79':    [
            #-----
            (r'(Measurement Error\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'(Meter event Measurement Error Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Measurement Error Detected).*', r'\1'),
            #-----
            (r'(Meter detected a measurement error).*', 'Meter event Measurement Error Detected')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'DSP Error cleared for meter 00:13:50:05:ff:0b:87:fc.'
        '3.21.82.28':    [
            #-----
            (r'(DSP Error cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:2c:f3:e2.'
        '3.21.82.79':    [
            #-----
            (r'(DSP Error\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1') 
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Test Mode Stopped  Time event occurred on meter = 08/27/2021 10:04:04  Sequence number = 23834  User id = 1  Event argument = 00-00 '
        '3.22.12.243':   [
            #-----
            (r'(Meter event Test Mode Stopped)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Test Mode Stopped).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Test Mode Started  Time event occurred on meter = 08/27/2021 07:48:19  Sequence number = 765  User id = 1  Event argument = 00-00 '
        '3.22.19.242':   [
            #-----
            (r'(Meter event Test Mode Started)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Test Mode Started).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Device 00:13:50:05:ff:2e:17:7e has been determined to have exceeded the max allowable trap threshold, 20, within a certain time limit, 3600 seconds.'
        '3.23.17.139':   [
            #-----
            (r'(Device)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+).*(exceeded the max allowable trap threshold).*', r'\1 \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Access Point 00:13:50:08:ff:00:06:8e has lost connectivity with FHSS 900 MHz band.'
        '3.23.136.47':  [
            #-----
            (r'(Access Point)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(has lost connectivity with FHSS 900 MHz band.)', r'\1 \2') 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # Device: 00:13:50:05:ff:20:f5:ef Time: 2021-01-20T06:03:47.000-05:00 Failed Device: 00:13:50:05:ff:20:f5:ef Reason: Security public key mismatch Reboot Counter: 44 Refresh Counter: 0 Seconds since last reboot 6872803
        # 'NIC Link Layer Handshake Failed: Device: 00:13:50:05:ff:19:4e:6b, Rejected neighbor Mac ID: 00:13:50:05:ff:18:a3:52, Rejection Cause: invalid eblob signature'
        '3.23.136.85':  [
            #-----
            # Below, Device and Failed Device sometimes blank, sometime MAC-esque
            (r'Device\:?(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)? Time: .* Failed Device\:?(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)? (Reason: .*) Reboot Counter: .* Refresh Counter: .*', r'Device Failed: \1'), 
            #-----
            (r'(NIC Link Layer Handshake Failed): Device:(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+), Rejected neighbor Mac ID:(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+), (Rejection Cause: .*)', r'\1: \2')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter generated an energy polarity gyrbox call in event.'
        '3.25.17.3':   [
            #-----
            (r'(Meter generated an energy polarity gyrbox call in event).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Primary Power Down occurred for meter 00:13:50:05:ff:16:5f:61.'
        # 'Meter had a power outage. Unsafe power fail count = 32714'
        # 'Meter event Primary Power Down  Time event occurred on meter = 08/05/2021 16:59:27  Sequence number = 691  User id = 0  Event argument = 00-00'
        '3.26.0.47': [
            #-----
            (r'(Primary Power Down)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'(Meter had a power outage)\.?\s*(Unsafe power fail)\s*count\s*=\s*[0-9]+', r'\1 (\2)'), 
            #-----
            (r'^(Meter had a power outage).*$', r'\1'), #Fail proof, in case Unsafe power fail, count, etc., not found 
            #-----
            (r'(Meter event Primary Power Down)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Primary Power Down).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
        ],         
        
        #-------------------------
        # Examples
        # 'Primary Power Up occurred for meter 00:13:50:05:ff:22:2a:0c.'
        # 'Meter event Primary Power Up Time event occurred on meter = 08/14/2020 Sequence number = 343 User id = 0 Event argument = 00-00'
        '3.26.0.216':   [
            #-----
            (r'(Primary Power Up)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'Meter event (Primary Power Up)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'Meter event (Primary Power Up).*', r'\1'),  #Fail proof, in case time, sequence, etc., not found 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter had a power outage. Unsafe power fail count = 13050'
        # Meter event Primary Power Down  Time event occurred on meter = 08/31/2021 20:07:18  Sequence number = 103  User id = 0  Event argument = 00-00 
        '3.26.17.185':  [
            #-----
            (r'(Meter had a power outage).\s*(Unsafe power fail) count = [0-9]+', r'\1 (\2)'), 
            #-----
            (r'(Meter event Primary Power Down)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Primary Power Down).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Primary Power Up  Time event occurred on meter = 08/31/2021 20:07:44  Sequence number = 104  User id = 0  Event argument = 00-00 '
        '3.26.17.216':  [
            #-----
            (r'Meter event (Primary Power Up)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'Meter event (Primary Power Up).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Under Voltage cleared (CA000400) for meter 00:13:50:05:ff:0b:88:ec.'
        # 'Under Voltage (CA000400) cleared for meter 00:13:50:05:ff:15:e8:3b.'
        # 'Under Voltage (Diagnostic 6) cleared for meter 00:13:50:05:ff:3f:87:07N/A.'
        '3.26.38.37':   [
            #-----
            # NOTE: Due to annoying N/A at end of some MAC-esque IDs, I have to specify length of numerical entries
            #       as [0-9a-zA-Z]{1,2}, instead of the more general [0-9a-zA-Z]+ found elsewhere!
            (r'(Under Voltage|Low Potential|Diag6 Condition)\s*(\scleared)?\s*(\s\(.*\))?\s*(\scleared)?\s*(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]{1,2})(?:\:[0-9a-zA-Z]{1,2})+(?:N/A)?\.?)', r'\1\3\2\4')
            #-----
        ],
        
        #-------------------------
        # Examples
        # 'Low Potential (C1219 Table 3) occurred for meter 00:13:50:05:ff:1b:67:3b.'
        '3.26.38.47': [
            #-----
            (r'(Low Potential\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1') 
            #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Diag7 Condition cleared for meter 00:13:50:03:00:4d:41:fa.'
        # 'Over Voltage (Diagnostic 7) cleared for meter 00:13:50:05:ff:37:87:3dN/A.'
        '3.26.38.73':   [
            #-----
            # NOTE: Due to annoying N/A at end of some MAC-esque IDs, I have to specify length of numerical entries
            #       as [0-9a-zA-Z]{1,2}, instead of the more general [0-9a-zA-Z]+ found elsewhere!
            # NOTE: Also, the use of non-greedy (.*?) at beginning.
            #       If (.*) were used instead, results would be, e.g.
            #          'Over Voltage (Diagnostic 7) cleared for meter' instead of 'Over Voltage (Diagnostic 7) cleared'
            (r'(.*?)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]{1,2})(?:\:[0-9a-zA-Z]{1,2})+(?:N/A)?\.?)', r'\1')
            #-----
            #-----
#             # COULD ALSO DO
#             # NOTE: Due to annoying N/A at end of some MAC-esque IDs, I have to specify length of numerical entries
#             #       as [0-9a-zA-Z]{1,2}, instead of the more general [0-9a-zA-Z]+ found elsewhere!
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]{1,2})(?:\:[0-9a-zA-Z]{1,2})+(?:N/A)?\.?)', '')
        ],         
        
        #-------------------------
        # Examples
        # 'Diag7: Over Voltage, Element A occurred for meter 03.34.0.400:13:50:02:00:0a:d7:98.'
        # 'Over Voltage (Diagnostic 7) occurred for meter 00:13:50:05:ff:41:8a:8f: Phase A.'
        # SEEMS RARE, BUT HAVE SEEN:
        # 'KV2c meter event Over Voltage Diagnostic flags:Phase A Voltage'
        # 'KV2c meter event Under Voltage Caution Diagnostic flags:Phase B Voltage'
        # 'KV2c meter event Received kWh Caution Diagnostic flags:Phase A Voltage '
        # 'KV2c meter event Received kWh Caution Cleared '
        '3.26.38.93':   [
            #-----
            (r'(KV2c meter event (?:(?:Over|Under) Voltage)|(?:Voltage Out of Tolerance)|(?:(?:Received|Delivered) kWh))(?:\s*Caution)?\s*(Diagnostic flags)\s*\:\s*(.*?)\s*$', r'\1 (\2 = \3)'), 
            #-----
            (r'(KV2c meter event (?:(?:Over|Under) Voltage)|(?:Voltage Out of Tolerance)|(?:(?:Received|Delivered) kWh))(?:\s*Caution)?\s*Cleared\s*$', r'\1 Cleared'), 
            #-----
            (r'(.*Over Voltage.*?)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)(.*?)\s*$', r'\1\2') 
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Under Voltage (CA000400) for meter 00:13:50:05:ff:0b:88:ec. Phase  C Voltage out of tolerance.'
        # 'Under Voltage (CA000400) occurred for meter 00:13:50:05:ff:15:e8:3b: Phase A.'
        # 'KV2c meter event Under Voltage Diagnostic flags:Phase A Voltage'
        # 'Diag6: Under Voltage, Element A occurred for meter 00:13:50:05:ff:0b:88:ec.'
        '3.26.38.150':   [
            #-----
            # NOTE: Due to annoying N/A at end of some MAC-esque IDs, I have to specify length of numerical entries
            #       as [0-9a-zA-Z]{1,2}, instead of the more general [0-9a-zA-Z]+ found elsewhere!
            # NOTE: Also, the use of non-greedy (.*?) at beginning.
            #       If (.*) were used instead, results would be, e.g.
            #          'Diag6: Under Voltage, Element A occurred for meter'
            #       instead of 
            #          'Diag6: Under Voltage, Element A'
            (r'(Under Voltage\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\.\:]?)(\s?.*?)', r'\1\2'), 
            #-----
            (r'(Diag6.*?)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\.\:]?)(\s?.*?)', r'\1\2'), 
            #-----
            (r'(KV2c meter event .*?)\s*(Diagnostic flags)\s*\:\s*(.*?)\s*$', r'\1 (\2 = \3)')
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Last Gasp - NIC power lost for device: 00:13:50:05:ff:0b:83:e4, Reboot Count: 12264, NIC timestamp: 2020-01-19T22:21:02.000-05:00, Received timestamp: 2020-01-19T22:21:04.353-05:00, Fail Reason: [0x49] LG_ZERO_X_DETECTOR ,LG_DIRECT_NOTIFICATION'
        '3.26.136.47':  [
            #-----
            (r'(Last Gasp - NIC power lost for device):(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+).*(Fail Reason: .*)$', r'\1, \2')
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Device 00:13:50:05:ff:0b:8a:18, Last Gasp State: EL_EVENT_POWER_FAIL_DETECT_LG_DISABLED, Detector State: EL_EVENT_POWER_FAIL_DETECT_NIC_ZX_DISABLED, Reboot Count: 108'
        '3.26.136.66':  [
            #-----
            (r'Device(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+), (Last Gasp State: .*), (Detector State: .*), Reboot Count: \d*', r'\1, \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'NIC Power Restore Trap Received from device: 00:13:50:05:ff:0c:7e:93, Reboot Count: 61, NIC timestamp: 2020-01-27T09:19:56.000-05:00, Received Timestamp: 2020-01-27T09:19:57.204-05:00, Power Restoration Timestamp: 2020-01-27T09:19:42.000-05:00, State: 4,p'
        '3.26.136.216': [
            #-----
            (r'(NIC Power Restore Trap Received from device):(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter assumed to be disconnected has reported Load side voltage indicating a potential case of tamper.'
        '3.31.1.143':   [
            #-----
            (r'(Meter assumed to be disconnected has reported Load side voltage indicating a potential case of tamper).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Reverse Rotation Detected  Time event occurred on meter = 08/30/2021 04:25:38  Sequence number = 13124  User id = 0  Event argument = 00-00 '
        '3.33.1.219':   [
            #-----
            (r'(Meter event Reverse Rotation Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Reverse Rotation Detected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a Reverse Rotation).*', 'Meter event Reverse Rotation Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a Tamper Attempt.'
        # 'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 08:45:05  Sequence number = 72  User id = 0  Event argument = 00-00 '
        '3.33.1.257':   [
            #-----
            (r'(Meter event Tamper Attempt Suspected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Tamper Attempt Suspected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a Tamper Attempt).*', 'Meter event Tamper Attempt Suspected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Cleared: Meter 00:13:50:05:ff:11:69:bb detected a high temperature condition. (C1219 Table 3)'
        '3.35.0.28': [
            #-----
            (r'(Cleared: Meter)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(detected a high temperature condition)\.\s*(.*)', r'\1 \2 \3') 
            #-----
            #-----
#             # COULD ALSO DO
#             # NOTE: Here, the MAC-esque code occurs in middle of string, not the end as is common elsewhere.
#             #       This is why the pattern here excludes [\s*\.]* at the end
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', '')
        ],         
        
        #-------------------------
        # Examples
        # 'Meter 00:13:50:05:ff:11:69:bb detected a high temperature condition. (C1219 Table 3)'
        # 'Meter's temperature threshold exceeded.'
        # 'Meter event AX Temp Threshold Exceeded  Time event occurred on meter = 02/19/2021 13:33:50  Sequence number = 5115  User id = 0  Event argument = 00-00 '
        # 'Meter event S4TemperatureThreshold  Time event occurred on meter = 05/25/2023 17:12:50  Sequence number = 45  User id = 0  Event argument = 00-00-00-00-00-00 '
        '3.35.0.40': [
            #-----
            (r'(Meter)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(detected a high temperature condition)\.\s*(.*)', r'\1 \2 \3'), 
            #-----
            (r"(Meter's temperature threshold exceeded).", r'\1'), 
            #-----
            (r'(Meter event .*?)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event (?:AX Temp Threshold Exceeded|S4TemperatureThreshold)).*', r'\1'),
        ],  
        
        #-------------------------
        # Examples
        # 'Meter detected a clock error.'
        # 'Meter event Clock Error Detected  Time event occurred on meter = 04/18/2020 10:00:10  Sequence number = 332  User id = 0  Event argument = 00-00'
        '3.36.0.79': [
            #-----
            (r'(Meter event Clock Error Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Clock Error Detected).*', r'\1'),
            #-----
            (r'(Meter detected a clock error).*', 'Meter event Clock Error Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a clock error.'
        '3.36.1.29': [
            #-----
            ('(Meter detected a clock error).', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter 00:13:50:05:ff:2e:13:de, detected loss of time (C1219 Table 3)'
        '3.36.114.73':  [
            #-----
            (r'(Meter)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+),\s*(detected loss of time .*)', r'\1 \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Ignoring Interval Read data for device 00:13:50:05:ff:1e:fa:a4 as it has time in the future 2069-05-02 18:51:00.0'
        '3.36.114.159': [
            #-----
            (r'(Ignoring (?:Interval|Register) Read data for device)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(as it has time in the future).*', r'\1 \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter 00:13:50:05:ff:14:c9:61 needs explicit time sync. Drift: 14391 s, Encountered Problems:  TS_ERR_LP_BX, TS_ERR_BIG_DRIFT [0x44], Meter_Time: 06:33:41'
        '3.36.136.73':  [
            #-----
            (r'(Meter)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(needs explicit time sync.) Drift: -?\d* s, (Encountered Problems:\s*.*), Meter_Time.*', r'\1 \2 \3'), 
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Error occurred when attempting to synch meter time with NIC time for device 00:13:50:05:ff:29:e1:20'
        # So, standard beg/end patterns should suffice
        '3.36.136.79':    [
            #-----
            (r'(Error occurred when attempting to synch meter time with NIC time for device)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)', r'\1')
            #-----
#             #-----
#             # COULD ALSO DO
#             (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
        ],         
        
        #-------------------------
        # Examples
        # 'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase B Voltage '
        # 'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase B Voltage, Phase C Voltage '
        '3.38.1.139':    [
            #-----
            (r'(KV2c meter event Polarity, Cross Phase, Reverse Energy Flow) Diagnostic flags:.*', r'\1'), 
            #-----
        ]
    }
    #-------------------------
    return patterns_to_replace_by_typeid

# %%
def get_std_patterns_to_replace_by_typeid_EXPLICIT():
    r"""
    Returns the standard patterns_to_replace_by_typeid.
    Function exists essentially to keep reduce_end_event_reasons_in_df from being too cluttered 
    """
    #-------------------------
    return {
        #-------------------------
        # Examples
        # 'Power Loss cleared for meter 00:13:50:05:ff:0d:dd:17'
        '3.2.0.28':    [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],  
        
        #-------------------------
        # Examples
        # 'Power loss detected on meter 00:13:50:05:ff:0d:dd:17'
        '3.2.0.85':    [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Low Battery cleared for meter 00:13:50:02:00:0a:9e:1e.'
        '3.2.22.28':    [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Low Battery (C1219 Table 3) occurred for meter 00:13:50:02:00:0a:9e:1e.'
        '3.2.22.150':    [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Test Mode Started occurred for meter 00:13:50:05:ff:1d:2d:4a.'
        # 'Meter event Test Mode Started  Time event occurred on meter = 01/20/2020 12:56:50  Sequence number = 56  User id = 1  Event argument = 00-00'
        # SEEMS RARE, BUT HAVE SEEN:
        # 'Meter is currently in test mode.'
        '3.7.19.242':    [
            #-----
            (r'(Test Mode Started)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'(Meter event Test Mode Started)\s*Time event occurred on meter = .* Sequence number = .* User id = .*  Event argument = .*', r'\1'), 
            #-----
            (r'(Meter event Test Mode Started).*', 'Test Mode Started'), 
            #-----
            (r'(Meter is currently in test mode)[\s\.]*', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Test Mode Stopped occurred for meter 00:13:50:03:ff:06:20:96.'
        # 'Meter event Test Mode Stopped  Time event occurred on meter = 01/02/2020 08:25:04  Sequence number = 573  User id = 1  Event argument = 00-00'
        '3.7.19.243':    [
            #-----
            (r'(Test Mode Stopped)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'(Meter event Test Mode Stopped)\s*Time event occurred on meter = .* Sequence number = .* User id = .*  Event argument = .*', r'\1'), 
            #-----
            (r'(Meter event Test Mode Stopped).*', 'Test Mode Stopped')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'NIC operating on backup battery: 00:13:50:ff:fe:70:96:ac, Reboot Count: 6, NIC timestamp: 2021-01-14T10:17:54.000-05:00, Received timestamp: 2021-01-14T10:17:55.728-05:00'
        '3.7.22.4':    [
            #-----
            (r'(NIC operating on backup battery)\:(\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?), Reboot Count: .*, NIC timestamp: .*, Received timestamp: .*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # All seem to be: 'NIC backup battery inactive'
        # So, don't need to run any regex, but should still so no flags raised
        '3.7.22.19':    [
            #-----
            (r'(NIC backup battery inactive).*', r'\1')
            #-----
        ],      
        
        #-------------------------
        # Examples
        # 'Demand Reset occurred for meter 00:13:50:05:ff:18:b3:c1.'
        '3.8.0.215':    [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter Program Seal mismatch for Device [Device ID, MAC Id] = [1ND785727916NMD06, 00:13:50:05:ff:1d:16:96] - program seal = 0bda0569c8e6ad375375eaa177034d3f61a80478 vs. UIQ program seal = e2dbe1ccbeef1f2df38adffeeafdb86fbd8fb006 at 2021-01-08T06:16:49.116-05:00.'
        '3.9.83.159':    [
            #-----
            (r'(Meter Program Seal mismatch for Device)\s*\[Device ID, MAC Id\]\s*=\s*.*', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Requested operation JOB_OP_TYPE_ARB_METER_COMMAND could not be applied to the given device type and firmware version. Device: 00:13:50:05:ff:2d:ff:34, DeviceType: DID_SUBTYPE_I210CRD_HAN, Firmware Version: 3.12.5c'
        '3.11.63.161':  [
            #-----
            # Below, Device sometimes blank, sometime MAC-esque
            (r'(Requested operation)\s*(.*?)\s*(could not be applied) to the given device type and firmware version.\s*Device\:?(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)?,\s*DeviceType\:?.*,\s*Firmware Version\:?.*', r'\1 \3: \2')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Tamper Attempt Suspected  Time event occurred on meter = 01/10/2020 10:03:37  Sequence number = 1189  User id = 0  Event argument = 00-00'
        # 'Meter detected a Tamper Attempt.'
        # 'Tamper attempt detected.'
        '3.12.0.257':   [
            #-----
            (r'(Meter event Tamper Attempt Suspected)\s*Time event occurred on meter = .* Sequence number = .* User id = .*  Event argument = .*', r'\1'), 
            #-----
            (r'(Meter event Tamper Attempt Suspected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a Tamper Attempt|Tamper attempt detected).*', 'Meter detected a Tamper Attempt'), 
            #-----
        ],    
        
        #-------------------------
        # Examples:
        # 'Tamper (Meter Inversion) detected on meter 00:13:50:05:ff:27:3f:a0.'
        '3.12.17.257':  [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\.?', '') 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Diag1 Condition cleared for meter 00:13:50:05:ff:04:55:a1.'
        # SEEMS RARE, BUT HAVE SEEN:
        # Reverse energy cleared for meter 00:13:50:05:ff:0d:dd:17.
        '3.12.48.28':    [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Diag1: Polarity, Cross Phase, Reverse Energy Flow occurred for meter 00:13:50:03:00:34:b7:e9. Angle out of tolerance [Voltage - Phase  B].'
        # 'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase A Current'
        # 'Service disconnect operation occurred with status: Close operation started'
        # 'Reverse energy (C1219 Table 3) occurred for meter 00:13:50:05:ff:0d:dd:17.'
        '3.12.48.219':  [
            #-----
            (r'(Diag1: Polarity, Cross Phase, Reverse Energy Flow)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)\s*(Angle out of tolerance) \[.*\]', r'\1: \2'), 
            #-----
            (r'(KV2c meter event Polarity, Cross Phase, Reverse Energy Flow) Diagnostic flags:.*', r'\1'), 
            #-----
            (r'(Service disconnect operation occurred with status:) (Open|Close) operation (started|succeeded)\s*', r'\1 \2 \3'), 
            #-----
            (r'((?:Diag1 Condition|Reverse energy)\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
        ],
        
        #-------------------------
        # Examples
        # 'Cleared: Meter00:13:50:05:ff:07:88:4b, cleared tamper detection (C1219 Table 3)'
        '3.12.93.28': [
            #-----
            (r'(Cleared: Meter)(?:\s*(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?), (cleared tamper detection.*)', r'\1 \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Meter event Reverse Rotation Detected.  Time event occurred on meter = 01/28/2020 15:31:34  Sequence number = 854  User id = 0  Event argument = 00-00'
        # 'Meter detected a Reverse Rotation.'
        # 'Meter 00:13:50:05:ff:0b:ae:84, detected tampering (C1219 Table 3)'
        # SEEMS RARE, BUT HAVE SEEN:
        # Meter event Demand Reset Occurred  Time event occurred on meter = 10/25/2020 10:07:33  Sequence number = 1256  User id = 1  Event argument = 00-00
        '3.12.93.219':    [
            #-----
            (r'(Meter)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\.,]?)\s*(detected tampering\s*(?:\(.*\))?)\s*', r'\1 \2'), 
            #-----
            (r'(Meter event (?:Reverse Rotation Detected|Demand Reset Occurred))\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'),
            #-----
            (r'(Meter event Reverse Rotation Detected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a Reverse Rotation).*', 'Meter event Reverse Rotation Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbc0:250:56ff:feb5:91c7 with a key that has insufficient privileges to execute it. ID: 53 READ SUBID: 65535 ASSOC_ID: 8448'
        # 'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbc0:a6ba:99ff:fe12:1b0e with a key that has insufficient privileges to execute it. ID: 207 WRITE SUBID: 65535 ASSOC_ID: 768'
        '3.12.136.38':  [
            #-----
            # BELOW, ID seemed meter-specific (or, at least, not general), as READ/WRITE SUBID and ASSOC_ID seem to only take on a few different values
            # Therefore, group 3, for ID, is not included in output
            (r'A?\s+?(.*command was sent) from(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(with a key that has insufficient privileges) to execute it.*(ID:\s*[0-9]+)\s*((?:READ|WRITE)\s*SUBID:\s*[0-9]+)\s*(ASSOC_ID:\s*[0-9]+).*', r'\1 \2: \4 \5'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'NET_MGMT command failed consecutively for 1 times for fd37:ec90:20c2:5c58:250:56ff:feb5:1010. WRITE'
        # 'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 16270'
        # 'failed consecutively for 1 times for 0:0:0:0:0:0:0:0.'
        # 'N/A failed consecutively for 1 times for 0:0:0:0:0:0:0:0. N/A'
        '3.12.136.85':  [
            #-----
            (r'(.*) failed consecutively for [0-9]+ times?(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1 failed consecutively for 1 or more times'), 
            #-----
            (r'^failed consecutively for [0-9]+ times? for 0:0:0:0:0:0:0:0.$', 'N/A failed consecutively for 1 or more times'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Meter detected a RAM failure.'
        # So, don't need to run any regex, but should still so no flags raised
        '3.18.1.199':    [
            #-----
            (r'(Meter detected a RAM failure).*', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # All seem to be: 'Meter detected a ROM failure.'
        # So, don't need to run any regex, but should still so no flags raised
        '3.18.1.220':    [
            #-----
            (r'(Meter detected a ROM failure).*', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'NVRAM Error cleared for meter 00:13:50:05:ff:0d:7e:64.'
        '3.18.72.28':   [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'NVRAM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:20:91:6c.'
        '3.18.72.79':   [
            #-----
            (r'(NVRAM Error\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 01/21/2020 09:45:01  Sequence number = 3335  User id = 0  Event argument = 00-00'
        # 'null'????????????
        # SEEMS RARE, BUT HAVE SEEN:
        # 'Meter event Demand Reset Occurred  Time event occurred on meter = 01/29/2023  Sequence number = 711  User id = 1  Event argument = 00-00 '
        # 'Meter event Reset List Pointers  Time event occurred on meter = 09/07/2021  Sequence number = 227  User id = 0  Event argument = 03-00'
        # 'KV2c meter event Received kWh Caution Diagnostic flags:Phase A Voltage'
        # 'Universal event Unsupported Event(41) with priority Alarm. '
        '3.18.72.85':   [
            #-----
#             (r'(Meter event (?:Nonvolatile Memory Failure Detected|Demand Reset Occurred|Reset List Pointers))\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'),
            (r'(Meter event.*?)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            # FAILSAFE in case Sequence number etc. not found above
            # NOTE: Cannot do (Meter event.*).*, as that will reduce everything altered above donw to simply 'Meter event'
            #       Also, if any additional info (e.g, Sequence number) is to be extracted using above, this must be removed
            (r'(Meter event (?:Nonvolatile Memory Failure Detected|Demand Reset Occurred|Reset List Pointers)).*', r'\1'),
            #-----
            (r'(Meter detected a nonvolatile memory failure).*', 'Meter event Nonvolatile Memory Failure Detected'), 
            #-----
            (r'(KV2c meter event .*?)\s*(Diagnostic flags)\s*\:\s*(.*?)\s*$', r'\1 (\2 = \3)'),
            #-----
            (r'(Universal event Unsupported Event\s*(?:\(.*\))?\s*with priority Alarm)[\s*\.]*', r'\1'), 
            #-----
            ('null', 'Reason is null, ID=3.18.72.85')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'RAM Error cleared for meter 00:13:50:05:ff:0d:dd:17.'
        '3.18.85.28':    [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'RAM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:0d:dd:17.'
        '3.18.85.79':   [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a RAM failure.'
        # 'Meter event Ram Failure Detected  Time event occurred on meter = 7/27/2021 12:45:53 PM  Sequence number = 89  User id = 34891  Event argument = 7D-75'
        '3.18.85.85':   [
            #-----
            (r'(Meter event Ram Failure Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Ram Failure Detected).*', r'\1'),
            #-----
            (r'(Meter detected a RAM failure).*', 'Meter event Ram Failure Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1f:ba:d0.'
        '3.18.92.28':   [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1f:ba:d0.'
        '3.18.92.79':   [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Rom Failure Detected  Time event occurred on meter = 03/16/2020 07:00:51  Sequence number = 1983  User id = 1024  Event argument = 00-00'
        # 'Meter detected a ROM failure.'
        # 'ROM failure detected.'
        '3.18.92.85':    [
            #-----
            (r'(Meter event Rom Failure Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Rom Failure Detected).*', r'\1'),
            #-----
            (r'^(?:Meter detected a ROM failure|ROM failure detected).*$', 'Meter event Rom Failure Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Measurement Error Detected  Time event occurred on meter = 08/26/2021 08:27:25  Sequence number = 307  User id = 0  Event argument = 00-00 '
        '3.21.1.79':    [
            #-----
            (r'(Meter event Measurement Error Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Measurement Error Detected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a measurement error).*', 'Meter event Measurement Error Detected')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 08/30/2021 04:00:11  Sequence number = 3256  User id = 0  Event argument = 00-00 '
        '3.21.1.173':    [
            #-----
            (r'(Meter event Nonvolatile Memory Failure Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Nonvolatile Memory Failure Detected).*', r'\1'),
            #-----
            (r'(Meter detected a nonvolatile memory failure).*', 'Meter event Nonvolatile Memory Failure Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'System Error cleared for meter 00:13:50:05:ff:11:2d:23.'
        '3.21.3.28':    [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0f:17:ba.'
        '3.21.3.79':    [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a self check error.'
        '3.21.17.28':    [
            #-----
            (r'(Meter detected a self check error).', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a self check error.'
        '3.21.18.79':    [
            #-----
            (r'(Meter detected a self check error).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Detected end of voltage sag on meter 00:13:50:05:ff:32:66:22 on one or several phases. Duration: 21 cycles (less than a second), Min RMS Voltage: Phase A 118.1 V, Phase B 95.4 V, Phase C 120.3 V, RMS Current (at min voltage): Phase A 1.0 A, Phase B 0.2 A, Phase C 1.2 A'
        '3.21.38.223':  [
            #-----
            (r'(Detected end of voltage sag)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*Duration:.*, Min RMS Voltage: Phase A .*, Phase B .*, Phase C .*, RMS Current \(at min voltage\): Phase A .*, Phase B .*, Phase C .*', r'\1'), 
            #-----
            # Failsafe
            (r'(Detected end of voltage sag)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Detected end of voltage swell on meter 00:13:50:05:ff:1b:49:b0 on one or several phases. Duration: 5 cycles (less than a second), Max RMS Voltage: Phase A 111.2 V, Phase B 133.2 V, Phase C 216.1 V, RMS Current (at max voltage): Phase A 2.8 A, Phase B 1.3 A, Phase C 0.8 A'
        '3.21.38.248':  [
            #-----
            (r'(Detected end of voltage swell)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*Duration: .*, Min RMS Voltage: .*, RMS Current \(at min voltage\): .*', r'\1'), 
            #-----
            # Failsafe
            (r'(Detected end of voltage swell)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1')  
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Detected end of voltage sag on meter 00:13:50:03:ff:01:a6:36. Duration: 2 seconds, Min RMS Voltage: Phase A 227.9 V, RMS Current (at min voltage): Phase A 0.0 A'
        '3.21.43.223':  [
            #-----
            (r'(Detected end of voltage sag)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*Duration: .*, Min RMS Voltage: .*, RMS Current \(at min voltage\): .*', r'\1'), 
            #-----
            (r'(Detected end of voltage sag)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1'), # failsafe  
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Detected end of voltage swell on meter 00:13:50:05:ff:2d:2c:25. Duration: 195 seconds, Max RMS Voltage: Phase A 265.7 V, RMS Current (at max voltage): Phase A 0.0 A'
        '3.21.43.248':  [
            #-----
            (r'(Detected end of voltage swell)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*Duration: .*, Min RMS Voltage: .*, RMS Current \(at min voltage\): .*', r'\1'), 
            #-----
            (r'(Detected end of voltage swell)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1'), # failsafe  
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Measurement Error cleared for meter 00:13:50:05:ff:07:c0:55.'
        '3.21.67.28':    [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Measurement Error Detected  Time event occurred on meter = 01/26/2020 19:47:00  Sequence number = 284  User id = 0  Event argument = 00-00'
        # 'Measurement Error (C1219 Table 3) occurred for meter 00:13:50:03:ff:06:d6:d5.'
        '3.21.67.79':    [
            #-----
            (r'(Measurement Error\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'(Meter event Measurement Error Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Measurement Error Detected).*', r'\1'),
            #-----
            (r'(Meter detected a measurement error).*', 'Meter event Measurement Error Detected')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'DSP Error cleared for meter 00:13:50:05:ff:0b:87:fc.'
        '3.21.82.28':    [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:2c:f3:e2.'
        '3.21.82.79':    [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Test Mode Stopped  Time event occurred on meter = 08/27/2021 10:04:04  Sequence number = 23834  User id = 1  Event argument = 00-00 '
        '3.22.12.243':   [
            #-----
            (r'(Meter event Test Mode Stopped)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Test Mode Stopped).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Test Mode Started  Time event occurred on meter = 08/27/2021 07:48:19  Sequence number = 765  User id = 1  Event argument = 00-00 '
        '3.22.19.242':   [
            #-----
            (r'(Meter event Test Mode Started)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Test Mode Started).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Device 00:13:50:05:ff:2e:17:7e has been determined to have exceeded the max allowable trap threshold, 20, within a certain time limit, 3600 seconds.'
        '3.23.17.139':   [
            #-----
            (r'(Device)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+).*(exceeded the max allowable trap threshold).*', r'\1 \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Access Point 00:13:50:08:ff:00:06:8e has lost connectivity with FHSS 900 MHz band.'
        '3.23.136.47':  [
            #-----
            (r'(Access Point)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(has lost connectivity with FHSS 900 MHz band.)', r'\1 \2') 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # Device: 00:13:50:05:ff:20:f5:ef Time: 2021-01-20T06:03:47.000-05:00 Failed Device: 00:13:50:05:ff:20:f5:ef Reason: Security public key mismatch Reboot Counter: 44 Refresh Counter: 0 Seconds since last reboot 6872803
        # 'NIC Link Layer Handshake Failed: Device: 00:13:50:05:ff:19:4e:6b, Rejected neighbor Mac ID: 00:13:50:05:ff:18:a3:52, Rejection Cause: invalid eblob signature'
        '3.23.136.85':  [
            #-----
            # Below, Device and Failed Device sometimes blank, sometime MAC-esque
            (r'Device\:?(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)? Time: .* Failed Device\:?(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)? (Reason: .*) Reboot Counter: .* Refresh Counter: .*', r'Device Failed: \1'), 
            #-----
            (r'(NIC Link Layer Handshake Failed): Device:(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+), Rejected neighbor Mac ID:(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+), (Rejection Cause: .*)', r'\1: \2')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter generated an energy polarity gyrbox call in event.'
        '3.25.17.3':   [
            #-----
            (r'(Meter generated an energy polarity gyrbox call in event).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Primary Power Down occurred for meter 00:13:50:05:ff:16:5f:61.'
        # 'Meter had a power outage. Unsafe power fail count = 32714'
        # 'Meter event Primary Power Down  Time event occurred on meter = 08/05/2021 16:59:27  Sequence number = 691  User id = 0  Event argument = 00-00'
        '3.26.0.47': [
            #-----
            (r'(Primary Power Down)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'(Meter had a power outage)\.?\s*(Unsafe power fail)\s*count\s*=\s*[0-9]+', r'\1 (\2)'), 
            #-----
            (r'^(Meter had a power outage).*$', r'\1'), #Fail proof, in case Unsafe power fail, count, etc., not found 
            #-----
            (r'(Meter event Primary Power Down)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Primary Power Down).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
        ],         
        
        #-------------------------
        # Examples
        # 'Primary Power Up occurred for meter 00:13:50:05:ff:22:2a:0c.'
        # 'Meter event Primary Power Up Time event occurred on meter = 08/14/2020 Sequence number = 343 User id = 0 Event argument = 00-00'
        '3.26.0.216':   [
            #-----
            (r'(Primary Power Up)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'Meter event (Primary Power Up)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'Meter event (Primary Power Up).*', r'\1'),  #Fail proof, in case time, sequence, etc., not found 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter had a power outage. Unsafe power fail count = 13050'
        # Meter event Primary Power Down  Time event occurred on meter = 08/31/2021 20:07:18  Sequence number = 103  User id = 0  Event argument = 00-00 
        '3.26.17.185':  [
            #-----
            (r'(Meter had a power outage).\s*(Unsafe power fail) count = [0-9]+', r'\1 (\2)'), 
            #-----
            (r'(Meter event Primary Power Down)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Primary Power Down).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Primary Power Up  Time event occurred on meter = 08/31/2021 20:07:44  Sequence number = 104  User id = 0  Event argument = 00-00 '
        '3.26.17.216':  [
            #-----
            (r'Meter event (Primary Power Up)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'Meter event (Primary Power Up).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Under Voltage cleared (CA000400) for meter 00:13:50:05:ff:0b:88:ec.'
        # 'Under Voltage (CA000400) cleared for meter 00:13:50:05:ff:15:e8:3b.'
        # 'Under Voltage (Diagnostic 6) cleared for meter 00:13:50:05:ff:3f:87:07N/A.'
        '3.26.38.37':   [
            #-----
            # NOTE: Due to annoying N/A at end of some MAC-esque IDs, I have to specify length of numerical entries
            #       as [0-9a-zA-Z]{1,2}, instead of the more general [0-9a-zA-Z]+ found elsewhere!
            (r'(Under Voltage|Low Potential|Diag6 Condition)\s*(\scleared)?\s*(\s\(.*\))?\s*(\scleared)?\s*(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]{1,2})(?:\:[0-9a-zA-Z]{1,2})+(?:N/A)?\.?)', r'\1\3\2\4')
            #-----
        ],       
        
        #-------------------------
        # Examples
        # 'Low Potential (C1219 Table 3) occurred for meter 00:13:50:05:ff:1b:67:3b.'
        '3.26.38.47': [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Diag7 Condition cleared for meter 00:13:50:03:00:4d:41:fa.'
        # 'Over Voltage (Diagnostic 7) cleared for meter 00:13:50:05:ff:37:87:3dN/A.'
        '3.26.38.73':   [
            #-----
            # NOTE: Due to annoying N/A at end of some MAC-esque IDs, I have to specify length of numerical entries
            #       as [0-9a-zA-Z]{1,2}, instead of the more general [0-9a-zA-Z]+ found elsewhere!
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]{1,2})(?:\:[0-9a-zA-Z]{1,2})+(?:N/A)?\.?)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Diag7: Over Voltage, Element A occurred for meter 03.34.0.400:13:50:02:00:0a:d7:98.'
        # 'Over Voltage (Diagnostic 7) occurred for meter 00:13:50:05:ff:41:8a:8f: Phase A.'
        # SEEMS RARE, BUT HAVE SEEN:
        # 'KV2c meter event Over Voltage Diagnostic flags:Phase A Voltage'
        # 'KV2c meter event Under Voltage Caution Diagnostic flags:Phase B Voltage'
        # 'KV2c meter event Received kWh Caution Diagnostic flags:Phase A Voltage '
        # 'KV2c meter event Received kWh Caution Cleared '
        '3.26.38.93':   [
            #-----
            (r'(KV2c meter event (?:(?:Over|Under) Voltage)|(?:Voltage Out of Tolerance)|(?:(?:Received|Delivered) kWh))(?:\s*Caution)?\s*(Diagnostic flags)\s*\:\s*(.*?)\s*$', r'\1 (\2 = \3)'), 
            #-----
            (r'(KV2c meter event (?:(?:Over|Under) Voltage)|(?:Voltage Out of Tolerance)|(?:(?:Received|Delivered) kWh))(?:\s*Caution)?\s*Cleared\s*$', r'\1 Cleared'), 
            #-----
            (r'(.*Over Voltage.*?)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)(.*?)\s*$', r'\1\2') 
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Under Voltage (CA000400) for meter 00:13:50:05:ff:0b:88:ec. Phase  C Voltage out of tolerance.'
        # 'Under Voltage (CA000400) occurred for meter 00:13:50:05:ff:15:e8:3b: Phase A.'
        # 'KV2c meter event Under Voltage Diagnostic flags:Phase A Voltage'
        # 'Diag6: Under Voltage, Element A occurred for meter 00:13:50:05:ff:0b:88:ec.'
        '3.26.38.150':   [
            #-----
            # NOTE: Due to annoying N/A at end of some MAC-esque IDs, I have to specify length of numerical entries
            #       as [0-9a-zA-Z]{1,2}, instead of the more general [0-9a-zA-Z]+ found elsewhere!
            # NOTE: Also, the use of non-greedy (.*?) at beginning.
            #       If (.*) were used instead, results would be, e.g.
            #          'Diag6: Under Voltage, Element A occurred for meter'
            #       instead of 
            #          'Diag6: Under Voltage, Element A'
            (r'(Under Voltage\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\.\:]?)(\s?.*?)', r'\1\2'), 
            #-----
            (r'(Diag6.*?)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\.\:]?)(\s?.*?)', r'\1\2'), 
            #-----
            (r'(KV2c meter event .*?)\s*(Diagnostic flags)\s*\:\s*(.*?)\s*$', r'\1 (\2 = \3)')
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Last Gasp - NIC power lost for device: 00:13:50:05:ff:0b:83:e4, Reboot Count: 12264, NIC timestamp: 2020-01-19T22:21:02.000-05:00, Received timestamp: 2020-01-19T22:21:04.353-05:00, Fail Reason: [0x49] LG_ZERO_X_DETECTOR ,LG_DIRECT_NOTIFICATION'
        '3.26.136.47':  [
            #-----
            (r'(Last Gasp - NIC power lost for device):(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+).*(Fail Reason: .*)$', r'\1, \2')
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Device 00:13:50:05:ff:0b:8a:18, Last Gasp State: EL_EVENT_POWER_FAIL_DETECT_LG_DISABLED, Detector State: EL_EVENT_POWER_FAIL_DETECT_NIC_ZX_DISABLED, Reboot Count: 108'
        '3.26.136.66':  [
            #-----
            (r'Device(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+), (Last Gasp State: .*), (Detector State: .*), Reboot Count: \d*', r'\1, \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'NIC Power Restore Trap Received from device: 00:13:50:05:ff:0c:7e:93, Reboot Count: 61, NIC timestamp: 2020-01-27T09:19:56.000-05:00, Received Timestamp: 2020-01-27T09:19:57.204-05:00, Power Restoration Timestamp: 2020-01-27T09:19:42.000-05:00, State: 4,p'
        '3.26.136.216': [
            #-----
            (r'(NIC Power Restore Trap Received from device):(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter assumed to be disconnected has reported Load side voltage indicating a potential case of tamper.'
        '3.31.1.143':   [
            #-----
            (r'(Meter assumed to be disconnected has reported Load side voltage indicating a potential case of tamper).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Reverse Rotation Detected  Time event occurred on meter = 08/30/2021 04:25:38  Sequence number = 13124  User id = 0  Event argument = 00-00 '
        '3.33.1.219':   [
            #-----
            (r'(Meter event Reverse Rotation Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Reverse Rotation Detected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a Reverse Rotation).*', 'Meter event Reverse Rotation Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a Tamper Attempt.'
        # 'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 08:45:05  Sequence number = 72  User id = 0  Event argument = 00-00 '
        '3.33.1.257':   [
            #-----
            (r'(Meter event Tamper Attempt Suspected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Tamper Attempt Suspected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a Tamper Attempt).*', 'Meter event Tamper Attempt Suspected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Cleared: Meter 00:13:50:05:ff:11:69:bb detected a high temperature condition. (C1219 Table 3)'
        '3.35.0.28': [
            #-----
            # NOTE: Here, the MAC-esque code occurs in middle of string, not the end as is common elsewhere.
            #       This is why the pattern here excludes [\s*\.]* at the end
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter 00:13:50:05:ff:11:69:bb detected a high temperature condition. (C1219 Table 3)'
        # 'Meter's temperature threshold exceeded.'
        # 'Meter event AX Temp Threshold Exceeded  Time event occurred on meter = 02/19/2021 13:33:50  Sequence number = 5115  User id = 0  Event argument = 00-00 '
        # 'Meter event S4TemperatureThreshold  Time event occurred on meter = 05/25/2023 17:12:50  Sequence number = 45  User id = 0  Event argument = 00-00-00-00-00-00 '
        '3.35.0.40': [
            #-----
            (r'(Meter)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(detected a high temperature condition)\.\s*(.*)', r'\1 \2 \3'), 
            #-----
            (r"(Meter's temperature threshold exceeded).", r'\1'), 
            #-----
            (r'(Meter event .*?)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event (?:AX Temp Threshold Exceeded|S4TemperatureThreshold)).*', r'\1'),
        ],  
        
        #-------------------------
        # Examples
        # 'Meter detected a clock error.'
        # 'Meter event Clock Error Detected  Time event occurred on meter = 04/18/2020 10:00:10  Sequence number = 332  User id = 0  Event argument = 00-00'
        '3.36.0.79': [
            #-----
            (r'(Meter event Clock Error Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Clock Error Detected).*', r'\1'),
            #-----
            (r'(Meter detected a clock error).*', 'Meter event Clock Error Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a clock error.'
        '3.36.1.29': [
            #-----
            ('(Meter detected a clock error).', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter 00:13:50:05:ff:2e:13:de, detected loss of time (C1219 Table 3)'
        '3.36.114.73':  [
            #-----
            (r'(Meter)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+),\s*(detected loss of time .*)', r'\1 \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Ignoring Interval Read data for device 00:13:50:05:ff:1e:fa:a4 as it has time in the future 2069-05-02 18:51:00.0'
        '3.36.114.159': [
            #-----
            (r'(Ignoring (?:Interval|Register) Read data for device)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(as it has time in the future).*', r'\1 \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter 00:13:50:05:ff:14:c9:61 needs explicit time sync. Drift: 14391 s, Encountered Problems:  TS_ERR_LP_BX, TS_ERR_BIG_DRIFT [0x44], Meter_Time: 06:33:41'
        '3.36.136.73':  [
            #-----
            (r'(Meter)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(needs explicit time sync.) Drift: -?\d* s, (Encountered Problems:\s*.*), Meter_Time.*', r'\1 \2 \3'), 
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Error occurred when attempting to synch meter time with NIC time for device 00:13:50:05:ff:29:e1:20'
        # So, standard beg/end patterns should suffice
        '3.36.136.79':    [
            #-----
            (r'((?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\s*\.]*)', '')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase B Voltage '
        # 'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase B Voltage, Phase C Voltage '
        '3.38.1.139':    [
            #-----
            (r'(KV2c meter event Polarity, Cross Phase, Reverse Energy Flow) Diagnostic flags:.*', r'\1'), 
            #-----
        ]
    }

# %%
def get_std_patterns_to_replace_by_typeid_EXPLICIT_v2():
    r"""
    Returns the standard patterns_to_replace_by_typeid.
    Function exists essentially to keep reduce_end_event_reasons_in_df from being too cluttered
    
    NOTE: Multi-line strings have more parentheses than absolutely necessary for clarity.
    NOTE: In (r'\s{2,}', ' '), the second element ' ' has a space between the quotes! So, multiple white-space characters
            are to be replaced with a single-space.
          This is different from many other cases, where ther is no space between the quotes, and in which case the match
            is to be removed (by replacing it with an empty character, e.g., (r'\s+([0-9a-zA-Z]+)(\:[0-9a-zA-Z]+)+', ''))  
    """
    #-------------------------
    patterns_to_replace_by_typeid = {
        #-------------------------
        # Examples
        # 'Power Loss cleared for meter 00:13:50:05:ff:0d:dd:17'
        '3.2.0.28':    [
            #-----
            (r'(Power Loss cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1')
            #-----
        ],  
        
        #-------------------------
        # Examples
        # 'Power loss detected on meter 00:13:50:05:ff:0d:dd:17'
        '3.2.0.85':    [
            #-----
            (r'(Power loss detected)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Low Battery cleared for meter 00:13:50:02:00:0a:9e:1e.'
        '3.2.22.28':    [
            #-----
            (r'(Low Battery cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Low Battery (C1219 Table 3) occurred for meter 00:13:50:02:00:0a:9e:1e.'
        '3.2.22.150':    [
            #-----
            (r'(Low Battery\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Test Mode Started occurred for meter 00:13:50:05:ff:1d:2d:4a.'
        # 'Meter event Test Mode Started  Time event occurred on meter = 01/20/2020 12:56:50  Sequence number = 56  User id = 1  Event argument = 00-00'
        # SEEMS RARE, BUT HAVE SEEN:
        # 'Meter is currently in test mode.'
        '3.7.19.242':    [
            #-----
            (r'(Test Mode Started)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'(Meter event Test Mode Started)\s*Time event occurred on meter = .* Sequence number = .* User id = .*  Event argument = .*', r'\1'), 
            #-----
            (r'(Meter event Test Mode Started).*', 'Test Mode Started'), 
            #-----
            (r'(Meter is currently in test mode)[\s\.]*', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Test Mode Stopped occurred for meter 00:13:50:03:ff:06:20:96.'
        # 'Meter event Test Mode Stopped  Time event occurred on meter = 01/02/2020 08:25:04  Sequence number = 573  User id = 1  Event argument = 00-00'
        '3.7.19.243':    [
            #-----
            (r'(Test Mode Stopped)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'(Meter event Test Mode Stopped)\s*Time event occurred on meter = .* Sequence number = .* User id = .*  Event argument = .*', r'\1'), 
            #-----
            (r'(Meter event Test Mode Stopped).*', 'Test Mode Stopped')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'NIC operating on backup battery: 00:13:50:ff:fe:70:96:ac, Reboot Count: 6, NIC timestamp: 2021-01-14T10:17:54.000-05:00, Received timestamp: 2021-01-14T10:17:55.728-05:00'
        '3.7.22.4':    [
            #-----
            (r'(NIC operating on backup battery)\:(\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?), Reboot Count: .*, NIC timestamp: .*, Received timestamp: .*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # All seem to be: 'NIC backup battery inactive'
        # So, don't need to run any regex, but should still so no flags raised
        '3.7.22.19':    [
            #-----
            (r'(NIC backup battery inactive).*', r'\1')
            #-----
        ],      
        
        #-------------------------
        # Examples
        # 'Demand Reset occurred for meter 00:13:50:05:ff:18:b3:c1.'
        '3.8.0.215':    [
            #-----
            (r'(Demand Reset)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1') 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter Program Seal mismatch for Device [Device ID, MAC Id] = [1ND785727916NMD06, 00:13:50:05:ff:1d:16:96] - program seal = 0bda0569c8e6ad375375eaa177034d3f61a80478 vs. UIQ program seal = e2dbe1ccbeef1f2df38adffeeafdb86fbd8fb006 at 2021-01-08T06:16:49.116-05:00.'
        '3.9.83.159':    [
            #-----
            (r'(Meter Program Seal mismatch for Device)\s*\[Device ID, MAC Id\]\s*=\s*.*', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Requested operation JOB_OP_TYPE_ARB_METER_COMMAND could not be applied to the given device type and firmware version. Device: 00:13:50:05:ff:2d:ff:34, DeviceType: DID_SUBTYPE_I210CRD_HAN, Firmware Version: 3.12.5c'
        '3.11.63.161':  [
            #-----
            # Below, Device sometimes blank, sometime MAC-esque
            (r'(Requested operation)\s*(.*?)\s*(could not be applied) to the given device type and firmware version.\s*Device\:?(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)?,\s*DeviceType\:?.*,\s*Firmware Version\:?.*', r'\1 \3: \2')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Tamper Attempt Suspected  Time event occurred on meter = 01/10/2020 10:03:37  Sequence number = 1189  User id = 0  Event argument = 00-00'
        # 'Meter detected a Tamper Attempt.'
        # 'Tamper attempt detected.'
        '3.12.0.257':   [
            #-----
            (r'(Meter event Tamper Attempt Suspected)\s*Time event occurred on meter = .* Sequence number = .* User id = .*  Event argument = .*', r'\1'), 
            #-----
            (r'(Meter event Tamper Attempt Suspected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a Tamper Attempt|Tamper attempt detected).*', 'Meter detected a Tamper Attempt'), 
            #-----
        ],    
        
        #-------------------------
        # Examples:
        # 'Tamper (Meter Inversion) detected on meter 00:13:50:05:ff:27:3f:a0.'
        '3.12.17.257':  [
            #-----
            (r'(Tamper\s*(?:\(.*\))?\s*detected)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Diag1 Condition cleared for meter 00:13:50:05:ff:04:55:a1.'
        # SEEMS RARE, BUT HAVE SEEN:
        # Reverse energy cleared for meter 00:13:50:05:ff:0d:dd:17.
        '3.12.48.28':    [
            #-----
            (r'((?:Diag1 Condition|Reverse energy) cleared)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Diag1: Polarity, Cross Phase, Reverse Energy Flow occurred for meter 00:13:50:03:00:34:b7:e9. Angle out of tolerance [Voltage - Phase  B].'
        # 'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase A Current'
        # 'Service disconnect operation occurred with status: Close operation started'
        # 'Reverse energy (C1219 Table 3) occurred for meter 00:13:50:05:ff:0d:dd:17.'
        '3.12.48.219':  [
            #-----
            (r'(Diag1: Polarity, Cross Phase, Reverse Energy Flow)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)\s*(Angle out of tolerance) \[.*\]', r'\1: \2'), 
            #-----
            (r'(KV2c meter event Polarity, Cross Phase, Reverse Energy Flow) Diagnostic flags:.*', r'\1'), 
            #-----
            (r'(Service disconnect operation occurred with status:) (Open|Close) operation (started|succeeded)\s*', r'\1 \2 \3'), 
            #-----
            (r'((?:Diag1 Condition|Reverse energy)\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
        ],
        
        #-------------------------
        # Examples
        # 'Cleared: Meter00:13:50:05:ff:07:88:4b, cleared tamper detection (C1219 Table 3)'
        '3.12.93.28': [
            #-----
            (r'(Cleared: Meter)(?:\s*(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?), (cleared tamper detection.*)', r'\1 \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Meter event Reverse Rotation Detected  Time event occurred on meter = 01/28/2020 15:31:34  Sequence number = 854  User id = 0  Event argument = 00-00'
        # 'Meter detected a Reverse Rotation.'
        # 'Meter 00:13:50:05:ff:0b:ae:84, detected tampering (C1219 Table 3)'
        # SEEMS RARE, BUT HAVE SEEN:
        # Meter event Demand Reset Occurred  Time event occurred on meter = 10/25/2020 10:07:33  Sequence number = 1256  User id = 1  Event argument = 00-00
        '3.12.93.219':    [
            #-----
            (r'(Meter)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\.,]?)\s*(detected tampering\s*(?:\(.*\))?)\s*', r'\1 \2'), 
            #-----
            (r'(Meter event (?:Reverse Rotation Detected|Demand Reset Occurred))\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'),
            #-----
            (r'(Meter event Reverse Rotation Detected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a Reverse Rotation).*', 'Meter event Reverse Rotation Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbc0:250:56ff:feb5:91c7 with a key that has insufficient privileges to execute it. ID: 53 READ SUBID: 65535 ASSOC_ID: 8448'
        # 'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbc0:a6ba:99ff:fe12:1b0e with a key that has insufficient privileges to execute it. ID: 207 WRITE SUBID: 65535 ASSOC_ID: 768'
        '3.12.136.38':  [
            #-----
            # BELOW, ID seemed meter-specific (or, at least, not general), as READ/WRITE SUBID and ASSOC_ID seem to only take on a few different values
            # Therefore, group 3, for ID, is not included in output
            (r'A?\s+?(.*command was sent) from(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(with a key that has insufficient privileges) to execute it.*(ID:\s*[0-9]+)\s*((?:READ|WRITE)\s*SUBID:\s*[0-9]+)\s*(ASSOC_ID:\s*[0-9]+).*', r'\1 \2: \4 \5'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'NET_MGMT command failed consecutively for 1 times for fd37:ec90:20c2:5c58:250:56ff:feb5:1010. WRITE'
        # 'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 16270'
        # 'failed consecutively for 1 times for 0:0:0:0:0:0:0:0.'
        # 'N/A failed consecutively for 1 times for 0:0:0:0:0:0:0:0. N/A'
        '3.12.136.85':  [
            #-----
            (r'(.*) failed consecutively for [0-9]+ times?(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1 failed consecutively for 1 or more times'), 
            #-----
            (r'^failed consecutively for [0-9]+ times? for 0:0:0:0:0:0:0:0.$', 'N/A failed consecutively for 1 or more times'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Meter detected a RAM failure.'
        # So, don't need to run any regex, but should still so no flags raised
        '3.18.1.199':    [
            #-----
            (r'(Meter detected a RAM failure).*', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # All seem to be: 'Meter detected a ROM failure.'
        # So, don't need to run any regex, but should still so no flags raised
        '3.18.1.220':    [
            #-----
            (r'(Meter detected a ROM failure).*', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'NVRAM Error cleared for meter 00:13:50:05:ff:0d:7e:64.'
        '3.18.72.28':   [
            #-----
            (r'(NVRAM Error cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'NVRAM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:20:91:6c.'
        '3.18.72.79':   [
            #-----
            (r'(NVRAM Error\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 01/21/2020 09:45:01  Sequence number = 3335  User id = 0  Event argument = 00-00'
        # 'null'????????????
        # SEEMS RARE, BUT HAVE SEEN:
        # 'Meter event Demand Reset Occurred  Time event occurred on meter = 01/29/2023  Sequence number = 711  User id = 1  Event argument = 00-00 '
        # 'Meter event Reset List Pointers  Time event occurred on meter = 09/07/2021  Sequence number = 227  User id = 0  Event argument = 03-00'
        # 'KV2c meter event Received kWh Caution Diagnostic flags:Phase A Voltage'
        # 'Universal event Unsupported Event(41) with priority Alarm. '
        '3.18.72.85':   [
            #-----
#             (r'(Meter event (?:Nonvolatile Memory Failure Detected|Demand Reset Occurred|Reset List Pointers))\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'),
            (r'(Meter event.*?)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            # FAILSAFE in case Sequence number etc. not found above
            # NOTE: Cannot do (Meter event.*).*, as that will reduce everything altered above donw to simply 'Meter event'
            #       Also, if any additional info (e.g, Sequence number) is to be extracted using above, this must be removed
            (r'(Meter event (?:Nonvolatile Memory Failure Detected|Demand Reset Occurred|Reset List Pointers)).*', r'\1'),
            #-----
            (r'(Meter detected a nonvolatile memory failure).*', 'Meter event Nonvolatile Memory Failure Detected'), 
            #-----
            (r'(KV2c meter event .*?)\s*(Diagnostic flags)\s*\:\s*(.*?)\s*$', r'\1 (\2 = \3)'),
            #-----
            (r'(Universal event Unsupported Event\s*(?:\(.*\))?\s*with priority Alarm)[\s*\.]*', r'\1'), 
            #-----
            ('null', 'Reason is null, ID=3.18.72.85')
            #-----
        ],         
        
        #-------------------------
        # Examples:
        # 'RAM Error cleared for meter 00:13:50:05:ff:0d:dd:17.'
        '3.18.85.28':    [
            #-----
            (r'(RAM Error cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'RAM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:0d:dd:17.'
        '3.18.85.79':   [
            #-----
            (r'(RAM Error\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a RAM failure.'
        # 'Meter event Ram Failure Detected  Time event occurred on meter = 7/27/2021 12:45:53 PM  Sequence number = 89  User id = 34891  Event argument = 7D-75'
        '3.18.85.85':   [
            #-----
            (r'(Meter event Ram Failure Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Ram Failure Detected).*', r'\1'),
            #-----
            (r'(Meter detected a RAM failure).*', 'Meter event Ram Failure Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1f:ba:d0.'
        '3.18.92.28':   [
            #-----
            (r'(ROM Error cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1f:ba:d0.'
        '3.18.92.79':   [
            #-----
            (r'(ROM Error\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Rom Failure Detected  Time event occurred on meter = 03/16/2020 07:00:51  Sequence number = 1983  User id = 1024  Event argument = 00-00'
        # 'Meter detected a ROM failure.'
        # 'ROM failure detected.'
        '3.18.92.85':    [
            #-----
            (r'(Meter event Rom Failure Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Rom Failure Detected).*', r'\1'),
            #-----
            (r'^(?:Meter detected a ROM failure|ROM failure detected).*$', 'Meter event Rom Failure Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Measurement Error Detected  Time event occurred on meter = 08/26/2021 08:27:25  Sequence number = 307  User id = 0  Event argument = 00-00 '
        '3.21.1.79':    [
            #-----
            (r'(Meter event Measurement Error Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Measurement Error Detected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a measurement error).*', 'Meter event Measurement Error Detected')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 08/30/2021 04:00:11  Sequence number = 3256  User id = 0  Event argument = 00-00 '
        '3.21.1.173':    [
            #-----
            (r'(Meter event Nonvolatile Memory Failure Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Nonvolatile Memory Failure Detected).*', r'\1'),
            #-----
            (r'(Meter detected a nonvolatile memory failure).*', 'Meter event Nonvolatile Memory Failure Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'System Error cleared for meter 00:13:50:05:ff:11:2d:23.'
        '3.21.3.28':    [
            #-----
            (r'(System Error cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0f:17:ba.'
        '3.21.3.79':    [
            #-----
            (r'(System Error\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a self check error.'
        '3.21.17.28':    [
            #-----
            (r'(Meter detected a self check error).', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a self check error.'
        '3.21.18.79':    [
            #-----
            (r'(Meter detected a self check error).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Detected end of voltage sag on meter 00:13:50:05:ff:32:66:22 on one or several phases. Duration: 21 cycles (less than a second), Min RMS Voltage: Phase A 118.1 V, Phase B 95.4 V, Phase C 120.3 V, RMS Current (at min voltage): Phase A 1.0 A, Phase B 0.2 A, Phase C 1.2 A'
        '3.21.38.223':  [
            #-----
            (r'(Detected end of voltage sag)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*Duration:.*, Min RMS Voltage: Phase A .*, Phase B .*, Phase C .*, RMS Current \(at min voltage\): Phase A .*, Phase B .*, Phase C .*', r'\1'), 
            #-----
            # Failsafe
            (r'(Detected end of voltage sag)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Detected end of voltage swell on meter 00:13:50:05:ff:1b:49:b0 on one or several phases. Duration: 5 cycles (less than a second), Max RMS Voltage: Phase A 111.2 V, Phase B 133.2 V, Phase C 216.1 V, RMS Current (at max voltage): Phase A 2.8 A, Phase B 1.3 A, Phase C 0.8 A'
        '3.21.38.248':  [
            #-----
            (r'(Detected end of voltage swell)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*Duration: .*, Min RMS Voltage: .*, RMS Current \(at min voltage\): .*', r'\1'), 
            #-----
            # Failsafe
            (r'(Detected end of voltage swell)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1')  
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Detected end of voltage sag on meter 00:13:50:03:ff:01:a6:36. Duration: 2 seconds, Min RMS Voltage: Phase A 227.9 V, RMS Current (at min voltage): Phase A 0.0 A'
        '3.21.43.223':  [
            #-----
            (r'(Detected end of voltage sag)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*Duration: .*, Min RMS Voltage: .*, RMS Current \(at min voltage\): .*', r'\1'), 
            #-----
            (r'(Detected end of voltage sag)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1'), # failsafe  
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Detected end of voltage swell on meter 00:13:50:05:ff:2d:2c:25. Duration: 195 seconds, Max RMS Voltage: Phase A 265.7 V, RMS Current (at max voltage): Phase A 0.0 A'
        '3.21.43.248':  [
            #-----
            (r'(Detected end of voltage swell)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*Duration: .*, Min RMS Voltage: .*, RMS Current \(at min voltage\): .*', r'\1'), 
            #-----
            (r'(Detected end of voltage swell)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?).*', r'\1'), # failsafe  
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Measurement Error cleared for meter 00:13:50:05:ff:07:c0:55.'
        '3.21.67.28':    [
            #-----
            (r'(Measurement Error.*cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Measurement Error Detected  Time event occurred on meter = 01/26/2020 19:47:00  Sequence number = 284  User id = 0  Event argument = 00-00'
        # 'Measurement Error (C1219 Table 3) occurred for meter 00:13:50:03:ff:06:d6:d5.'
        '3.21.67.79':    [
            #-----
            (r'(Measurement Error\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'(Meter event Measurement Error Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Measurement Error Detected).*', r'\1'),
            #-----
            (r'(Meter detected a measurement error).*', 'Meter event Measurement Error Detected')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'DSP Error cleared for meter 00:13:50:05:ff:0b:87:fc.'
        '3.21.82.28':    [
            #-----
            (r'(DSP Error cleared)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:2c:f3:e2.'
        '3.21.82.79':    [
            #-----
            (r'(DSP Error\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1') 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Test Mode Stopped  Time event occurred on meter = 08/27/2021 10:04:04  Sequence number = 23834  User id = 1  Event argument = 00-00 '
        '3.22.12.243':   [
            #-----
            (r'(Meter event Test Mode Stopped)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Test Mode Stopped).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Test Mode Started  Time event occurred on meter = 08/27/2021 07:48:19  Sequence number = 765  User id = 1  Event argument = 00-00 '
        '3.22.19.242':   [
            #-----
            (r'(Meter event Test Mode Started)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Test Mode Started).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Device 00:13:50:05:ff:2e:17:7e has been determined to have exceeded the max allowable trap threshold, 20, within a certain time limit, 3600 seconds.'
        '3.23.17.139':   [
            #-----
            (r'(Device)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+).*(exceeded the max allowable trap threshold).*', r'\1 \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Access Point 00:13:50:08:ff:00:06:8e has lost connectivity with FHSS 900 MHz band.'
        '3.23.136.47':  [
            #-----
            (r'(Access Point)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(has lost connectivity with FHSS 900 MHz band.)', r'\1 \2') 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # Device: 00:13:50:05:ff:20:f5:ef Time: 2021-01-20T06:03:47.000-05:00 Failed Device: 00:13:50:05:ff:20:f5:ef Reason: Security public key mismatch Reboot Counter: 44 Refresh Counter: 0 Seconds since last reboot 6872803
        # 'NIC Link Layer Handshake Failed: Device: 00:13:50:05:ff:19:4e:6b, Rejected neighbor Mac ID: 00:13:50:05:ff:18:a3:52, Rejection Cause: invalid eblob signature'
        '3.23.136.85':  [
            #-----
            # Below, Device and Failed Device sometimes blank, sometime MAC-esque
            (r'Device\:?(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)? Time: .* Failed Device\:?(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)? (Reason: .*) Reboot Counter: .* Refresh Counter: .*', r'Device Failed: \1'), 
            #-----
            (r'(NIC Link Layer Handshake Failed): Device:(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+), Rejected neighbor Mac ID:(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+), (Rejection Cause: .*)', r'\1: \2')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter generated an energy polarity gyrbox call in event.'
        '3.25.17.3':   [
            #-----
            (r'(Meter generated an energy polarity gyrbox call in event).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Primary Power Down occurred for meter 00:13:50:05:ff:16:5f:61.'
        # 'Meter had a power outage. Unsafe power fail count = 32714'
        # 'Meter event Primary Power Down  Time event occurred on meter = 08/05/2021 16:59:27  Sequence number = 691  User id = 0  Event argument = 00-00'
        '3.26.0.47': [
            #-----
            (r'(Primary Power Down)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'(Meter had a power outage)\.?\s*(Unsafe power fail)\s*count\s*=\s*[0-9]+', r'\1 (\2)'), 
            #-----
            (r'^(Meter had a power outage).*$', r'\1'), #Fail proof, in case Unsafe power fail, count, etc., not found 
            #-----
            (r'(Meter event Primary Power Down)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Primary Power Down).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
        ],         
        
        #-------------------------
        # Examples
        # 'Primary Power Up occurred for meter 00:13:50:05:ff:22:2a:0c.'
        # 'Meter event Primary Power Up Time event occurred on meter = 08/14/2020 Sequence number = 343 User id = 0 Event argument = 00-00'
        '3.26.0.216':   [
            #-----
            (r'(Primary Power Up)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1'), 
            #-----
            (r'Meter event (Primary Power Up)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'Meter event (Primary Power Up).*', r'\1'),  #Fail proof, in case time, sequence, etc., not found 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter had a power outage. Unsafe power fail count = 13050'
        # Meter event Primary Power Down  Time event occurred on meter = 08/31/2021 20:07:18  Sequence number = 103  User id = 0  Event argument = 00-00 
        '3.26.17.185':  [
            #-----
            (r'(Meter had a power outage).\s*(Unsafe power fail) count = [0-9]+', r'\1 (\2)'), 
            #-----
            (r'(Meter event Primary Power Down)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Primary Power Down).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Primary Power Up  Time event occurred on meter = 08/31/2021 20:07:44  Sequence number = 104  User id = 0  Event argument = 00-00 '
        '3.26.17.216':  [
            #-----
            (r'Meter event (Primary Power Up)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'Meter event (Primary Power Up).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Under Voltage cleared (CA000400) for meter 00:13:50:05:ff:0b:88:ec.'
        # 'Under Voltage (CA000400) cleared for meter 00:13:50:05:ff:15:e8:3b.'
        # 'Under Voltage (Diagnostic 6) cleared for meter 00:13:50:05:ff:3f:87:07N/A.'
        '3.26.38.37':   [
            #-----
            # NOTE: Due to annoying N/A at end of some MAC-esque IDs, I have to specify length of numerical entries
            #       as [0-9a-zA-Z]{1,2}, instead of the more general [0-9a-zA-Z]+ found elsewhere!
            (r'(Under Voltage|Low Potential|Diag6 Condition)\s*(\scleared)?\s*(\s\(.*\))?\s*(\scleared)?\s*(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]{1,2})(?:\:[0-9a-zA-Z]{1,2})+(?:N/A)?\.?)', r'\1\3\2\4')
            #-----
        ],        
        
        #-------------------------
        # Examples
        # 'Low Potential (C1219 Table 3) occurred for meter 00:13:50:05:ff:1b:67:3b.'
        '3.26.38.47': [
            #-----
            (r'(Low Potential\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)', r'\1') 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Diag7 Condition cleared for meter 00:13:50:03:00:4d:41:fa.'
        # 'Over Voltage (Diagnostic 7) cleared for meter 00:13:50:05:ff:37:87:3dN/A.'
        '3.26.38.73':   [
            #-----
            # NOTE: Due to annoying N/A at end of some MAC-esque IDs, I have to specify length of numerical entries
            #       as [0-9a-zA-Z]{1,2}, instead of the more general [0-9a-zA-Z]+ found elsewhere!
            # NOTE: Also, the use of non-greedy (.*?) at beginning.
            #       If (.*) were used instead, results would be, e.g.
            #          'Over Voltage (Diagnostic 7) cleared for meter' instead of 'Over Voltage (Diagnostic 7) cleared'
            (r'(.*?)(?:(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]{1,2})(?:\:[0-9a-zA-Z]{1,2})+(?:N/A)?\.?)', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Diag7: Over Voltage, Element A occurred for meter 03.34.0.400:13:50:02:00:0a:d7:98.'
        # 'Over Voltage (Diagnostic 7) occurred for meter 00:13:50:05:ff:41:8a:8f: Phase A.'
        # SEEMS RARE, BUT HAVE SEEN:
        # 'KV2c meter event Over Voltage Diagnostic flags:Phase A Voltage'
        # 'KV2c meter event Under Voltage Caution Diagnostic flags:Phase B Voltage'
        # 'KV2c meter event Received kWh Caution Diagnostic flags:Phase A Voltage '
        # 'KV2c meter event Received kWh Caution Cleared '
        '3.26.38.93':   [
            #-----
            (r'(KV2c meter event (?:(?:Over|Under) Voltage)|(?:Voltage Out of Tolerance)|(?:(?:Received|Delivered) kWh))(?:\s*Caution)?\s*(Diagnostic flags)\s*\:\s*(.*?)\s*$', r'\1 (\2 = \3)'), 
            #-----
            (r'(KV2c meter event (?:(?:Over|Under) Voltage)|(?:Voltage Out of Tolerance)|(?:(?:Received|Delivered) kWh))(?:\s*Caution)?\s*Cleared\s*$', r'\1 Cleared'), 
            #-----
            (r'(.*Over Voltage.*?)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+\.?)(.*?)\s*$', r'\1\2') 
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Under Voltage (CA000400) for meter 00:13:50:05:ff:0b:88:ec. Phase  C Voltage out of tolerance.'
        # 'Under Voltage (CA000400) occurred for meter 00:13:50:05:ff:15:e8:3b: Phase A.'
        # 'KV2c meter event Under Voltage Diagnostic flags:Phase A Voltage'
        # 'Diag6: Under Voltage, Element A occurred for meter 00:13:50:05:ff:0b:88:ec.'
        '3.26.38.150':   [
            #-----
            # NOTE: Due to annoying N/A at end of some MAC-esque IDs, I have to specify length of numerical entries
            #       as [0-9a-zA-Z]{1,2}, instead of the more general [0-9a-zA-Z]+ found elsewhere!
            # NOTE: Also, the use of non-greedy (.*?) at beginning.
            #       If (.*) were used instead, results would be, e.g.
            #          'Diag6: Under Voltage, Element A occurred for meter'
            #       instead of 
            #          'Diag6: Under Voltage, Element A'
            (r'(Under Voltage\s*(?:\(.*\))?)\s*(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\.\:]?)(\s?.*?)', r'\1\2'), 
            #-----
            (r'(Diag6.*?)(?:(?:\s*occurred\s*)?(?:\s*(?:for|on)?\s*(?:meter)?)?\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+[\.\:]?)(\s?.*?)', r'\1\2'), 
            #-----
            (r'(KV2c meter event .*?)\s*(Diagnostic flags)\s*\:\s*(.*?)\s*$', r'\1 (\2 = \3)')
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Last Gasp - NIC power lost for device: 00:13:50:05:ff:0b:83:e4, Reboot Count: 12264, NIC timestamp: 2020-01-19T22:21:02.000-05:00, Received timestamp: 2020-01-19T22:21:04.353-05:00, Fail Reason: [0x49] LG_ZERO_X_DETECTOR ,LG_DIRECT_NOTIFICATION'
        '3.26.136.47':  [
            #-----
            (r'(Last Gasp - NIC power lost for device):(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+).*(Fail Reason: .*)$', r'\1, \2')
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Device 00:13:50:05:ff:0b:8a:18, Last Gasp State: EL_EVENT_POWER_FAIL_DETECT_LG_DISABLED, Detector State: EL_EVENT_POWER_FAIL_DETECT_NIC_ZX_DISABLED, Reboot Count: 108'
        '3.26.136.66':  [
            #-----
            (r'Device(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+), (Last Gasp State: .*), (Detector State: .*), Reboot Count: \d*', r'\1, \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'NIC Power Restore Trap Received from device: 00:13:50:05:ff:0c:7e:93, Reboot Count: 61, NIC timestamp: 2020-01-27T09:19:56.000-05:00, Received Timestamp: 2020-01-27T09:19:57.204-05:00, Power Restoration Timestamp: 2020-01-27T09:19:42.000-05:00, State: 4,p'
        '3.26.136.216': [
            #-----
            (r'(NIC Power Restore Trap Received from device):(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter assumed to be disconnected has reported Load side voltage indicating a potential case of tamper.'
        '3.31.1.143':   [
            #-----
            (r'(Meter assumed to be disconnected has reported Load side voltage indicating a potential case of tamper).*', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter event Reverse Rotation Detected  Time event occurred on meter = 08/30/2021 04:25:38  Sequence number = 13124  User id = 0  Event argument = 00-00 '
        '3.33.1.219':   [
            #-----
            (r'(Meter event Reverse Rotation Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Reverse Rotation Detected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a Reverse Rotation).*', 'Meter event Reverse Rotation Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a Tamper Attempt.'
        # 'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 08:45:05  Sequence number = 72  User id = 0  Event argument = 00-00 '
        '3.33.1.257':   [
            #-----
            (r'(Meter event Tamper Attempt Suspected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Tamper Attempt Suspected).*', r'\1'), #Fail proof, in case time, sequence, etc., not found 
            #-----
            (r'(Meter detected a Tamper Attempt).*', 'Meter event Tamper Attempt Suspected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Cleared: Meter 00:13:50:05:ff:11:69:bb detected a high temperature condition. (C1219 Table 3)'
        '3.35.0.28': [
            #-----
            (r'(Cleared: Meter)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(detected a high temperature condition)\.\s*(.*)', r'\1 \2 \3') 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter 00:13:50:05:ff:11:69:bb detected a high temperature condition. (C1219 Table 3)'
        # 'Meter's temperature threshold exceeded.'
        # 'Meter event AX Temp Threshold Exceeded  Time event occurred on meter = 02/19/2021 13:33:50  Sequence number = 5115  User id = 0  Event argument = 00-00 '
        # 'Meter event S4TemperatureThreshold  Time event occurred on meter = 05/25/2023 17:12:50  Sequence number = 45  User id = 0  Event argument = 00-00-00-00-00-00 '
        '3.35.0.40': [
            #-----
            (r'(Meter)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(detected a high temperature condition)\.\s*(.*)', r'\1 \2 \3'), 
            #-----
            (r"(Meter's temperature threshold exceeded).", r'\1'), 
            #-----
            (r'(Meter event .*?)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event (?:AX Temp Threshold Exceeded|S4TemperatureThreshold)).*', r'\1'),
        ],  
        
        #-------------------------
        # Examples
        # 'Meter detected a clock error.'
        # 'Meter event Clock Error Detected  Time event occurred on meter = 04/18/2020 10:00:10  Sequence number = 332  User id = 0  Event argument = 00-00'
        '3.36.0.79': [
            #-----
            (r'(Meter event Clock Error Detected)\s*Time event occurred on meter\s*=.*\s*Sequence number\s*=.*\s*User id\s*=.*\s*Event argument\s*=.*', r'\1'), 
            #-----
            (r'(Meter event Clock Error Detected).*', r'\1'),
            #-----
            (r'(Meter detected a clock error).*', 'Meter event Clock Error Detected'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter detected a clock error.'
        '3.36.1.29': [
            #-----
            ('(Meter detected a clock error).', r'\1'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter 00:13:50:05:ff:2e:13:de, detected loss of time (C1219 Table 3)'
        '3.36.114.73':  [
            #-----
            (r'(Meter)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+),\s*(detected loss of time .*)', r'\1 \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Ignoring Interval Read data for device 00:13:50:05:ff:1e:fa:a4 as it has time in the future 2069-05-02 18:51:00.0'
        '3.36.114.159': [
            #-----
            (r'(Ignoring (?:Interval|Register) Read data for device)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(as it has time in the future).*', r'\1 \2'), 
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'Meter 00:13:50:05:ff:14:c9:61 needs explicit time sync. Drift: 14391 s, Encountered Problems:  TS_ERR_LP_BX, TS_ERR_BIG_DRIFT [0x44], Meter_Time: 06:33:41'
        '3.36.136.73':  [
            #-----
            (r'(Meter)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)\s*(needs explicit time sync.) Drift: -?\d* s, (Encountered Problems:\s*.*), Meter_Time.*', r'\1 \2 \3'), 
            #-----
        ], 
        
        #-------------------------
        # Examples
        # 'Error occurred when attempting to synch meter time with NIC time for device 00:13:50:05:ff:29:e1:20'
        # So, standard beg/end patterns should suffice
        '3.36.136.79':    [
            #-----
            (r'(Error occurred when attempting to synch meter time with NIC time for device)(?:\s+(?:[0-9a-zA-Z]+)(?:\:[0-9a-zA-Z]+)+)', r'\1')
            #-----
        ],         
        
        #-------------------------
        # Examples
        # 'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase B Voltage '
        # 'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase B Voltage, Phase C Voltage '
        '3.38.1.139':    [
            #-----
            (r'(KV2c meter event Polarity, Cross Phase, Reverse Energy Flow) Diagnostic flags:.*', r'\1'), 
            #-----
        ]
    }
    #-------------------------
    return patterns_to_replace_by_typeid

# %%
save_dir_base = r'C:\Users\s346557\Documents\LocalData\dovs_and_end_events_data\regex'
build_samples = False

# %%
# distinct_ids = AMIEndEvents.get_end_event_distinct_fields(
#     '2020-01-01', 
#     '2023-03-21', 
#     fields=['enddeviceeventtypeid']
# )
# distinct_ids.to_pickle(os.path.join(save_dir_base, 'distinct_ids.pkl'))
#-----
distinct_ids = pd.read_pickle(os.path.join(save_dir_base, 'distinct_ids.pkl'))
#-----
distinct_ids = natsorted(distinct_ids['enddeviceeventtypeid'].tolist())

# %%
distinct_ids
# Out:
# [None,
#  '3.2.0.28',
#  '3.2.0.85',
#  '3.2.22.28',
#  '3.2.22.150',
#  '3.7.19.242',
#  '3.7.19.243',
#  '3.7.22.4',
#  '3.7.22.19',
#  '3.8.0.215',
#  '3.9.83.159',
#  '3.11.63.161',
#  '3.12.0.257',
#  '3.12.17.257',
#  '3.12.48.28',
#  '3.12.48.219',
#  '3.12.93.28',
#  '3.12.93.219',
#  '3.12.136.38',
#  '3.12.136.85',
#  '3.18.1.199',
#  '3.18.1.220',
#  '3.18.72.28',
#  '3.18.72.79',
#  '3.18.72.85',
#  '3.18.85.28',
#  '3.18.85.79',
#  '3.18.85.85',
#  '3.18.92.28',
#  '3.18.92.79',
#  '3.18.92.85',
#  '3.21.1.79',
#  '3.21.1.173',
#  '3.21.3.28',
#  '3.21.3.79',
#  '3.21.17.28',
#  '3.21.18.79',
#  '3.21.38.223',
#  '3.21.38.248',
#  '3.21.43.223',
#  '3.21.43.248',
#  '3.21.67.28',
#  '3.21.67.79',
#  '3.21.82.28',
#  '3.21.82.79',
#  '3.22.12.243',
#  '3.22.19.242',
#  '3.23.17.139',
#  '3.23.136.47',
#  '3.23.136.85',
#  '3.25.17.3',
#  '3.26.0.47',
#  '3.26.0.216',
#  '3.26.17.185',
#  '3.26.17.216',
#  '3.26.38.37',
#  '3.26.38.47',
#  '3.26.38.73',
#  '3.26.38.93',
#  '3.26.38.150',
#  '3.26.136.47',
#  '3.26.136.66',
#  '3.26.136.216',
#  '3.31.1.143',
#  '3.33.1.219',
#  '3.33.1.257',
#  '3.35.0.28',
#  '3.35.0.40',
#  '3.36.0.79',
#  '3.36.1.29',
#  '3.36.114.73',
#  '3.36.114.159',
#  '3.36.136.73',
#  '3.36.136.79',
#  '3.38.1.139']

# %%
if build_samples:
    build_sample_dfs(
        distinct_ids=distinct_ids,
        save_dir=os.path.join(save_dir_base, 'sample_dfs'), 
        years = [2020, 2021, 2022, 2023], 
        limit_per_month=10000, 
        conn_db=Utilities.get_athena_prod_aws_connection()
    )

# %%
sample_df_paths = Utilities.find_all_paths(
    base_dir=os.path.join(save_dir_base, 'sample_dfs'), 
    glob_pattern=r'df_*.pkl'
)
#-----
ids_with_paths_dict = {}
for path_i in sample_df_paths:
    name_i = Path(path_i).name
    name_i = re.sub(r'df_(.*).pkl', r'\1', name_i)
    name_i = name_i.replace('_', '.')
    assert(name_i not in ids_with_paths_dict.keys())
    ids_with_paths_dict[name_i] = path_i

# %%
# natsorted(ids_with_paths_dict.keys())

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------

# %%
std_patterns_to_replace = get_std_patterns_to_replace_by_typeid_EXPLICIT()

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------

# %% [markdown]
# # '3.2.0.28'

# %%
df_3_2_0_28 = pd.read_pickle(ids_with_paths_dict['3.2.0.28'])
#-----
print(f"shape[0] = {df_3_2_0_28.shape[0]}")
print(f"# Unique reasons = {df_3_2_0_28['reason'].nunique()}")
print(df_3_2_0_28['reason'].unique())
# Out:
# shape[0] = 1
# # Unique reasons = 1
# ['Power Loss cleared for meter 00:13:50:05:ff:0d:dd:17']

# %%
curated_reasons = []
for reason_i in df_3_2_0_28['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.2.0.28']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Power Loss cleared

# %% [markdown]
# # '3.2.0.85'

# %%
df_3_2_0_85 = pd.read_pickle(ids_with_paths_dict['3.2.0.85'])
#-----
print(f"shape[0] = {df_3_2_0_85.shape[0]}")
print(f"# Unique reasons = {df_3_2_0_85['reason'].nunique()}")
print(df_3_2_0_85['reason'].unique())
# Out:
# shape[0] = 1
# # Unique reasons = 1
# ['Power loss detected on meter 00:13:50:05:ff:0d:dd:17']

# %%
curated_reasons = []
for reason_i in df_3_2_0_85['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.2.0.85']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Power loss detected

# %% [markdown]
# # '3.2.22.28'

# %%
df_3_2_22_28 = pd.read_pickle(ids_with_paths_dict['3.2.22.28'])
#-----
print(f"shape[0] = {df_3_2_22_28.shape[0]}")
print(f"# Unique reasons = {df_3_2_22_28['reason'].nunique()}")
print(df_3_2_22_28['reason'].unique())
# Out:
# shape[0] = 82
# # Unique reasons = 41
# ['Low Battery cleared for meter 00:13:50:02:00:0a:9e:1e.'
#  'Low Battery cleared for meter 00:13:50:02:00:0a:a2:c6.'
#  'Low Battery cleared for meter 00:13:50:05:ff:06:67:48.'
#  'Low Battery cleared for meter 00:13:50:05:ff:1b:6d:70.'
#  'Low Battery cleared for meter 00:13:50:05:ff:23:ad:78.'
#  'Low Battery cleared for meter 00:13:50:02:00:0a:a8:e3.'
#  'Low Battery cleared for meter 00:13:50:02:00:0a:a8:a6.'
#  'Low Battery cleared for meter 00:13:50:05:ff:1e:72:94.'
#  'Low Battery cleared for meter 00:13:50:05:ff:1f:f9:bf.'
#  'Low Battery cleared for meter 00:13:50:02:00:0a:bd:72.'
#  'Low Battery cleared for meter 00:13:50:01:01:60:ed:1e.'
#  'Low Battery cleared for meter 00:13:50:02:00:0b:36:e4.'
#  'Low Battery cleared for meter 00:13:50:ff:fe:03:4f:11.'
#  'Low Battery cleared for meter 00:13:50:01:01:60:f0:f1.'
#  'Low Battery cleared for meter 00:13:50:05:ff:1a:7f:93.'
#  'Low Battery cleared for meter 00:13:50:05:ff:0b:98:cb.'
#  'Low Battery cleared for meter 00:13:50:05:ff:2e:2b:b2.'
#  'Low Battery cleared for meter 00:13:50:05:ff:1f:fd:1f.'
#  'Low Battery cleared for meter 00:13:50:01:01:7a:fd:18.'
#  'Low Battery cleared for meter 00:13:50:02:00:0b:26:3f.'
#  'Low Battery cleared for meter 00:13:50:01:01:5a:59:20.'
#  'Low Battery cleared for meter 00:13:50:05:ff:0b:98:7c.'
#  'Low Battery cleared for meter 00:13:50:05:ff:1f:fc:66.'
#  'Low Battery cleared for meter 00:13:50:01:01:7a:fc:6f.'
#  'Low Battery cleared for meter 00:13:50:01:01:7a:f9:68.'
#  'Low Battery cleared for meter 00:13:50:02:00:0a:a4:d5.'
#  'Low Battery cleared for meter 00:13:50:05:ff:0d:dd:17.'
#  'Low Battery cleared for meter 00:13:50:01:01:45:ef:44.'
#  'Low Battery cleared for meter 00:13:50:ff:fe:03:4d:10.'
#  'Low Battery cleared for meter 00:13:50:ff:fe:03:4e:d9.'
#  'Low Battery cleared for meter 00:13:50:01:01:60:ef:0a.'
#  'Low Battery cleared for meter 00:13:50:01:01:78:fd:f1.'
#  'Low Battery cleared for meter 00:13:50:01:01:7a:fe:34.'
#  'Low Battery cleared for meter 00:13:50:01:01:78:fd:7d.'
#  'Low Battery cleared for meter 00:13:50:01:01:7a:fe:2a.'
#  'Low Battery cleared for meter 00:13:50:ff:fe:03:4f:23.'
#  'Low Battery cleared for meter 00:13:50:05:ff:19:3f:25.'
#  'Low Battery cleared for meter 00:13:50:03:ff:02:23:c5.'
#  'Low Battery cleared for meter 00:13:50:03:ff:06:d4:35.'
#  'Low Battery cleared for meter 00:13:50:05:ff:36:7c:f8.'
#  'Low Battery cleared for meter 00:13:50:02:00:0a:9a:dd.']

# %%
curated_reasons = []
for reason_i in df_3_2_22_28['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.2.22.28']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Low Battery cleared

# %% [markdown]
# # '3.2.22.150'

# %%
df_3_2_22_150 = pd.read_pickle(ids_with_paths_dict['3.2.22.150'])
#-----
print(f"shape[0] = {df_3_2_22_150.shape[0]}")
print(f"# Unique reasons = {df_3_2_22_150['reason'].nunique()}")
print(df_3_2_22_150['reason'].unique())
# Out:
# shape[0] = 92
# # Unique reasons = 48
# ['Low Battery (C1219 Table 3) occurred for meter 00:13:50:02:00:0a:9e:1e.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:02:72:01.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:02:00:0a:a2:c6.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:06:67:48.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:1b:6d:70.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:02:00:0a:a8:e3.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:02:00:0a:a8:a6.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:01:01:5a:59:20.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:01:01:60:ed:1e.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:1f:f9:bf.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:1e:61:86.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:02:00:0a:bd:72.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:02:00:0b:36:e4.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:01:01:60:f0:f1.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:ff:fe:03:4f:11.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:0b:98:cb.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:01:01:5a:58:3f.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:2e:2b:b2.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:0e:ff:e6.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:1f:fd:1f.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:01:01:7a:fd:18.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:01:01:60:ef:0e.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:1f:fc:66.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:01:01:38:20:88.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:02:00:0b:26:3f.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:01:01:7a:f9:68.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:01:01:7a:fe:34.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:0b:98:7c.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:01:01:7a:fc:6f.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:02:00:0a:a4:d5.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:0d:dd:17.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:03:ff:06:26:57.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:01:01:78:fd:7d.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:03:ff:02:27:4d.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:03:ff:02:26:ec.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:39:21:e3.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:ff:fe:03:4f:bc.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:01:01:78:fd:f1.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:01:01:7a:fe:2a.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:02:00:0b:3b:82.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:ff:fe:03:4e:d9.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:ff:fe:03:4d:10.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:36:7c:f8.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:01:01:60:ef:0a.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:ff:fe:03:4f:23.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:2b:47:c4.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:02:00:0a:9a:dd.'
#  'Low Battery (C1219 Table 3) occurred for meter 00:13:50:05:ff:38:2f:3b.']

# %%
curated_reasons = []
for reason_i in df_3_2_22_150['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.2.22.150']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Low Battery (C1219 Table 3)

# %% [markdown]
# # '3.7.19.242'

# %%
df_3_7_19_242 = pd.read_pickle(ids_with_paths_dict['3.7.19.242'])
#-----
print(f"shape[0] = {df_3_7_19_242.shape[0]}")
print(f"# Unique reasons = {df_3_7_19_242['reason'].nunique()}")
print(df_3_7_19_242['reason'].unique())
# Out:
# shape[0] = 1449426
# # Unique reasons = 10010
# ['Meter event Test Mode Started  Time event occurred on meter = 01/03/2020 10:52:59  Sequence number = 10  User id = 1  Event argument = 00-00'
#  'Meter event Test Mode Started  Time event occurred on meter = 01/03/2020 19:38:56  Sequence number = 119  User id = 1  Event argument = 00-00'
#  'Meter event Test Mode Started  Time event occurred on meter = 01/03/2020 16:43:05  Sequence number = 3025  User id = 1  Event argument = 00-00'
#  ... 'Test Mode Started occurred for meter 00:13:50:05:ff:02:6e:cc.'
#  'Test Mode Started occurred for meter 00:13:50:05:ff:02:88:29.'
#  'Test Mode Started occurred for meter 00:13:50:03:ff:06:d1:d5.']

# %%
curated_reasons = []
for reason_i in df_3_7_19_242['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.7.19.242']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter is currently in test mode
# Test Mode Started
# Meter event Test Mode Started

# %% [markdown]
# # '3.7.19.243'

# %%
df_3_7_19_243 = pd.read_pickle(ids_with_paths_dict['3.7.19.243'])
#-----
print(f"shape[0] = {df_3_7_19_243.shape[0]}")
print(f"# Unique reasons = {df_3_7_19_243['reason'].nunique()}")
print(df_3_7_19_243['reason'].unique())
# Out:
# shape[0] = 1447615
# # Unique reasons = 8809
# ['Meter event Test Mode Stopped  Time event occurred on meter = 01/20/2020 14:05:56  Sequence number = 61  User id = 1  Event argument = 00-00'
#  'Meter event Test Mode Stopped  Time event occurred on meter = 01/30/2020 13:56:48  Sequence number = 148  User id = 1  Event argument = 00-00'
#  'Meter event Test Mode Stopped  Time event occurred on meter = 01/04/2020 16:45:31  Sequence number = 3043  User id = 1  Event argument = 00-00'
#  ... 'Test Mode Stopped occurred for meter 00:13:50:03:ff:06:3f:51.'
#  'Test Mode Stopped occurred for meter 00:13:50:03:ff:04:65:d8.'
#  'Test Mode Stopped occurred for meter 00:13:50:03:ff:06:70:47.']

# %%
curated_reasons = []
for reason_i in df_3_7_19_243['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.7.19.243']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter event Test Mode Stopped
# Test Mode Stopped

# %% [markdown]
# # '3.7.22.4'

# %%
df_3_7_22_4 = pd.read_pickle(ids_with_paths_dict['3.7.22.4'])
#-----
print(f"shape[0] = {df_3_7_22_4.shape[0]}")
print(f"# Unique reasons = {df_3_7_22_4['reason'].nunique()}")
print(df_3_7_22_4['reason'].unique())
# Out:
# shape[0] = 15881
# # Unique reasons = 15869
# ['NIC operating on backup battery: 00:13:50:ff:fe:70:96:b7, Reboot Count: 6, NIC timestamp: 2021-01-09T23:51:00.000-05:00, Received timestamp: 2021-01-09T23:51:01.816-05:00'
#  'NIC operating on backup battery: 00:13:50:ff:fe:70:96:63, Reboot Count: 8, NIC timestamp: 2021-01-09T08:10:15.000-05:00, Received timestamp: 2021-01-09T08:10:17.475-05:00'
#  'NIC operating on backup battery: 00:13:50:ff:fe:70:96:ac, Reboot Count: 6, NIC timestamp: 2021-01-14T10:17:54.000-05:00, Received timestamp: 2021-01-14T10:17:55.728-05:00'
#  ...
#  'NIC operating on backup battery: 00:13:50:ff:fe:12:1a:0e, Reboot Count: 25, NIC timestamp: 2023-03-02T18:42:55.000-06:00, Received timestamp: 2023-03-02T18:42:56.419-06:00'
#  'NIC operating on backup battery: 00:13:50:ff:fe:12:1a:0e, Reboot Count: 25, NIC timestamp: 2023-03-01T06:41:24.000-06:00, Received timestamp: 2023-03-01T06:41:26.031-06:00'
#  'NIC operating on backup battery: 00:13:50:ff:fe:12:1a:0e, Reboot Count: 25, NIC timestamp: 2023-03-01T20:41:38.000-06:00, Received timestamp: 2023-03-01T20:41:40.005-06:00']

# %%
curated_reasons = []
for reason_i in df_3_7_22_4['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.7.22.4']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# NIC operating on backup battery

# %% [markdown]
# # '3.7.22.19'

# %%
df_3_7_22_19 = pd.read_pickle(ids_with_paths_dict['3.7.22.19'])
#-----
print(f"shape[0] = {df_3_7_22_19.shape[0]}")
print(f"# Unique reasons = {df_3_7_22_19['reason'].nunique()}")
print(df_3_7_22_19['reason'].unique())
# Out:
# shape[0] = 59047
# # Unique reasons = 1
# ['NIC backup battery inactive']

# %%
curated_reasons = []
for reason_i in df_3_7_22_19['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.7.22.19']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# NIC backup battery inactive

# %% [markdown]
# # '3.8.0.215'

# %%
df_3_8_0_215 = pd.read_pickle(ids_with_paths_dict['3.8.0.215'])
#-----
print(f"shape[0] = {df_3_8_0_215.shape[0]}")
print(f"# Unique reasons = {df_3_8_0_215['reason'].nunique()}")
print(df_3_8_0_215['reason'].unique())
# Out:
# shape[0] = 2700000
# # Unique reasons = 262388
# ['Demand Reset occurred for meter 00:13:50:01:00:0d:a3:2d.'
#  'Demand Reset occurred for meter 00:13:50:01:00:b7:b3:77.'
#  'Demand Reset occurred for meter 00:13:50:02:00:97:f3:d0.' ...
#  'Demand Reset occurred for meter 00:13:50:05:ff:3a:6d:8e.'
#  'Demand Reset occurred for meter 00:13:50:05:ff:3a:6d:7b.'
#  'Demand Reset occurred for meter 00:13:50:05:ff:4b:7b:98.']

# %%
curated_reasons = []
for reason_i in df_3_8_0_215['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.8.0.215']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Demand Reset

# %% [markdown]
# # '3.9.83.159'

# %%
df_3_9_83_159 = pd.read_pickle(ids_with_paths_dict['3.9.83.159'])
#-----
print(f"shape[0] = {df_3_9_83_159.shape[0]}")
print(f"# Unique reasons = {df_3_9_83_159['reason'].nunique()}")
print(df_3_9_83_159['reason'].unique())
# Out:
# shape[0] = 27497
# # Unique reasons = 27007
# ['Meter Program Seal mismatch for Device [Device ID, MAC Id] = [V9D585888649PMNA1, 00:13:50:05:ff:26:2f:5f] - program seal = 6a622d2cb1b04fb4b869b90103eac1842a0e2169 vs. UIQ program seal = 7298b94285241f59f4bc491277f5a0df61365ac7 at 2021-01-16T13:36:22.904-05:00.'
#  'Meter Program Seal mismatch for Device [Device ID, MAC Id] = [V9D585888649PMNA1, 00:13:50:05:ff:26:2f:5f] - program seal = 6a622d2cb1b04fb4b869b90103eac1842a0e2169 vs. UIQ program seal = 7298b94285241f59f4bc491277f5a0df61365ac7 at 2021-01-16T13:36:03.750-05:00.'
#  'Meter Program Seal mismatch for Device [Device ID, MAC Id] = [1ND785901154NMD06, 00:13:50:05:ff:25:52:90] - program seal = d503282c96d067dab2104cb4742107161c4c69b1 vs. UIQ program seal = 05e157fd3041d59efceb489a9aba694ecf23f259 at 2021-01-13T16:14:19.468-05:00.'
#  ...
#  'Meter Program Seal mismatch for Device [Device ID, MAC Id] = [3KD784133129NM008, 00:13:50:05:ff:20:ea:e9] - program seal = eda212e784aaa25b1f0a76705f1d621641d7b8c8 vs. UIQ program seal = 590e32d3bf848b4090f2ce3df8001a2cc81a628d at 2023-03-03T16:06:28.585-05:00.'
#  'Meter Program Seal mismatch for Device [Device ID, MAC Id] = [1ND998993505NMD06, 00:13:50:05:ff:4b:dd:63] - program seal = 4b9520e1e38867cc1932ed210a5c84eeb2478ecf vs. UIQ program seal = a27b544ef07b912a80ad921d7ca2aa3a3ea183e7 at 2023-03-03T18:15:05.792-05:00.'
#  'Meter Program Seal mismatch for Device [Device ID, MAC Id] = [1ND998757910NMD06, 00:13:50:05:ff:48:87:81] - program seal = a27b544ef07b912a80ad921d7ca2aa3a3ea183e7 vs. UIQ program seal = 4b9520e1e38867cc1932ed210a5c84eeb2478ecf at 2023-03-03T09:40:46.952-05:00.']

# %%
curated_reasons = []
for reason_i in df_3_9_83_159['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.9.83.159']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter Program Seal mismatch for Device

# %% [markdown]
# # '3.11.63.161'

# %%
df_3_11_63_161 = pd.read_pickle(ids_with_paths_dict['3.11.63.161'])
#-----
print(f"shape[0] = {df_3_11_63_161.shape[0]}")
print(f"# Unique reasons = {df_3_11_63_161['reason'].nunique()}")
print(df_3_11_63_161['reason'].unique())
# Out:
# shape[0] = 72980
# # Unique reasons = 62937
# ['Requested operation JOB_OP_TYPE_ARB_METER_COMMAND could not be applied to the given device type and firmware version. Device: 00:13:50:05:ff:2d:e0:5f, DeviceType: DID_SUBTYPE_I210CRD_HAN, Firmware Version: 3.12.5c'
#  'Requested operation JOB_OP_TYPE_ARB_METER_COMMAND could not be applied to the given device type and firmware version. Device: 00:13:50:05:ff:2d:e3:b7, DeviceType: DID_SUBTYPE_I210CRD_HAN, Firmware Version: 3.12.5c'
#  'Requested operation JOB_OP_TYPE_ARB_METER_COMMAND could not be applied to the given device type and firmware version. Device: 00:13:50:05:ff:2e:28:ab, DeviceType: DID_SUBTYPE_I210CRD_HAN, Firmware Version: 3.12.5c'
#  ...
#  'Requested operation JOB_OP_NEW_DATA_READ could not be applied to the given device type and firmware version. Device: 00:13:50:05:ff:3e:15:38, DeviceType: DID_SUBTYPE_I210CRD_HAN, Firmware Version: 3.12.5c'
#  'Requested operation JOB_OP_PROVISION_GET_STATUS could not be applied to the given device type and firmware version. Device: 00:13:50:05:ff:22:97:a6, DeviceType: DID_SUBTYPE_I210C_HAN, Firmware Version: 3.12.3c'
#  'Requested operation JOB_OP_NEW_DATA_READ could not be applied to the given device type and firmware version. Device: 00:13:50:05:ff:3d:fd:6b, DeviceType: DID_SUBTYPE_I210CRD_HAN, Firmware Version: 3.12.5c']

# %%
curated_reasons = []
for reason_i in df_3_11_63_161['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.11.63.161']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Requested operation could not be applied: JOB_OP_TYPE_DEMAND_RESET
# Requested operation could not be applied: JOB_OP_TYPE_ARB_METER_COMMAND
# Requested operation could not be applied: JOB_OP_PROVISION_CONNECT
# Requested operation could not be applied: JOB_OP_LP_READ
# Requested operation could not be applied: JOB_OP_NEW_DATA_READ
# Requested operation could not be applied: JOB_OP_REGISTER_SELF_READ
# Requested operation could not be applied: JOB_OP_REGISTER_CURR_READ
# Requested operation could not be applied: JOB_OP_TYPE_DEV_PROG_READ
# Requested operation could not be applied: JOB_OP_PROVISION_GET_STATUS
# Requested operation could not be applied: JOB_OP_PROVISION_DISCONNECT
# Requested operation could not be applied: JOB_OP_NIC_NEW_DATA_READ

# %% [markdown]
# # '3.12.0.257'

# %%
df_3_12_0_257_1 = pd.read_pickle(ids_with_paths_dict['3.12.0.257'])
df_3_12_0_257_2 = pd.read_pickle(r'C:\Users\s346557\Documents\LocalData\dovs_and_end_events_data\regex_TX\sample_dfs\df_3_12_0_257.pkl')
df_3_12_0_257 = pd.concat([df_3_12_0_257_1, df_3_12_0_257_2])
#-----
print(f"shape[0] = {df_3_12_0_257.shape[0]}")
print(f"# Unique reasons = {df_3_12_0_257['reason'].nunique()}")
print(df_3_12_0_257['reason'].unique())
# Out:
# shape[0] = 1021729
# # Unique reasons = 36463
# ['Meter event Tamper Attempt Suspected  Time event occurred on meter = 01/20/2020 10:11:26  Sequence number = 152  User id = 0  Event argument = 00-00'
#  'Meter detected a Tamper Attempt.'
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 01/20/2020 12:24:49  Sequence number = 158  User id = 0  Event argument = 00-00'
#  ...
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 05/03/2023 16:09:59  Sequence number = 161  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 05/03/2023 16:42:02  Sequence number = 549  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 05/03/2023 17:19:37  Sequence number = 7275  User id = 0  Event argument = 00-00 ']

# %%
curated_reasons = []
for reason_i in df_3_12_0_257['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.12.0.257']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter detected a Tamper Attempt
# Meter event Tamper Attempt Suspected

# %% [markdown]
# # '3.12.17.257'

# %%
df_3_12_17_257 = pd.read_pickle(ids_with_paths_dict['3.12.17.257'])
#-----
print(f"shape[0] = {df_3_12_17_257.shape[0]}")
print(f"# Unique reasons = {df_3_12_17_257['reason'].nunique()}")
print(df_3_12_17_257['reason'].unique())
# Out:
# shape[0] = 19389
# # Unique reasons = 7183
# ['Tamper (Meter Inversion) detected on meter 00:13:50:05:ff:10:96:90.'
#  'Tamper (Meter Inversion) detected on meter 00:13:50:05:ff:18:cb:30.'
#  'Tamper (Meter Inversion) detected on meter 00:13:50:05:ff:0e:a4:8f.' ...
#  'Tamper (Meter Inversion) detected on meter 00:13:50:05:ff:4e:40:56.'
#  'Tamper (Meter Inversion) detected on meter 00:13:50:05:ff:22:02:d7.'
#  'Tamper (Meter Inversion) detected on meter 00:13:50:05:ff:3c:9d:69.']

# %%
curated_reasons = []
for reason_i in df_3_12_17_257['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.12.17.257']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Tamper (Meter Inversion) detected

# %% [markdown]
# # '3.12.48.28'

# %%
df_3_12_48_28 = pd.read_pickle(ids_with_paths_dict['3.12.48.28'])
#-----
print(f"shape[0] = {df_3_12_48_28.shape[0]}")
print(f"# Unique reasons = {df_3_12_48_28['reason'].nunique()}")
print(df_3_12_48_28['reason'].unique())
# Out:
# shape[0] = 2432609
# # Unique reasons = 20338
# ['Diag1 Condition cleared for meter 00:13:50:05:ff:04:55:a1.'
#  'Diag1 Condition cleared for meter 00:13:50:05:ff:1b:3f:03.'
#  'Diag1 Condition cleared for meter 00:13:50:05:ff:0f:74:ac.' ...
#  'Diag1 Condition cleared for meter 00:13:50:05:ff:0b:83:22.'
#  'Diag1 Condition cleared for meter 00:13:50:05:ff:24:a1:85.'
#  'Diag1 Condition cleared for meter 00:13:50:05:ff:2c:ee:e8.']

# %%
curated_reasons = []
for reason_i in df_3_12_48_28['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.12.48.28']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Reverse energy cleared
# Diag1 Condition cleared

# %% [markdown]
# # '3.12.48.219'

# %%
df_3_12_48_219 = pd.read_pickle(ids_with_paths_dict['3.12.48.219'])
#-----
print(f"shape[0] = {df_3_12_48_219.shape[0]}")
print(f"# Unique reasons = {df_3_12_48_219['reason'].nunique()}")
print(df_3_12_48_219['reason'].unique())
# Out:
# shape[0] = 2459882
# # Unique reasons = 27622
# ['KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase C Voltage'
#  'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase A Current'
#  'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase B Voltage, Phase C Voltage'
#  ...
#  'Diag1: Polarity, Cross Phase, Reverse Energy Flow occurred for meter 00:13:50:05:ff:2c:f6:ef. Angle out of tolerance [Voltage - Phase  C].'
#  'Diag1: Polarity, Cross Phase, Reverse Energy Flow occurred for meter 00:13:50:05:ff:24:a6:88. Angle out of tolerance [Voltage - Phase  C].'
#  'Diag1: Polarity, Cross Phase, Reverse Energy Flow occurred for meter 00:13:50:05:ff:34:8d:e9. Angle out of tolerance [Voltage - Phase  B][Current - Phase  B].']

# %%
curated_reasons = []
for reason_i in df_3_12_48_219['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.12.48.219']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Service disconnect operation occurred with status: Open succeeded
# Service disconnect operation occurred with status: Close succeeded
# Service disconnect operation occurred with status: Open started
# Service disconnect operation occurred with status: Close started
# Diag1: Polarity, Cross Phase, Reverse Energy Flow: Angle out of tolerance.
# Reverse energy (C1219 Table 3)
# Service disconnect operation occurred with status: Close started
# KV2c meter event Polarity, Cross Phase, Reverse Energy Flow

# %% [markdown]
# # '3.12.93.28'

# %%
df_3_12_93_28 = pd.read_pickle(ids_with_paths_dict['3.12.93.28'])
#-----
print(f"shape[0] = {df_3_12_93_28.shape[0]}")
print(f"# Unique reasons = {df_3_12_93_28['reason'].nunique()}")
print(df_3_12_93_28['reason'].unique())
# Out:
# shape[0] = 3436
# # Unique reasons = 3172
# ['Cleared: Meter00:13:50:05:ff:12:b4:8d, cleared tamper detection (C1219 Table 3)'
#  'Cleared: Meter00:13:50:05:ff:13:63:20, cleared tamper detection (C1219 Table 3)'
#  'Cleared: Meter00:13:50:05:ff:07:88:4b, cleared tamper detection (C1219 Table 3)'
#  ...
#  'Cleared: Meter00:13:50:05:ff:09:33:03, cleared tamper detection (C1219 Table 3)'
#  'Cleared: Meter00:13:50:03:ff:01:ba:28, cleared tamper detection (C1219 Table 3)'
#  'Cleared: Meter00:13:50:03:ff:03:58:7f, cleared tamper detection (C1219 Table 3)']

# %%
curated_reasons = []
for reason_i in df_3_12_93_28['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.12.93.28']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Cleared: Meter cleared tamper detection (C1219 Table 3)

# %% [markdown]
# # '3.12.93.219'

# %%
df_3_12_93_219 = pd.read_pickle(ids_with_paths_dict['3.12.93.219'])
#-----
print(f"shape[0] = {df_3_12_93_219.shape[0]}")
print(f"# Unique reasons = {df_3_12_93_219['reason'].nunique()}")
print(df_3_12_93_219['reason'].unique())
# Out:
# shape[0] = 3900000
# # Unique reasons = 426463
# ['Meter event Reverse Rotation Detected  Time event occurred on meter = 01/31/2020 15:58:24  Sequence number = 16908  User id = 0  Event argument = 00-00'
#  'Meter detected a Reverse Rotation.'
#  'Meter event Reverse Rotation Detected  Time event occurred on meter = 01/31/2020 12:55:31  Sequence number = 36052  User id = 0  Event argument = 00-00'
#  ...
#  'Meter event Reverse Rotation Detected  Time event occurred on meter = 03/09/2023 09:23:03  Sequence number = 1965  User id = 0  Event argument = 00-00 '
#  'Meter event Reverse Rotation Detected  Time event occurred on meter = 03/09/2023 09:24:39  Sequence number = 3636  User id = 0  Event argument = 00-00 '
#  'Meter event Reverse Rotation Detected  Time event occurred on meter = 03/09/2023 10:06:33  Sequence number = 596  User id = 0  Event argument = 00-00 ']

# %%
curated_reasons = []
for reason_i in df_3_12_93_219['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.12.93.219']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter detected tampering (C1219 Table 3)
# Meter event Reverse Rotation Detected
# Meter event Demand Reset Occurred

# %% [markdown]
# # '3.12.136.38'

# %%
df_3_12_136_38 = pd.read_pickle(ids_with_paths_dict['3.12.136.38'])
#-----
print(f"shape[0] = {df_3_12_136_38.shape[0]}")
print(f"# Unique reasons = {df_3_12_136_38['reason'].nunique()}")
print(df_3_12_136_38['reason'].unique())
# Out:
# shape[0] = 85383
# # Unique reasons = 58
# ['A NET_MGMT command was sent from fdc9:ccbe:52c0:cbc0:a6ba:99ff:fe12:1b0e with a key that has insufficient privileges to execute it. ID: 207 WRITE SUBID: 65535 ASSOC_ID: 768'
#  'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbc0:250:56ff:feb5:91c7 with a key that has insufficient privileges to execute it. ID: 53 READ SUBID: 65535 ASSOC_ID: 8448'
#  'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbc0:a6ba:99ff:fe12:1b0e with a key that has insufficient privileges to execute it. ID: 208 WRITE SUBID: 65535 ASSOC_ID: 768'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:250:56ff:feb5:2d1f with a key that has insufficient privileges to execute it. ID: 53 READ SUBID: 65535 ASSOC_ID: 8448'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 312 WRITE SUBID: 65535 ASSOC_ID: 768'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 208 WRITE SUBID: 65535 ASSOC_ID: 768'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 444 WRITE SUBID: 65535 ASSOC_ID: 768'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 287 WRITE SUBID: 65535 ASSOC_ID: 768'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 286 WRITE SUBID: 65535 ASSOC_ID: 768'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 207 WRITE SUBID: 65535 ASSOC_ID: 768'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 458 WRITE SUBID: 65535 ASSOC_ID: 768'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 327 WRITE SUBID: 65535 ASSOC_ID: 8960'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 312 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 207 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 287 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 286 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:250:56ff:feb5:70e4 with a key that has insufficient privileges to execute it. ID: 389 READ SUBID: 65535 ASSOC_ID: 256'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:59:1c80 with a key that has insufficient privileges to execute it. ID: 317 WRITE SUBID: 65535 ASSOC_ID: 768'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:59:1c80 with a key that has insufficient privileges to execute it. ID: 14 WRITE SUBID: 65535 ASSOC_ID: 768'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:250:56ff:feb5:2d1f with a key that has insufficient privileges to execute it. ID: 53 READ SUBID: 65535 ASSOC_ID: 8448 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 208 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 444 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 458 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbc0:250:56ff:feb5:91c7 with a key that has insufficient privileges to execute it. ID: 53 READ SUBID: 65535 ASSOC_ID: 8448 N/A'
#  'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbc0:a6ba:99ff:fe12:1b0e with a key that has insufficient privileges to execute it. ID: 207 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbc0:a6ba:99ff:fe12:1b0e with a key that has insufficient privileges to execute it. ID: 208 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5002:b:8a8e with a key that has insufficient privileges to execute it. ID: 375 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbc0:a6ba:99ff:fe12:1b0e with a key that has insufficient privileges to execute it. ID: 518 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbe0:a6ba:2bff:fe72:1c0a with a key that has insufficient privileges to execute it. ID: 207 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 484 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:226:55ff:fe2b:fd3e with a key that has insufficient privileges to execute it. ID: 518 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:250:56ff:feb5:2d1f with a key that has insufficient privileges to execute it. ID: 14 READ SUBID: 65535 ASSOC_ID: 256 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:250:56ff:feb5:2d1f with a key that has insufficient privileges to execute it. ID: 44 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5003:3d:ea64 with a key that has insufficient privileges to execute it. ID: 16 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c with a key that has insufficient privileges to execute it. ID: 46 WRITE SUBID: 1 ASSOC_ID: 52894 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:250:56ff:feb5:2d1f with a key that has insufficient privileges to execute it. ID: 389 READ SUBID: 65535 ASSOC_ID: 7317 N/A'
#  'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbe0:a6ba:2bff:fe72:1c0a with a key that has insufficient privileges to execute it. ID: 208 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:8b:f26 with a key that has insufficient privileges to execute it. ID: 120 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:250:56ff:feb5:1010 with a key that has insufficient privileges to execute it. ID: 46 WRITE SUBID: 1 ASSOC_ID: 27367 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:14e:a450 with a key that has insufficient privileges to execute it. ID: 46 READ SUBID: 65535 ASSOC_ID: 256 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:14e:a450 with a key that has insufficient privileges to execute it. ID: 259 READ SUBID: 65535 ASSOC_ID: 256 N/A'
#  'A NET_MGMT command was sent from 0:0:0:0:0:0:0:0 with a key that has insufficient privileges to execute it. ID: 389 WRITE SUBID: 38769 ASSOC_ID: 1542 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:59:1d98 with a key that has insufficient privileges to execute it. ID: 120 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:250:56ff:feb5:2d1f with a key that has insufficient privileges to execute it. ID: 38 WRITE SUBID: 65535 ASSOC_ID: 45182 N/A'
#  'A NET_MGMT command was sent from fd37:ec90:20c2:5c58:250:56ff:feb5:1010 with a key that has insufficient privileges to execute it. ID: 46 READ SUBID: 65535 ASSOC_ID: 20036 N/A'
#  'A NET_MGMT command was sent from fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c with a key that has insufficient privileges to execute it. ID: 14 READ SUBID: 1164 ASSOC_ID: 27412 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:be:c721 with a key that has insufficient privileges to execute it. ID: 756 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:be:c721 with a key that has insufficient privileges to execute it. ID: 46 READ SUBID: 65535 ASSOC_ID: 256 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:be:c721 with a key that has insufficient privileges to execute it. ID: 259 READ SUBID: 65535 ASSOC_ID: 256 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:14e:a3b8 with a key that has insufficient privileges to execute it. ID: 762 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:59:1cbb with a key that has insufficient privileges to execute it. ID: 30 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:14e:a3bd with a key that has insufficient privileges to execute it. ID: 762 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:4c:690c with a key that has insufficient privileges to execute it. ID: 14 READ SUBID: 65535 ASSOC_ID: 256 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:4c:690c with a key that has insufficient privileges to execute it. ID: 374 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbe0:a6ba:2bff:fe72:1c0a with a key that has insufficient privileges to execute it. ID: 518 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fe80:0:0:0:213:5005:8b:f26 with a key that has insufficient privileges to execute it. ID: 16 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbc0:250:56ff:feb5:d8f with a key that has insufficient privileges to execute it. ID: 44 WRITE SUBID: 65535 ASSOC_ID: 768 N/A'
#  'A NET_MGMT command was sent from fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32 with a key that has insufficient privileges to execute it. ID: 14 READ SUBID: 1164 ASSOC_ID: 61704 N/A']

# %%
curated_reasons = []
for reason_i in df_3_12_136_38['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.12.136.38']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# NET_MGMT command was sent with a key that has insufficient privileges: WRITE SUBID: 65535 ASSOC_ID: 8960
# NET_MGMT command was sent with a key that has insufficient privileges: WRITE SUBID: 1 ASSOC_ID: 52894
# NET_MGMT command was sent with a key that has insufficient privileges: WRITE SUBID: 1 ASSOC_ID: 27367
# NET_MGMT command was sent with a key that has insufficient privileges: READ SUBID: 65535 ASSOC_ID: 256
# NET_MGMT command was sent with a key that has insufficient privileges: READ SUBID: 65535 ASSOC_ID: 20036
# NET_MGMT command was sent with a key that has insufficient privileges: WRITE SUBID: 65535 ASSOC_ID: 768
# NET_MGMT command was sent with a key that has insufficient privileges: WRITE SUBID: 38769 ASSOC_ID: 1542
# NET_MGMT command was sent with a key that has insufficient privileges: READ SUBID: 65535 ASSOC_ID: 8448
# NET_MGMT command was sent with a key that has insufficient privileges: READ SUBID: 1164 ASSOC_ID: 27412
# NET_MGMT command was sent with a key that has insufficient privileges: READ SUBID: 1164 ASSOC_ID: 61704
# NET_MGMT command was sent with a key that has insufficient privileges: WRITE SUBID: 65535 ASSOC_ID: 45182
# NET_MGMT command was sent with a key that has insufficient privileges: READ SUBID: 65535 ASSOC_ID: 7317

# %% [markdown]
# # '3.12.136.85'

# %%
df_3_12_136_85 = pd.read_pickle(ids_with_paths_dict['3.12.136.85'])
#-----
print(f"shape[0] = {df_3_12_136_85.shape[0]}")
print(f"# Unique reasons = {df_3_12_136_85['reason'].nunique()}")
print(df_3_12_136_85['reason'].unique())
# Out:
# shape[0] = 2700000
# # Unique reasons = 105
# ['NET_MGMT command failed consecutively for 1 times for fd37:ec90:20c2:5c58:250:56ff:feb5:1010. WRITE'
#  'NET_MGMT command failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. WRITE'
#  'failed consecutively for 1 times for 0:0:0:0:0:0:0:0.'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 58753'
#  'NET_MGMT command failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. WRITE'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 40991'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 26035'
#  'NET_MGMT command failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ad6b. WRITE'
#  'Secure association operation failed consecutively for 1 times for fd37:ec90:20c2:5c58:250:56ff:feb5:1010. 57781'
#  'Certificate "insert" operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. SHA1:0000000000000000000000000000000000000000'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 44691'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 13181'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 37236'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 53167'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 6746'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 19737'
#  'NET_MGMT command failed consecutively for 1 times for fd37:ec90:20c2:5c58:250:56ff:feb5:2d1f. WRITE'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 57107'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 54660'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 31275'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 57320'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 2969'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 9292'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 14097'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 19592'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 28292'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 57312'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 54938'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 34052'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 32682'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 37809'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 35960'
#  'Secure association operation failed consecutively for 1 times for fd37:ec90:20c2:5c58:250:56ff:feb5:1010. 47588'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 26334'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 28642'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 32717'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 39170'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 2487'
#  'Certificate "insert" operation failed consecutively for 1 times for fd37:ec90:20c2:5c58:250:56ff:feb5:2d1f. SHA1:0000000000000000000000000000000000000000'
#  'N/A failed consecutively for 1 times for 0:0:0:0:0:0:0:0. N/A'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 49427'
#  'NET_MGMT command failed consecutively for 1 times for fdc9:ccbe:52c0:cbc0:250:56ff:feb5:27a6. WRITE'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbc0:250:56ff:feb5:27a6. 25090'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 44877'
#  'NET_MGMT command failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5127. WRITE'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 15239'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 41997'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 55915'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 47358'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 8709'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 20573'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 36315'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 29338'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 19240'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 49961'
#  'N/A failed consecutively for 1 times for 18f0:9fe5:18f0:9fe5:18f0:9fe5:18f0:9fe5. N/A'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 31693'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 7101'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 760'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 6638'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 43309'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 31679'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 63907'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 46320'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 38072'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 40862'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 47448'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 9991'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 64749'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbc0:250:56ff:feb5:27a6. 0'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbc0:250:56ff:feb5:27a6. 52164'
#  'NET_MGMT command failed consecutively for 1 times for 4a79:14ff:0:0:1c1c:288:2070:cc86. WRITE'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 42055'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 21503'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 60229'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbc0:250:56ff:feb5:27a6. 21612'
#  'NET_MGMT command failed consecutively for 1 times for 4a79:14ff:0:0:1c1c:288:7d26:7d23. WRITE'
#  'NET_MGMT command failed consecutively for 1 times for 4a79:14ff:0:0:1c1c:288:7d20:377d. WRITE'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbe0:250:56ff:feb5:5b32. 0'
#  'NET_MGMT command failed consecutively for 1 times for fe80:0:0:0:213:5005:12e:9012. WRITE'
#  'NET_MGMT command failed consecutively for 1 times for 4a79:14ff:0:0:1c1c:288:0:0. WRITE'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbc0:250:56ff:feb5:27a6. 60434'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbc0:250:56ff:feb5:27a6. 6811'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbc0:250:56ff:feb5:27a6. 42556'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbc0:250:56ff:feb5:27a6. 51254'
#  'Secure association operation failed consecutively for 1 times for fd37:ec90:20c2:5c58:250:56ff:feb5:1010. 38365'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 51450'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 2142'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 9904'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 52399'
#  'Secure association operation failed consecutively for 1 times for fd37:ec90:20c2:5c58:250:56ff:feb5:1010. 53354'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 63785'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 49826'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 18571'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 27045'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 44113'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 3007'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 26213'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbc0:250:56ff:feb5:27a6. 51686'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ad6b. 44273'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ad6b. 56024'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:cbc0:250:56ff:feb5:27a6. 62795'
#  'NET_MGMT command failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:adb1. WRITE'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ad6b. 273'
#  'Secure association operation failed consecutively for 1 times for fdc9:ccbe:52c0:d3a0:250:56ff:feb5:ec3c. 0']

# %%
curated_reasons = []
for reason_i in df_3_12_136_85['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.12.136.85']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Secure association operation failed consecutively for 1 or more times
# NET_MGMT command failed consecutively for 1 or more times
# N/A failed consecutively for 1 or more times
# Certificate "insert" operation failed consecutively for 1 or more times

# %% [markdown]
# # '3.18.1.199'

# %%
df_3_18_1_199 = pd.read_pickle(ids_with_paths_dict['3.18.1.199'])
#-----
print(f"shape[0] = {df_3_18_1_199.shape[0]}")
print(f"# Unique reasons = {df_3_18_1_199['reason'].nunique()}")
print(df_3_18_1_199['reason'].unique())
# Out:
# shape[0] = 1
# # Unique reasons = 1
# ['Meter detected a RAM failure.']

# %%
curated_reasons = []
for reason_i in df_3_18_1_199['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.18.1.199']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter detected a RAM failure

# %% [markdown]
# # '3.18.1.220'

# %%
df_3_18_1_220 = pd.read_pickle(ids_with_paths_dict['3.18.1.220'])
#-----
print(f"shape[0] = {df_3_18_1_220.shape[0]}")
print(f"# Unique reasons = {df_3_18_1_220['reason'].nunique()}")
print(df_3_18_1_220['reason'].unique())
# Out:
# shape[0] = 21
# # Unique reasons = 1
# ['Meter detected a ROM failure.']

# %%
curated_reasons = []
for reason_i in df_3_18_1_220['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.18.1.220']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter detected a ROM failure

# %% [markdown]
# # '3.18.72.28'

# %%
df_3_18_72_28 = pd.read_pickle(ids_with_paths_dict['3.18.72.28'])
#-----
print(f"shape[0] = {df_3_18_72_28.shape[0]}")
print(f"# Unique reasons = {df_3_18_72_28['reason'].nunique()}")
print(df_3_18_72_28['reason'].unique())
# Out:
# shape[0] = 3942
# # Unique reasons = 1728
# ['NVRAM Error cleared for meter 00:13:50:05:ff:1b:b6:d0.'
#  'NVRAM Error cleared for meter 00:13:50:05:ff:1c:5c:8b.'
#  'NVRAM Error cleared for meter 00:13:50:05:ff:24:d7:d7.' ...
#  'NVRAM Error cleared for meter 00:13:50:05:ff:41:40:4e.'
#  'NVRAM Error cleared for meter 00:13:50:05:ff:00:46:a7.'
#  'NVRAM Error cleared for meter 00:13:50:03:ff:02:a8:3a.']

# %%
curated_reasons = []
for reason_i in df_3_18_72_28['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.18.72.28']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# NVRAM Error cleared

# %% [markdown]
# # '3.18.72.79'

# %%
df_3_18_72_79 = pd.read_pickle(ids_with_paths_dict['3.18.72.79'])
#-----
print(f"shape[0] = {df_3_18_72_79.shape[0]}")
print(f"# Unique reasons = {df_3_18_72_79['reason'].nunique()}")
print(df_3_18_72_79['reason'].unique())
# Out:
# shape[0] = 6143
# # Unique reasons = 3524
# ['NVRAM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:11:10:cc.'
#  'NVRAM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:10:fd:3b.'
#  'NVRAM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1d:77:d9.'
#  ...
#  'NVRAM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:04:8d:47.'
#  'NVRAM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:04:8d:64.'
#  'NVRAM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:00:46:a7.']

# %%
curated_reasons = []
for reason_i in df_3_18_72_79['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.18.72.79']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# NVRAM Error (C1219 Table 3)
# NVRAM Error (C1219 Table 3: Er000200)

# %% [markdown]
# # '3.18.72.85'

# %%
df_3_18_72_85 = pd.read_pickle(ids_with_paths_dict['3.18.72.85'])
#-----
print(f"shape[0] = {df_3_18_72_85.shape[0]}")
print(f"# Unique reasons = {df_3_18_72_85['reason'].nunique()}")
print(df_3_18_72_85['reason'].unique())
# Out:
# shape[0] = 1815480
# # Unique reasons = 1638510
# ['Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 01/16/2020 15:00:11  Sequence number = 1339  User id = 0  Event argument = 00-00'
#  'Meter detected a nonvolatile memory failure.'
#  'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 01/16/2020 15:52:15  Sequence number = 33574  User id = 0  Event argument = 00-00'
#  ...
#  'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 07/03/2023 18:37:09  Sequence number = 31521  User id = 0  Event argument = 00-00'
#  'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 9/19/2023 4:21:16 PM  Sequence number = 16663  User id = 0  Event argument = 00-00'
#  'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 12/11/2023 01:17:41  Sequence number = 17951  User id = 44624  Event argument = FF-00']

# %%
curated_reasons = []
for reason_i in df_3_18_72_85['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.18.72.85']
    )
#     if curated_reason_i=='Meter event ':
#         print(reason_i)
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*sorted(curated_reasons), sep='\n')
# Out:
# KV2c meter event Received kWh Caution  (Diagnostic flags = Phase A Voltage)
# Meter event Demand Reset Occurred
# Meter event Nonvolatile Memory Failure Detected
# Meter event Nonvolatile Memory Failure Detected
# Meter event Reset List Pointers
# Reason is null, ID=3.18.72.85
# Universal event Unsupported Event(41) with priority Alarm

# %% [markdown]
# # '3.18.85.28'

# %%
df_3_18_85_28 = pd.read_pickle(ids_with_paths_dict['3.18.85.28'])
#-----
print(f"shape[0] = {df_3_18_85_28.shape[0]}")
print(f"# Unique reasons = {df_3_18_85_28['reason'].nunique()}")
print(df_3_18_85_28['reason'].unique())
# Out:
# shape[0] = 1
# # Unique reasons = 1
# ['RAM Error cleared for meter 00:13:50:05:ff:0d:dd:17.']

# %%
curated_reasons = []
for reason_i in df_3_18_85_28['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.18.85.28']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# RAM Error cleared

# %% [markdown]
# # '3.18.85.79'

# %%
df_3_18_85_79 = pd.read_pickle(ids_with_paths_dict['3.18.85.79'])
#-----
print(f"shape[0] = {df_3_18_85_79.shape[0]}")
print(f"# Unique reasons = {df_3_18_85_79['reason'].nunique()}")
print(df_3_18_85_79['reason'].unique())
# Out:
# shape[0] = 1
# # Unique reasons = 1
# ['RAM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:0d:dd:17.']

# %%
curated_reasons = []
for reason_i in df_3_18_85_79['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.18.85.79']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# RAM Error (C1219 Table 3)

# %% [markdown]
# # '3.18.85.85'

# %%
df_3_18_85_85 = pd.read_pickle(ids_with_paths_dict['3.18.85.85'])
#-----
print(f"shape[0] = {df_3_18_85_85.shape[0]}")
print(f"# Unique reasons = {df_3_18_85_85['reason'].nunique()}")
print(df_3_18_85_85['reason'].unique())
# Out:
# shape[0] = 361
# # Unique reasons = 5
# ['Meter detected a RAM failure.'
#  'Meter event Ram Failure Detected  Time event occurred on meter = 7/27/2021 12:45:53 PM  Sequence number = 89  User id = 34891  Event argument = 7D-75'
#  'Meter event Ram Failure Detected  Time event occurred on meter = 12/27/2021 07:04:06  Sequence number = 195  User id = 0  Event argument = 00-00 '
#  'Meter event Ram Failure Detected  Time event occurred on meter = 2/6/2022 5:06:08 PM  Sequence number = 345  User id = 34891  Event argument = 7D-75'
#  'Meter event Ram Failure Detected  Time event occurred on meter = 10/02/2022 20:51:19  Sequence number = 141  User id = 0  Event argument = 00-00 ']

# %%
curated_reasons = []
for reason_i in df_3_18_85_85['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.18.85.85']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter event Ram Failure Detected

# %% [markdown]
# # '3.18.92.28'

# %%
df_3_18_92_28 = pd.read_pickle(ids_with_paths_dict['3.18.92.28'])
#-----
print(f"shape[0] = {df_3_18_92_28.shape[0]}")
print(f"# Unique reasons = {df_3_18_92_28['reason'].nunique()}")
print(df_3_18_92_28['reason'].unique())
# Out:
# shape[0] = 21
# # Unique reasons = 19
# ['ROM Error cleared for meter 00:13:50:05:ff:1f:ba:d0.'
#  'ROM Error cleared for meter 00:13:50:05:ff:0f:50:01.'
#  'ROM Error cleared for meter 00:13:50:05:ff:1b:6e:54.'
#  'ROM Error cleared for meter 00:13:50:05:ff:0f:6e:8e.'
#  'ROM Error cleared for meter 00:13:50:05:ff:0a:e3:83.'
#  'ROM Error cleared for meter 00:13:50:05:ff:1b:35:ed.'
#  'ROM Error cleared for meter 00:13:50:03:ff:06:22:d6.'
#  'ROM Error cleared for meter 00:13:50:05:ff:1b:27:df.'
#  'ROM Error cleared for meter 00:13:50:05:ff:0f:0e:34.'
#  'ROM Error cleared for meter 00:13:50:05:ff:1f:c2:93.'
#  'ROM Error cleared for meter 00:13:50:05:ff:0d:dd:17.'
#  'ROM Error cleared for meter 00:13:50:05:ff:1b:1c:b1.'
#  'ROM Error cleared for meter 00:13:50:05:ff:11:7c:3e.'
#  'ROM Error cleared for meter 00:13:50:03:ff:06:0d:f6.'
#  'ROM Error cleared for meter 00:13:50:05:ff:2c:f6:f9.'
#  'ROM Error cleared for meter 00:13:50:03:ff:06:78:77.'
#  'ROM Error cleared for meter 00:13:50:05:ff:02:7f:04.'
#  'ROM Error cleared for meter 00:13:50:05:ff:02:68:cb.'
#  'ROM Error cleared for meter 00:13:50:05:ff:02:82:8c.']

# %%
curated_reasons = []
for reason_i in df_3_18_92_28['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.18.92.28']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# ROM Error cleared

# %% [markdown]
# # '3.18.92.79'

# %%
df_3_18_92_79 = pd.read_pickle(ids_with_paths_dict['3.18.92.79'])
#-----
print(f"shape[0] = {df_3_18_92_79.shape[0]}")
print(f"# Unique reasons = {df_3_18_92_79['reason'].nunique()}")
print(df_3_18_92_79['reason'].unique())
# Out:
# shape[0] = 29
# # Unique reasons = 26
# ['ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1f:ba:d0.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1b:35:ed.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:0f:6e:8e.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1b:3e:4e.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1b:6e:54.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:04:1a:66.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1b:27:df.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:0f:6e:d0.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:13:c1:55.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:0f:0e:34.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1b:3c:9a.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1f:c7:11.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1f:c2:93.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:23:a7:5b.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:0d:dd:17.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:1b:1c:b1.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:2c:f6:f9.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:03:ff:06:78:77.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:11:7c:3e.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:03:ff:06:d4:c7.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:03:ff:06:0d:f6.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:03:ff:02:2e:95.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:02:82:8c.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:02:7f:04.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:02:68:cb.'
#  'ROM Error (C1219 Table 3) occurred for meter 00:13:50:05:ff:01:f1:95.']

# %%
curated_reasons = []
for reason_i in df_3_18_92_79['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.18.92.79']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# ROM Error (C1219 Table 3)

# %% [markdown]
# # '3.18.92.85'

# %%
df_3_18_92_85_1 = pd.read_pickle(ids_with_paths_dict['3.18.92.85'])
df_3_18_92_85_2 = pd.read_pickle(r'C:\Users\s346557\Documents\LocalData\dovs_and_end_events_data\regex_TX\sample_dfs\df_3_18_92_85.pkl')
df_3_18_92_85 = pd.concat([df_3_18_92_85_1, df_3_18_92_85_2])
#-----
print(f"shape[0] = {df_3_18_92_85.shape[0]}")
print(f"# Unique reasons = {df_3_18_92_85['reason'].nunique()}")
print(df_3_18_92_85['reason'].unique())
# Out:
# shape[0] = 8277
# # Unique reasons = 9
# ['Meter detected a ROM failure.'
#  'Meter event Rom Failure Detected  Time event occurred on meter = 03/16/2020 07:00:51  Sequence number = 1983  User id = 1024  Event argument = 00-00'
#  'Meter event Rom Failure Detected  Time event occurred on meter = 11/24/2020 17:00:11  Sequence number = 564  User id = 0  Event argument = 00-00 '
#  'Meter event Rom Failure Detected  Time event occurred on meter = 12/04/2020 10:00:13  Sequence number = 69  User id = 0  Event argument = 00-00 '
#  'Meter event Rom Failure Detected  Time event occurred on meter = 12/09/2020 03:23:51  Sequence number = 1688  User id = 0  Event argument = 00-00 '
#  'Meter event Rom Failure Detected  Time event occurred on meter = 12/18/2021 13:47:16  Sequence number = 20510  User id = 0  Event argument = 00-00 '
#  'Meter event Rom Failure Detected  Time event occurred on meter = 12/20/2021 14:40:16  Sequence number = 20510  User id = 0  Event argument = 00-00 '
#  'Meter event Rom Failure Detected  Time event occurred on meter = 8/19/2022 9:26:25 PM  Sequence number = 89  User id = 34891  Event argument = 7D-75'
#  'ROM failure detected.']

# %%
curated_reasons = []
for reason_i in df_3_18_92_85['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.18.92.85']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter event Rom Failure Detected

# %% [markdown]
# # '3.21.1.79'

# %%
df_3_21_1_79 = pd.read_pickle(ids_with_paths_dict['3.21.1.79'])
#-----
print(f"shape[0] = {df_3_21_1_79.shape[0]}")
print(f"# Unique reasons = {df_3_21_1_79['reason'].nunique()}")
print(df_3_21_1_79['reason'].unique())
# Out:
# shape[0] = 118
# # Unique reasons = 61
# ['Meter event Measurement Error Detected  Time event occurred on meter = 08/22/2021 20:05:07  Sequence number = 27684  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/26/2021 08:27:25  Sequence number = 307  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/26/2021 08:51:07  Sequence number = 308  User id = 0  Event argument = 00-00 '
#  'Meter detected a measurement error.'
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/26/2021 22:13:49  Sequence number = 1104  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/26/2021 05:54:09  Sequence number = 311  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/26/2021 16:36:23  Sequence number = 55256  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/26/2021 20:13:50  Sequence number = 312  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/28/2021 09:22:20  Sequence number = 4972  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/28/2021 15:48:41  Sequence number = 2094  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/28/2021 19:50:15  Sequence number = 310  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/28/2021 22:24:38  Sequence number = 3690  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/28/2021 10:11:17  Sequence number = 128  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/28/2021 13:40:49  Sequence number = 1105  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/31/2021 14:16:34  Sequence number = 317  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/31/2021 15:22:30  Sequence number = 318  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/31/2021 07:06:20  Sequence number = 323  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/31/2021 10:10:13  Sequence number = 324  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/31/2021 12:23:41  Sequence number = 325  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/31/2021 20:59:14  Sequence number = 326  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/30/2021 11:57:45  Sequence number = 129  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/30/2021 14:39:32  Sequence number = 320  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/30/2021 16:36:26  Sequence number = 316  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/30/2021 17:31:11  Sequence number = 1136  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/30/2021 20:14:46  Sequence number = 322  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/30/2021 13:30:07  Sequence number = 130  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/30/2021 14:16:01  Sequence number = 2096  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/30/2021 18:46:19  Sequence number = 321  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/29/2021 04:44:46  Sequence number = 3691  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/29/2021 17:03:45  Sequence number = 2095  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/29/2021 17:27:55  Sequence number = 313  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/29/2021 17:59:50  Sequence number = 314  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/29/2021 20:10:44  Sequence number = 315  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/29/2021 21:16:22  Sequence number = 318  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/29/2021 04:39:49  Sequence number = 311  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/29/2021 04:50:23  Sequence number = 312  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/29/2021 09:11:49  Sequence number = 4973  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/29/2021 11:17:34  Sequence number = 315  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/29/2021 11:29:42  Sequence number = 316  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/29/2021 12:47:37  Sequence number = 317  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/29/2021 18:18:01  Sequence number = 1121  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/29/2021 22:56:30  Sequence number = 319  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/25/2021 07:13:12  Sequence number = 305  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/25/2021 21:10:18  Sequence number = 712  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/25/2021 21:36:12  Sequence number = 1103  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/25/2021 16:19:12  Sequence number = 2088  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/25/2021 21:00:16  Sequence number = 2089  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/25/2021 22:02:52  Sequence number = 306  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/27/2021 07:07:35  Sequence number = 309  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/27/2021 09:22:32  Sequence number = 4971  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/27/2021 16:46:46  Sequence number = 125  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/27/2021 20:11:00  Sequence number = 127  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/27/2021 23:53:13  Sequence number = 3689  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/27/2021 07:59:10  Sequence number = 313  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/27/2021 09:33:51  Sequence number = 314  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 08/27/2021 17:04:00  Sequence number = 126  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 09/01/2021 11:54:04  Sequence number = 131  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 09/01/2021 14:47:06  Sequence number = 319  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 09/01/2021 10:43:06  Sequence number = 54395  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 09/01/2021 19:23:16  Sequence number = 320  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 09/01/2021 23:39:52  Sequence number = 327  User id = 0  Event argument = 00-00 ']

# %%
curated_reasons = []
for reason_i in df_3_21_1_79['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.21.1.79']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter event Measurement Error Detected

# %% [markdown]
# # '3.21.1.173'

# %%
df_3_21_1_173 = pd.read_pickle(ids_with_paths_dict['3.21.1.173'])
#-----
print(f"shape[0] = {df_3_21_1_173.shape[0]}")
print(f"# Unique reasons = {df_3_21_1_173['reason'].nunique()}")
print(df_3_21_1_173['reason'].unique())
# Out:
# shape[0] = 10430
# # Unique reasons = 9251
# ['Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 08/28/2021 04:00:11  Sequence number = 3232  User id = 0  Event argument = 00-00 '
#  'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 08/28/2021 04:22:00  Sequence number = 5476  User id = 0  Event argument = 00-00 '
#  'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 08/28/2021 04:00:01  Sequence number = 10175  User id = 0  Event argument = 00-00 '
#  ...
#  'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 09/02/2021 03:41:33  Sequence number = 42906  User id = 0  Event argument = 00-00 '
#  'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 09/02/2021 03:41:34  Sequence number = 42907  User id = 0  Event argument = 00-00 '
#  'Meter event Nonvolatile Memory Failure Detected  Time event occurred on meter = 09/02/2021 03:51:00  Sequence number = 22928  User id = 0  Event argument = 00-00 ']

# %%
curated_reasons = []
for reason_i in df_3_21_1_173['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.21.1.173']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter event Nonvolatile Memory Failure Detected

# %% [markdown]
# # '3.21.3.28'

# %%
df_3_21_3_28 = pd.read_pickle(ids_with_paths_dict['3.21.3.28'])
#-----
print(f"shape[0] = {df_3_21_3_28.shape[0]}")
print(f"# Unique reasons = {df_3_21_3_28['reason'].nunique()}")
print(df_3_21_3_28['reason'].unique())
# Out:
# shape[0] = 122
# # Unique reasons = 121
# ['System Error cleared for meter 00:13:50:05:ff:1b:65:b4.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:c6:bc.'
#  'System Error cleared for meter 00:13:50:05:ff:10:14:0c.'
#  'System Error cleared for meter 00:13:50:05:ff:11:07:96.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:d4:5c.'
#  'System Error cleared for meter 00:13:50:05:ff:11:a8:ab.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:22:1a.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:13:d2.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:e9:95.'
#  'System Error cleared for meter 00:13:50:05:ff:13:3d:f2.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:cf:29.'
#  'System Error cleared for meter 00:13:50:05:ff:11:55:84.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:ce:32.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:d1:a0.'
#  'System Error cleared for meter 00:13:50:05:ff:11:83:06.'
#  'System Error cleared for meter 00:13:50:05:ff:11:7f:dd.'
#  'System Error cleared for meter 00:13:50:05:ff:13:04:b7.'
#  'System Error cleared for meter 00:13:50:03:ff:03:45:e5.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:67:90.'
#  'System Error cleared for meter 00:13:50:05:ff:18:57:70.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:ea:50.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:fe:74.'
#  'System Error cleared for meter 00:13:50:05:ff:1e:d8:5b.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:50:01.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:ad:1e.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:f7:52.'
#  'System Error cleared for meter 00:13:50:05:ff:0a:5e:b5.'
#  'System Error cleared for meter 00:13:50:05:ff:22:f2:58.'
#  'System Error cleared for meter 00:13:50:05:ff:21:9d:c1.'
#  'System Error cleared for meter 00:13:50:05:ff:1b:42:7b.'
#  'System Error cleared for meter 00:13:50:05:ff:0e:16:4d.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:bd:36.'
#  'System Error cleared for meter 00:13:50:05:ff:25:29:dc.'
#  'System Error cleared for meter 00:13:50:05:ff:1a:64:f7.'
#  'System Error cleared for meter 00:13:50:05:ff:10:ca:97.'
#  'System Error cleared for meter 00:13:50:05:ff:21:50:5e.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:6c:c6.'
#  'System Error cleared for meter 00:13:50:05:ff:14:82:c7.'
#  'System Error cleared for meter 00:13:50:05:ff:14:8c:05.'
#  'System Error cleared for meter 00:13:50:05:ff:18:ba:33.'
#  'System Error cleared for meter 00:13:50:05:ff:13:2d:0a.'
#  'System Error cleared for meter 00:13:50:05:ff:1b:6e:54.'
#  'System Error cleared for meter 00:13:50:05:ff:13:f0:74.'
#  'System Error cleared for meter 00:13:50:05:ff:1b:4c:65.'
#  'System Error cleared for meter 00:13:50:05:ff:13:9e:2e.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:03:18.'
#  'System Error cleared for meter 00:13:50:05:ff:14:c8:8b.'
#  'System Error cleared for meter 00:13:50:05:ff:12:dc:fd.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:d8:b9.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:7b:fc.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:b4:ba.'
#  'System Error cleared for meter 00:13:50:05:ff:11:40:84.'
#  'System Error cleared for meter 00:13:50:05:ff:1e:ac:06.'
#  'System Error cleared for meter 00:13:50:05:ff:10:b8:15.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:f8:d1.'
#  'System Error cleared for meter 00:13:50:05:ff:11:0e:bf.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:be:01.'
#  'System Error cleared for meter 00:13:50:05:ff:1e:42:c5.'
#  'System Error cleared for meter 00:13:50:05:ff:12:55:83.'
#  'System Error cleared for meter 00:13:50:05:ff:20:89:d6.'
#  'System Error cleared for meter 00:13:50:05:ff:1d:5f:e6.'
#  'System Error cleared for meter 00:13:50:05:ff:14:ff:64.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:88:18.'
#  'System Error cleared for meter 00:13:50:05:ff:05:24:30.'
#  'System Error cleared for meter 00:13:50:05:ff:17:fe:1c.'
#  'System Error cleared for meter 00:13:50:05:ff:17:c8:75.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:20:53.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:8a:47.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:b5:44.'
#  'System Error cleared for meter 00:13:50:05:ff:10:d5:49.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:2c:a9.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:ed:6d.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:a0:b3.'
#  'System Error cleared for meter 00:13:50:05:ff:12:ca:dc.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:bf:69.'
#  'System Error cleared for meter 00:13:50:05:ff:23:82:47.'
#  'System Error cleared for meter 00:13:50:01:00:a7:b6:65.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:dd:17.'
#  'System Error cleared for meter 00:13:50:05:ff:11:08:56.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:48:fc.'
#  'System Error cleared for meter 00:13:50:05:ff:21:b1:f0.'
#  'System Error cleared for meter 00:13:50:05:ff:2c:f9:98.'
#  'System Error cleared for meter 00:13:50:05:ff:12:24:f4.'
#  'System Error cleared for meter 00:13:50:05:ff:20:47:43.'
#  'System Error cleared for meter 00:13:50:05:ff:20:6c:41.'
#  'System Error cleared for meter 00:13:50:05:ff:18:5a:03.'
#  'System Error cleared for meter 00:13:50:05:ff:17:b4:8c.'
#  'System Error cleared for meter 00:13:50:05:ff:15:03:79.'
#  'System Error cleared for meter 00:13:50:05:ff:21:70:d5.'
#  'System Error cleared for meter 00:13:50:05:ff:28:e9:c5.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:bf:fc.'
#  'System Error cleared for meter 00:13:50:05:ff:2d:26:d3.'
#  'System Error cleared for meter 00:13:50:05:ff:24:1f:f5.'
#  'System Error cleared for meter 00:13:50:05:ff:0d:c6:ca.'
#  'System Error cleared for meter 00:13:50:05:ff:15:12:c1.'
#  'System Error cleared for meter 00:13:50:05:ff:20:36:71.'
#  'System Error cleared for meter 00:13:50:05:ff:15:f5:e1.'
#  'System Error cleared for meter 00:13:50:05:ff:18:23:d2.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:21:9b.'
#  'System Error cleared for meter 00:13:50:05:ff:1f:ed:ef.'
#  'System Error cleared for meter 00:13:50:05:ff:43:1c:74.'
#  'System Error cleared for meter 00:13:50:05:ff:43:1c:94.'
#  'System Error cleared for meter 00:13:50:05:ff:43:1c:ad.'
#  'System Error cleared for meter 00:13:50:05:ff:43:1c:a5.'
#  'System Error cleared for meter 00:13:50:05:ff:43:1c:86.'
#  'System Error cleared for meter 00:13:50:05:ff:43:1c:72.'
#  'System Error cleared for meter 00:13:50:05:ff:36:ca:6b.'
#  'System Error cleared for meter 00:13:50:05:ff:43:1c:7d.'
#  'System Error cleared for meter 00:13:50:05:ff:11:2d:23.'
#  'System Error cleared for meter 00:13:50:05:ff:13:61:cf.'
#  'System Error cleared for meter 00:13:50:05:ff:1f:4f:14.'
#  'System Error cleared for meter 00:13:50:05:ff:19:3f:25.'
#  'System Error cleared for meter 00:13:50:05:ff:20:d6:67.'
#  'System Error cleared for meter 00:13:50:05:ff:0e:04:3d.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:a9:3d.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:de:5b.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:a0:d6.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:97:cd.'
#  'System Error cleared for meter 00:13:50:05:ff:1d:1c:cc.'
#  'System Error cleared for meter 00:13:50:05:ff:0f:39:01.'
#  'System Error cleared for meter 00:13:50:05:ff:15:31:21.']

# %%
curated_reasons = []
for reason_i in df_3_21_3_28['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.21.3.28']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# System Error cleared

# %% [markdown]
# # '3.21.3.79'

# %%
df_3_21_3_79 = pd.read_pickle(ids_with_paths_dict['3.21.3.79'])
#-----
print(f"shape[0] = {df_3_21_3_79.shape[0]}")
print(f"# Unique reasons = {df_3_21_3_79['reason'].nunique()}")
print(df_3_21_3_79['reason'].unique())
# Out:
# shape[0] = 209
# # Unique reasons = 204
# ['System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0f:17:ba.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:07:6a:3f.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:14:cb:05.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:11:7f:dd.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:11:8e:70.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:14:cb:09.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:25:b0:3d.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0f:0d:e1.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:14:d2:a6.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0f:0d:e3.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0f:03:18.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:24:b8:2f.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:25:7f:9a.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:08:ff:00:05:f1.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:05:0a:58.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1e:d8:5b.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1e:05:7d.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:01:01:03:93:4c.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1c:f7:b4.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:08:dd:fc.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1d:38:ba.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:00:2f:09.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:00:4d:39.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:07:16:57.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:01:2d:dc.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0a:3c:a6.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:07:61:af.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:13:f0:74.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:05:24:ae.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:06:f7:f3.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0b:62:0a.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:ff:03:52:f3.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:12:dc:fd.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:01:00:a7:91:e9.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:15:43:79.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0d:fa:f6.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:21:9a:91.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:19:bb:fb.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1b:9d:1c.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0f:6e:8e.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0a:3d:78.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:00:2e:85.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1b:3e:4e.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1b:6e:54.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:04:1a:66.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:09:1c:1d.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:13:32:e2.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0f:2d:8c.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:14:c8:8b.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:08:c1:fb.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0f:d5:bc.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1b:4c:65.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:20:1c:59.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:01:43:c5.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1b:27:df.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:ff:01:e3:38.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:11:40:99.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0d:c8:e3.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:17:10:44.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:18:ba:33.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:20:47:43.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:00:0b:23.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:17:10:ff.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:ff:04:ab:24.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0d:f0:dd.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:05:8b:6a.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:ff:04:68:2e.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:21:92:9c.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0b:4d:17.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0d:b4:ba.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:ff:04:c9:bf.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:06:24:29.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1c:39:86.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:22:63:4a.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:04:be:4c.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0f:8e:0d.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:ff:04:a4:0d.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:2e:17:7e.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:ff:03:6d:27.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:13:c1:55.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1f:c7:11.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0f:0e:34.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1b:3c:9a.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:20:1b:2d.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0d:4b:56.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:24:1a:d2.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0d:18:bc.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:09:00:ba.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:27:53:ac.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:19:7b:2f.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:01:3e:9f.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:14:9c:d0.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:23:a7:5b.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:33:65:5e.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:18:59:bd.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1c:14:ff.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:27:e0:a1.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:04:ef:43.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:00:0d:ee.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:01:00:f8:8c:cd.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:10:44:c8.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:01:00:a7:b6:65.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0d:dd:17.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1c:c2:ba.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:01:0e:97.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:28:2d:38.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:2c:f9:98.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:35:e6:70.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:24:68:ef.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:00:83:45.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0a:5f:35.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0a:60:35.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0a:5c:95.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0a:5f:88.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:04:8c:83.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:09:1e:bd.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:ff:01:fe:d1.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0d:9f:92.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0f:85:03.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:24:09:ae.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:2e:1d:c9.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:ff:03:2f:ee.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:22:d0:e8.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:2c:fd:a3.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:21:09:ec.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:2e:5b:93.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:38:e8:a0.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:32:40:69.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0a:66:80.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:27:a3:8a.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:22:ca:b3.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:00:4e:de:4c.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:08:7e:64.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:20:28:a1.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:01:00:f7:67:57.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:16:18:12.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:09:68:7f.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0a:8b:fe.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:2c:f6:f9.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:18:e1:3e.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:22:4c:fa.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:32:40:9c.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:ff:06:78:77.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:08:ef:e3.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:00:4f:04:05.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:11:7c:3e.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:ff:03:55:5e.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:ff:06:d4:c7.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:2b:7e:d7.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:ff:06:0d:f6.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:17:7b:e3.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:27:cd:84.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:18:ff:e0.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:22:78:17.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:05:97:75.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:02:82:8c.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:12:7f:2e.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:1f:53:02.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0a:02:a4.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0a:6a:6c.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:20:bd:f2.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:21:1a:30.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:15:f5:e1.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:24:1f:f5.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:02:7f:04.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:36:ca:6b.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:3c:ba:6f.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:02:00:9c:01:90.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:34:8a:8f.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:2c:f0:3a.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:24:c8:f8.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:44:c7:d6.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:27:ea:c2.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:23:42:61.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:13:3d:b5.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:20:c5:28.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:3d:ca:d1.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:00:e8:91.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0a:5e:ff.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:02:68:cb.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:37:b0:62.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:16:35:ab.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:2b:b1:db.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0e:79:fe.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0e:62:93.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:15:de:36.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:16:f3:be.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:24:6d:44.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:24:66:db.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:0e:51:ab.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:01:00:f3:9a:fe.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:ff:03:27:fa.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:3c:e4:6e.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:2b:47:c4.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:2b:4f:e7.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:45:9f:31.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:3c:c0:1b.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:24:4d:48.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:02:72:39.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:01:00:0d:a5:78.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:11:2c:5f.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:38:2f:3b.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:05:ff:05:41:e4.'
#  'System Error (C1219 Table 3: Er000020) occurred for meter 00:13:50:03:00:4e:ee:ad.']

# %%
curated_reasons = []
for reason_i in df_3_21_3_79['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.21.3.79']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# System Error (C1219 Table 3: Er000020)

# %% [markdown]
# # '3.21.17.28'

# %%
df_3_21_17_28 = pd.read_pickle(ids_with_paths_dict['3.21.17.28'])
#-----
print(f"shape[0] = {df_3_21_17_28.shape[0]}")
print(f"# Unique reasons = {df_3_21_17_28['reason'].nunique()}")
print(df_3_21_17_28['reason'].unique())
# Out:
# shape[0] = 380484
# # Unique reasons = 1
# ['Meter detected a self check error.']

# %%
curated_reasons = []
for reason_i in df_3_21_17_28['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.21.17.28']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter detected a self check error

# %% [markdown]
# # '3.21.18.79'

# %%
df_3_21_18_79 = pd.read_pickle(ids_with_paths_dict['3.21.18.79'])
#-----
print(f"shape[0] = {df_3_21_18_79.shape[0]}")
print(f"# Unique reasons = {df_3_21_18_79['reason'].nunique()}")
print(df_3_21_18_79['reason'].unique())
# Out:
# shape[0] = 4352
# # Unique reasons = 1
# ['Meter detected a self check error.']

# %%
curated_reasons = []
for reason_i in df_3_21_18_79['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.21.18.79']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter detected a self check error

# %% [markdown]
# # '3.21.38.223'

# %%
df_3_21_38_223 = pd.read_pickle(ids_with_paths_dict['3.21.38.223'])
#-----
print(f"shape[0] = {df_3_21_38_223.shape[0]}")
print(f"# Unique reasons = {df_3_21_38_223['reason'].nunique()}")
print(df_3_21_38_223['reason'].unique())
# Out:
# shape[0] = 785056
# # Unique reasons = 707588
# ['Detected end of voltage sag on meter 00:13:50:05:ff:32:66:22 on one or several phases. Duration: 21 cycles (less than a second), Min RMS Voltage: Phase A 118.1 V, Phase B 95.4 V, Phase C 120.3 V, RMS Current (at min voltage): Phase A 1.0 A, Phase B 0.2 A, Phase C 1.2 A'
#  'Detected end of voltage sag on meter 00:13:50:05:ff:32:66:22 on one or several phases. Duration: 22 cycles (less than a second), Min RMS Voltage: Phase A 118.2 V, Phase B 96.3 V, Phase C 120.3 V, RMS Current (at min voltage): Phase A 1.0 A, Phase B 0.2 A, Phase C 1.2 A'
#  'Detected end of voltage sag on meter 00:13:50:05:ff:32:66:22 on one or several phases. Duration: 22 cycles (less than a second), Min RMS Voltage: Phase A 119.6 V, Phase B 118.1 V, Phase C 103.3 V, RMS Current (at min voltage): Phase A 0.9 A, Phase B 1.2 A, Phase C 0.6 A'
#  ...
#  'Detected end of voltage sag on meter 00:13:50:05:ff:06:8d:d9 on one or several phases. Duration: 13 cycles (less than a second), Min RMS Voltage: Phase A 111.1 V, Phase B 133.3 V, Phase C 210.5 V, RMS Current (at min voltage): Phase A 17.9 A, Phase B 4.6 A, Phase C 0.5 A'
#  'Detected end of voltage sag on meter 00:13:50:05:ff:06:8d:d9 on one or several phases. Duration: 6 cycles (less than a second), Min RMS Voltage: Phase A 111.8 V, Phase B 133.4 V, Phase C 210.6 V, RMS Current (at min voltage): Phase A 17.1 A, Phase B 4.3 A, Phase C 0.5 A'
#  'Detected end of voltage sag on meter 00:13:50:05:ff:06:8d:d9 on one or several phases. Duration: 13 cycles (less than a second), Min RMS Voltage: Phase A 106.3 V, Phase B 132.5 V, Phase C 207.6 V, RMS Current (at min voltage): Phase A 25.8 A, Phase B 5.7 A, Phase C 0.5 A']

# %%
curated_reasons = []
for reason_i in df_3_21_38_223['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.21.38.223']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Detected end of voltage sag

# %% [markdown]
# # '3.21.38.248'

# %%
df_3_21_38_248 = pd.read_pickle(ids_with_paths_dict['3.21.38.248'])
#-----
print(f"shape[0] = {df_3_21_38_248.shape[0]}")
print(f"# Unique reasons = {df_3_21_38_248['reason'].nunique()}")
print(df_3_21_38_248['reason'].unique())
# Out:
# shape[0] = 669559
# # Unique reasons = 571198
# ['Detected end of voltage swell on meter 00:13:50:05:ff:15:90:5d on one or several phases. Duration: 61 cycles (0 minutes 1.0 seconds), Max RMS Voltage: Phase A 123.1 V, Phase B 164.0 V, Phase C 122.4 V, RMS Current (at max voltage): Phase A 0.5 A, Phase B 0.2 A, Phase C 0.4 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:15:90:5d on one or several phases. Duration: 134 cycles (0 minutes 2.2 seconds), Max RMS Voltage: Phase A 123.1 V, Phase B 163.8 V, Phase C 122.3 V, RMS Current (at max voltage): Phase A 0.4 A, Phase B 0.2 A, Phase C 0.4 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:15:90:5d on one or several phases. Duration: 102 cycles (0 minutes 1.7 seconds), Max RMS Voltage: Phase A 122.4 V, Phase B 163.2 V, Phase C 122.3 V, RMS Current (at max voltage): Phase A 0.4 A, Phase B 0.2 A, Phase C 0.4 A'
#  ...
#  'Detected end of voltage swell on meter 00:13:50:03:ff:06:11:dc on one or several phases. Duration: 5 cycles (less than a second), Max RMS Voltage: Phase A 124.8 V, Phase B 125.1 V, Phase C 220.5 V, RMS Current (at max voltage): Phase A 8.1 A, Phase B 1.5 A, Phase C 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:06:11:dc on one or several phases. Duration: 44 cycles (less than a second), Max RMS Voltage: Phase A 124.8 V, Phase B 125.1 V, Phase C 220.5 V, RMS Current (at max voltage): Phase A 7.8 A, Phase B 1.4 A, Phase C 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:06:11:dc on one or several phases. Duration: 14 cycles (less than a second), Max RMS Voltage: Phase A 124.8 V, Phase B 125.1 V, Phase C 220.5 V, RMS Current (at max voltage): Phase A 8.1 A, Phase B 1.5 A, Phase C 0.0 A']

# %%
curated_reasons = []
for reason_i in df_3_21_38_248['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.21.38.248']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Detected end of voltage swell

# %% [markdown]
# # '3.21.43.223'

# %%
df_3_21_43_223 = pd.read_pickle(ids_with_paths_dict['3.21.43.223'])
#-----
print(f"shape[0] = {df_3_21_43_223.shape[0]}")
print(f"# Unique reasons = {df_3_21_43_223['reason'].nunique()}")
print(df_3_21_43_223['reason'].unique())
# Out:
# shape[0] = 2682
# # Unique reasons = 1430
# ['Detected end of voltage sag on meter 00:13:50:03:00:4f:77:74. Duration: 4 seconds, Min RMS Voltage: Phase A 227.7 V, RMS Current (at min voltage): Phase A 0.0 A'
#  'Detected end of voltage sag on meter 00:13:50:03:00:4f:77:74. Duration: 2 seconds, Min RMS Voltage: Phase A 227.7 V, RMS Current (at min voltage): Phase A 0.0 A'
#  'Detected end of voltage sag on meter 00:13:50:03:00:4f:77:74. Duration: 3 seconds, Min RMS Voltage: Phase A 227.0 V, RMS Current (at min voltage): Phase A 0.0 A'
#  ...
#  'Detected end of voltage sag on meter 00:13:50:05:ff:2b:e0:8d. Duration: 11 seconds, Min RMS Voltage: Phase A 227.7 V, RMS Current (at min voltage): Phase A 0.0 A'
#  'Detected end of voltage sag on meter 00:13:50:05:ff:08:bc:99. Duration: 1 seconds, Min RMS Voltage: Phase A 213.8 V, RMS Current (at min voltage): Phase A 0.0 A'
#  'Detected end of voltage sag on meter 00:13:50:05:ff:08:bc:99. Duration: 1 seconds, Min RMS Voltage: Phase A 200.6 V, RMS Current (at min voltage): Phase A 0.0 A']

# %%
curated_reasons = []
for reason_i in df_3_21_43_223['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.21.43.223']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Detected end of voltage sag

# %% [markdown]
# # '3.21.43.248'

# %%
df_3_21_43_248 = pd.read_pickle(ids_with_paths_dict['3.21.43.248'])
#-----
print(f"shape[0] = {df_3_21_43_248.shape[0]}")
print(f"# Unique reasons = {df_3_21_43_248['reason'].nunique()}")
print(df_3_21_43_248['reason'].unique())
# Out:
# shape[0] = 848
# # Unique reasons = 333
# ['Detected end of voltage swell on meter 00:13:50:05:ff:2d:2c:25. Duration: 195 seconds, Max RMS Voltage: Phase A 265.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2d:2c:25. Duration: 6 seconds, Max RMS Voltage: Phase A 266.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 23166 seconds, Max RMS Voltage: Phase A 158.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 1 seconds, Max RMS Voltage: Phase A 132.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 32 seconds, Max RMS Voltage: Phase A 132.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 352 seconds, Max RMS Voltage: Phase A 146.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 31 seconds, Max RMS Voltage: Phase A 134.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 382 seconds, Max RMS Voltage: Phase A 150.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 191 seconds, Max RMS Voltage: Phase A 138.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 324 seconds, Max RMS Voltage: Phase A 144.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 344 seconds, Max RMS Voltage: Phase A 145.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 29 seconds, Max RMS Voltage: Phase A 134.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 401 seconds, Max RMS Voltage: Phase A 146.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 28 seconds, Max RMS Voltage: Phase A 135.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 301 seconds, Max RMS Voltage: Phase A 147.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 28 seconds, Max RMS Voltage: Phase A 135.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 341 seconds, Max RMS Voltage: Phase A 147.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 1 seconds, Max RMS Voltage: Phase A 134.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 466 seconds, Max RMS Voltage: Phase A 144.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 14285 seconds, Max RMS Voltage: Phase A 157.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 124 seconds, Max RMS Voltage: Phase A 144.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 356 seconds, Max RMS Voltage: Phase A 146.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 1 seconds, Max RMS Voltage: Phase A 132.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 30 seconds, Max RMS Voltage: Phase A 132.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 323 seconds, Max RMS Voltage: Phase A 146.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 32 seconds, Max RMS Voltage: Phase A 133.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 329 seconds, Max RMS Voltage: Phase A 147.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 31 seconds, Max RMS Voltage: Phase A 134.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 902 seconds, Max RMS Voltage: Phase A 154.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 30 seconds, Max RMS Voltage: Phase A 134.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 408 seconds, Max RMS Voltage: Phase A 148.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 29 seconds, Max RMS Voltage: Phase A 134.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 439 seconds, Max RMS Voltage: Phase A 146.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 30 seconds, Max RMS Voltage: Phase A 134.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 299 seconds, Max RMS Voltage: Phase A 144.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 350 seconds, Max RMS Voltage: Phase A 146.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 29 seconds, Max RMS Voltage: Phase A 134.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 306 seconds, Max RMS Voltage: Phase A 146.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 28 seconds, Max RMS Voltage: Phase A 134.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 28 seconds, Max RMS Voltage: Phase A 135.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 303 seconds, Max RMS Voltage: Phase A 147.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 28 seconds, Max RMS Voltage: Phase A 135.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 29 seconds, Max RMS Voltage: Phase A 134.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 401 seconds, Max RMS Voltage: Phase A 145.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 467 seconds, Max RMS Voltage: Phase A 145.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 286 seconds, Max RMS Voltage: Phase A 144.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 28 seconds, Max RMS Voltage: Phase A 135.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 28 seconds, Max RMS Voltage: Phase A 135.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 400 seconds, Max RMS Voltage: Phase A 146.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 1 seconds, Max RMS Voltage: Phase A 264.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 8 seconds, Max RMS Voltage: Phase A 264.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 4 seconds, Max RMS Voltage: Phase A 264.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 13 seconds, Max RMS Voltage: Phase A 264.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 3 seconds, Max RMS Voltage: Phase A 264.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 6 seconds, Max RMS Voltage: Phase A 264.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 5 seconds, Max RMS Voltage: Phase A 264.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 2 seconds, Max RMS Voltage: Phase A 264.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 1 seconds, Max RMS Voltage: Phase A 264.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 34 seconds, Max RMS Voltage: Phase A 264.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 254 seconds, Max RMS Voltage: Phase A 264.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 221 seconds, Max RMS Voltage: Phase A 264.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 5 seconds, Max RMS Voltage: Phase A 264.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 7 seconds, Max RMS Voltage: Phase A 264.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 9 seconds, Max RMS Voltage: Phase A 264.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 4 seconds, Max RMS Voltage: Phase A 264.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 14 seconds, Max RMS Voltage: Phase A 264.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 6 seconds, Max RMS Voltage: Phase A 264.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 11 seconds, Max RMS Voltage: Phase A 264.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 13 seconds, Max RMS Voltage: Phase A 264.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 10 seconds, Max RMS Voltage: Phase A 264.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 8 seconds, Max RMS Voltage: Phase A 264.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 5 seconds, Max RMS Voltage: Phase A 264.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 45 seconds, Max RMS Voltage: Phase A 264.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 10 seconds, Max RMS Voltage: Phase A 264.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 50 seconds, Max RMS Voltage: Phase A 264.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 32 seconds, Max RMS Voltage: Phase A 264.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 18 seconds, Max RMS Voltage: Phase A 264.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 20 seconds, Max RMS Voltage: Phase A 264.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:0f:ba:76. Duration: 12 seconds, Max RMS Voltage: Phase A 264.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 28 seconds, Max RMS Voltage: Phase A 134.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 1 seconds, Max RMS Voltage: Phase A 134.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 344 seconds, Max RMS Voltage: Phase A 147.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 28 seconds, Max RMS Voltage: Phase A 135.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 28 seconds, Max RMS Voltage: Phase A 134.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 484 seconds, Max RMS Voltage: Phase A 144.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 373 seconds, Max RMS Voltage: Phase A 147.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 183 seconds, Max RMS Voltage: Phase A 138.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 359 seconds, Max RMS Voltage: Phase A 145.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 28 seconds, Max RMS Voltage: Phase A 134.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 297 seconds, Max RMS Voltage: Phase A 148.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 313 seconds, Max RMS Voltage: Phase A 146.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 385 seconds, Max RMS Voltage: Phase A 145.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 316 seconds, Max RMS Voltage: Phase A 145.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 881 seconds, Max RMS Voltage: Phase A 154.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 355 seconds, Max RMS Voltage: Phase A 146.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 184 seconds, Max RMS Voltage: Phase A 138.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 328 seconds, Max RMS Voltage: Phase A 144.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 28 seconds, Max RMS Voltage: Phase A 135.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 29 seconds, Max RMS Voltage: Phase A 134.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 344 seconds, Max RMS Voltage: Phase A 145.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 516 seconds, Max RMS Voltage: Phase A 145.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 334 seconds, Max RMS Voltage: Phase A 145.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 182 seconds, Max RMS Voltage: Phase A 137.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 29 seconds, Max RMS Voltage: Phase A 134.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 30 seconds, Max RMS Voltage: Phase A 135.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 29 seconds, Max RMS Voltage: Phase A 134.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 30 seconds, Max RMS Voltage: Phase A 134.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 31 seconds, Max RMS Voltage: Phase A 134.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 378 seconds, Max RMS Voltage: Phase A 146.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 31 seconds, Max RMS Voltage: Phase A 134.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 183 seconds, Max RMS Voltage: Phase A 138.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 316 seconds, Max RMS Voltage: Phase A 146.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 30 seconds, Max RMS Voltage: Phase A 136.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 453 seconds, Max RMS Voltage: Phase A 147.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 347 seconds, Max RMS Voltage: Phase A 146.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 29 seconds, Max RMS Voltage: Phase A 135.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 305 seconds, Max RMS Voltage: Phase A 147.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 309 seconds, Max RMS Voltage: Phase A 147.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 297 seconds, Max RMS Voltage: Phase A 145.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 334 seconds, Max RMS Voltage: Phase A 146.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 302 seconds, Max RMS Voltage: Phase A 146.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 27 seconds, Max RMS Voltage: Phase A 134.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 319 seconds, Max RMS Voltage: Phase A 147.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 27 seconds, Max RMS Voltage: Phase A 135.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 406 seconds, Max RMS Voltage: Phase A 147.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 290 seconds, Max RMS Voltage: Phase A 145.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 296 seconds, Max RMS Voltage: Phase A 144.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 439 seconds, Max RMS Voltage: Phase A 145.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 27 seconds, Max RMS Voltage: Phase A 135.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 286 seconds, Max RMS Voltage: Phase A 145.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 183 seconds, Max RMS Voltage: Phase A 137.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 454 seconds, Max RMS Voltage: Phase A 145.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 383 seconds, Max RMS Voltage: Phase A 146.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 441 seconds, Max RMS Voltage: Phase A 147.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 308 seconds, Max RMS Voltage: Phase A 145.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 459 seconds, Max RMS Voltage: Phase A 144.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 396 seconds, Max RMS Voltage: Phase A 144.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 329 seconds, Max RMS Voltage: Phase A 146.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 334 seconds, Max RMS Voltage: Phase A 147.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 397 seconds, Max RMS Voltage: Phase A 145.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 463 seconds, Max RMS Voltage: Phase A 145.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 329 seconds, Max RMS Voltage: Phase A 144.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 467 seconds, Max RMS Voltage: Phase A 147.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 1 seconds, Max RMS Voltage: Phase A 134.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 418 seconds, Max RMS Voltage: Phase A 147.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 1 seconds, Max RMS Voltage: Phase A 134.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 367 seconds, Max RMS Voltage: Phase A 146.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 30 seconds, Max RMS Voltage: Phase A 135.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 386 seconds, Max RMS Voltage: Phase A 146.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 31 seconds, Max RMS Voltage: Phase A 133.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 385 seconds, Max RMS Voltage: Phase A 147.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 369 seconds, Max RMS Voltage: Phase A 146.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 472 seconds, Max RMS Voltage: Phase A 146.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 331 seconds, Max RMS Voltage: Phase A 146.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:12:f5:b1. Duration: 31 seconds, Max RMS Voltage: Phase A 137.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 12 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 16 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 19 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 56 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 93 seconds, Max RMS Voltage: Phase A 254.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 5 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 114 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 25 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 3 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 59 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 2 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 8 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 21 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 125 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 1 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 3 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 6 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 4 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 7 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 5 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 7 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 52 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 2 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 136 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 30 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 6 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 1 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 17 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 245 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 12 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 10 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 67 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 17 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 89 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 4 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 13 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 46 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:c0:c9. Duration: 10 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:36:53:b4. Duration: 30 seconds, Max RMS Voltage: Phase A 258.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 10 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 6 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 2 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 656 seconds, Max RMS Voltage: Phase A 257.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 41 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 26 seconds, Max RMS Voltage: Phase A 254.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 1 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 24 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 18 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 77 seconds, Max RMS Voltage: Phase A 255.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 5 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 33 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 131 seconds, Max RMS Voltage: Phase A 255.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 10 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 14 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 4 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 9 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 3 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 25 seconds, Max RMS Voltage: Phase A 254.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 3 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 14 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 16 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 8 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 7 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 11 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 183 seconds, Max RMS Voltage: Phase A 255.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 9 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 65 seconds, Max RMS Voltage: Phase A 255.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 4 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 95 seconds, Max RMS Voltage: Phase A 255.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 15 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 61 seconds, Max RMS Voltage: Phase A 255.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 27 seconds, Max RMS Voltage: Phase A 255.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 8 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 37 seconds, Max RMS Voltage: Phase A 255.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 17 seconds, Max RMS Voltage: Phase A 255.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 22 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 11 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 3 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 59 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 23 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 13 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 6 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 59 seconds, Max RMS Voltage: Phase A 255.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 12 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 13 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 2 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 55 seconds, Max RMS Voltage: Phase A 255.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 21 seconds, Max RMS Voltage: Phase A 255.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 2 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 12 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 6 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 4 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 38 seconds, Max RMS Voltage: Phase A 254.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 5 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 8 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 343 seconds, Max RMS Voltage: Phase A 255.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 20 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 12 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 42 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 16 seconds, Max RMS Voltage: Phase A 255.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 17 seconds, Max RMS Voltage: Phase A 254.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 60 seconds, Max RMS Voltage: Phase A 255.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 29 seconds, Max RMS Voltage: Phase A 255.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 17 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 40 seconds, Max RMS Voltage: Phase A 255.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 142 seconds, Max RMS Voltage: Phase A 255.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 34 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 10 seconds, Max RMS Voltage: Phase A 254.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 347 seconds, Max RMS Voltage: Phase A 255.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 31 seconds, Max RMS Voltage: Phase A 255.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 77 seconds, Max RMS Voltage: Phase A 255.2 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 26 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 62 seconds, Max RMS Voltage: Phase A 255.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 51 seconds, Max RMS Voltage: Phase A 255.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 31 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 32 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 62 seconds, Max RMS Voltage: Phase A 254.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 33 seconds, Max RMS Voltage: Phase A 254.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 54 seconds, Max RMS Voltage: Phase A 255.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 54 seconds, Max RMS Voltage: Phase A 254.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 5 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 15 seconds, Max RMS Voltage: Phase A 254.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 30 seconds, Max RMS Voltage: Phase A 255.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 59 seconds, Max RMS Voltage: Phase A 255.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 100 seconds, Max RMS Voltage: Phase A 255.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2a:66:ad. Duration: 3 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2e:10:b4. Duration: 7 seconds, Max RMS Voltage: Phase A 255.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2e:10:b4. Duration: 1 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:25:68:1b. Duration: 4 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:25:68:1b. Duration: 5 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:25:68:1b. Duration: 1 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:3d:0f:ec. Duration: 66 seconds, Max RMS Voltage: Phase A 258.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:2b:6d:c4. Duration: 182 seconds, Max RMS Voltage: Phase A 144.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:3d:0f:ec. Duration: 67 seconds, Max RMS Voltage: Phase A 258.3 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:00:18:9b. Duration: 1 seconds, Max RMS Voltage: Phase A 268.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:44:7c:5a. Duration: 92 seconds, Max RMS Voltage: Phase A 266.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:44:7c:5a. Duration: 76 seconds, Max RMS Voltage: Phase A 266.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:05:ff:05:b4:79. Duration: 45 seconds, Max RMS Voltage: Phase A 256.1 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:04:b0:68. Duration: 88 seconds, Max RMS Voltage: Phase A 264.0 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 1 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 6 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 87 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 1147 seconds, Max RMS Voltage: Phase A 255.4 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 3 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 4 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 7 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 2 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 4 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 5 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 6 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 30 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 19 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 1 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 5 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 3 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 2 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 23 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 50 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 2 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 10 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 22 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 12 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 8 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 23 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 89 seconds, Max RMS Voltage: Phase A 254.9 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 5 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 13 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 14 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 10 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 14327 seconds, Max RMS Voltage: Phase A 256.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 9 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 7 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 11 seconds, Max RMS Voltage: Phase A 254.5 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 43 seconds, Max RMS Voltage: Phase A 254.7 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 21 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 55 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 8 seconds, Max RMS Voltage: Phase A 254.6 V, RMS Current (at max voltage): Phase A 0.0 A'
#  'Detected end of voltage swell on meter 00:13:50:03:ff:01:d1:1b. Duration: 61 seconds, Max RMS Voltage: Phase A 254.8 V, RMS Current (at max voltage): Phase A 0.0 A']

# %%
curated_reasons = []
for reason_i in df_3_21_43_248['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.21.43.248']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Detected end of voltage swell

# %% [markdown]
# # '3.21.67.28'

# %%
df_3_21_67_28 = pd.read_pickle(ids_with_paths_dict['3.21.67.28'])
#-----
print(f"shape[0] = {df_3_21_67_28.shape[0]}")
print(f"# Unique reasons = {df_3_21_67_28['reason'].nunique()}")
print(df_3_21_67_28['reason'].unique())
# Out:
# shape[0] = 1509
# # Unique reasons = 36
# ['Measurement Error cleared for meter 00:13:50:03:ff:06:10:15.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:07:c0:55.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:0f:0c:b6.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:0b:87:fc.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:02:7a:f9.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:1b:35:ed.'
#  'Measurement Error cleared for meter 00:13:50:02:00:03:69:e3.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:0f:74:8d.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:04:1a:66.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:07:ba:b9.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:0b:86:38.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:1f:c7:11.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:0b:7f:f7.'
#  'Measurement Error cleared for meter 00:13:50:03:ff:02:2b:d0.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:02:91:b4.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:0d:dd:17.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:02:91:97.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:2c:f9:98.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:0b:89:ac.'
#  'Measurement Error cleared for meter 00:13:50:03:ff:02:1f:b8.'
#  'Measurement Error cleared for meter 00:13:50:03:ff:02:30:97.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:11:82:c2.'
#  'Measurement Error cleared for meter 00:13:50:03:ff:06:16:77.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:15:af:91.'
#  'Measurement Error cleared for meter 00:13:50:03:ff:06:0d:f6.'
#  'Measurement Error cleared for meter 00:13:50:03:ff:06:24:2b.'
#  'Measurement Error cleared for meter 00:13:50:03:ff:02:2c:a3.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:32:67:85.'
#  'Measurement Error cleared for meter 00:13:50:03:ff:06:d6:d5.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:02:7f:04.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:02:68:cb.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:0a:d1:e6.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:11:74:04.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:2c:f3:e2.'
#  'Measurement Error cleared for meter 00:13:50:03:ff:02:1d:8a.'
#  'Measurement Error cleared for meter 00:13:50:05:ff:44:c7:b1.']

# %%
curated_reasons = []
for reason_i in df_3_21_67_28['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.21.67.28']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Measurement Error cleared

# %% [markdown]
# # '3.21.67.79'

# %%
df_3_21_67_79 = pd.read_pickle(ids_with_paths_dict['3.21.67.79'])
#-----
print(f"shape[0] = {df_3_21_67_79.shape[0]}")
print(f"# Unique reasons = {df_3_21_67_79['reason'].nunique()}")
print(df_3_21_67_79['reason'].unique())
# Out:
# shape[0] = 45365
# # Unique reasons = 24035
# ['Meter event Measurement Error Detected  Time event occurred on meter = 01/01/2020 05:02:43  Sequence number = 241  User id = 0  Event argument = 00-00'
#  'Meter event Measurement Error Detected  Time event occurred on meter = 01/01/2020 20:51:18  Sequence number = 1878  User id = 0  Event argument = 00-00'
#  'Meter event Measurement Error Detected  Time event occurred on meter = 01/01/2020 07:56:50  Sequence number = 242  User id = 0  Event argument = 00-00'
#  ...
#  'Meter event Measurement Error Detected  Time event occurred on meter = 03/14/2023 02:00:56  Sequence number = 3953  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 03/14/2023 03:27:02  Sequence number = 3954  User id = 0  Event argument = 00-00 '
#  'Meter event Measurement Error Detected  Time event occurred on meter = 9/12/2023 6:06:57 AM  Sequence number = 89  User id = 34891  Event argument = 7D-75']

# %%
curated_reasons = []
for reason_i in df_3_21_67_79['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.21.67.79']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Measurement Error (C1219 Table 3)
# Measurement Error (C1219 Table 3: Er100000)
# Meter event Measurement Error Detected

# %% [markdown]
# # '3.21.82.28'

# %%
df_3_21_82_28 = pd.read_pickle(ids_with_paths_dict['3.21.82.28'])
#-----
print(f"shape[0] = {df_3_21_82_28.shape[0]}")
print(f"# Unique reasons = {df_3_21_82_28['reason'].nunique()}")
print(df_3_21_82_28['reason'].unique())
# Out:
# shape[0] = 62
# # Unique reasons = 19
# ['DSP Error cleared for meter 00:13:50:05:ff:0b:87:fc.'
#  'DSP Error cleared for meter 00:13:50:05:ff:1b:35:ed.'
#  'DSP Error cleared for meter 00:13:50:05:ff:0f:74:8d.'
#  'DSP Error cleared for meter 00:13:50:02:00:03:69:e3.'
#  'DSP Error cleared for meter 00:13:50:05:ff:15:af:91.'
#  'DSP Error cleared for meter 00:13:50:05:ff:07:ba:b9.'
#  'DSP Error cleared for meter 00:13:50:05:ff:13:c0:a6.'
#  'DSP Error cleared for meter 00:13:50:05:ff:0f:0c:b6.'
#  'DSP Error cleared for meter 00:13:50:05:ff:1f:c7:11.'
#  'DSP Error cleared for meter 00:13:50:03:ff:02:2b:d0.'
#  'DSP Error cleared for meter 00:13:50:05:ff:02:91:97.'
#  'DSP Error cleared for meter 00:13:50:03:ff:06:3c:37.'
#  'DSP Error cleared for meter 00:13:50:05:ff:23:a7:ab.'
#  'DSP Error cleared for meter 00:13:50:03:ff:06:0d:f6.'
#  'DSP Error cleared for meter 00:13:50:05:ff:11:7d:2f.'
#  'DSP Error cleared for meter 00:13:50:05:ff:02:7f:04.'
#  'DSP Error cleared for meter 00:13:50:05:ff:02:68:cb.'
#  'DSP Error cleared for meter 00:13:50:05:ff:26:32:45.'
#  'DSP Error cleared for meter 00:13:50:05:ff:2c:f3:e2.']

# %%
curated_reasons = []
for reason_i in df_3_21_82_28['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.21.82.28']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# DSP Error cleared

# %% [markdown]
# # '3.21.82.79'

# %%
df_3_21_82_79 = pd.read_pickle(ids_with_paths_dict['3.21.82.79'])
#-----
print(f"shape[0] = {df_3_21_82_79.shape[0]}")
print(f"# Unique reasons = {df_3_21_82_79['reason'].nunique()}")
print(df_3_21_82_79['reason'].unique())
# Out:
# shape[0] = 83
# # Unique reasons = 32
# ['DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:15:af:91.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:0b:87:fc.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:1b:35:ed.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:02:00:03:69:e3.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:04:1a:66.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:13:c0:a6.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:07:ba:b9.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:13:bb:db.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:0f:0c:b6.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:03:ff:02:1f:cb.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:03:ff:06:78:70.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:1f:c7:11.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:0f:0e:34.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:03:ff:02:2b:d0.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:03:ff:02:26:bb.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:02:91:97.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:23:a7:ab.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:03:ff:02:2b:f9.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:03:ff:06:23:75.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:03:ff:06:0d:f6.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:02:89:eb.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:03:ff:02:2e:95.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:03:ff:06:24:2b.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:06:64:d4.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:0f:10:87.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:11:7d:2f.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:02:7f:04.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:1e:63:80.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:26:32:45.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:02:68:cb.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:03:ff:02:28:44.'
#  'DSP Error (C1219 Table 3: Er200000) occurred for meter 00:13:50:05:ff:2c:f3:e2.']

# %%
curated_reasons = []
for reason_i in df_3_21_82_79['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.21.82.79']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# DSP Error (C1219 Table 3: Er200000)

# %% [markdown]
# # '3.22.12.243'

# %%
df_3_22_12_243 = pd.read_pickle(ids_with_paths_dict['3.22.12.243'])
#-----
print(f"shape[0] = {df_3_22_12_243.shape[0]}")
print(f"# Unique reasons = {df_3_22_12_243['reason'].nunique()}")
print(df_3_22_12_243['reason'].unique())
# Out:
# shape[0] = 45
# # Unique reasons = 45
# ['Meter event Test Mode Stopped  Time event occurred on meter = 08/27/2021 10:04:04  Sequence number = 23834  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/30/2021 09:27:50  Sequence number = 2442  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/30/2021 10:57:32  Sequence number = 1465  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/30/2021 19:49:10  Sequence number = 296  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/30/2021 11:52:44  Sequence number = 1915  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/24/2021 15:11:30  Sequence number = 2515  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/24/2021 09:14:08  Sequence number = 55  User id = 349  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/30/2021 03:34:07  Sequence number = 126  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/30/2021 03:34:32  Sequence number = 131  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/30/2021 03:35:02  Sequence number = 139  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/30/2021 03:31:26  Sequence number = 121  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/30/2021 03:34:34  Sequence number = 135  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/25/2021 15:09:05  Sequence number = 3290  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/25/2021 08:07:27  Sequence number = 2630  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/25/2021 11:33:58  Sequence number = 2964  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/25/2021 13:24:15  Sequence number = 3000  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/25/2021 13:57:56  Sequence number = 2749  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/26/2021 01:42:05  Sequence number = 713  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/25/2021 14:24:38  Sequence number = 246  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/25/2021 10:31:54  Sequence number = 7232  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/31/2021 09:14:01  Sequence number = 80  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/31/2021 10:38:24  Sequence number = 105  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/31/2021 12:40:18  Sequence number = 1681  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/31/2021 12:48:19  Sequence number = 1683  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/31/2021 12:55:45  Sequence number = 1685  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/31/2021 09:25:00  Sequence number = 82  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/31/2021 10:45:37  Sequence number = 107  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/26/2021 13:17:42  Sequence number = 183  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/26/2021 13:17:44  Sequence number = 187  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/26/2021 13:17:45  Sequence number = 191  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/26/2021 13:27:05  Sequence number = 195  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/26/2021 08:57:27  Sequence number = 2728  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/26/2021 10:31:33  Sequence number = 53591  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/26/2021 09:58:29  Sequence number = 19177  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/26/2021 13:36:31  Sequence number = 199  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 08/26/2021 14:05:52  Sequence number = 212  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 09/01/2021 11:06:01  Sequence number = 3134  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 09/01/2021 09:34:33  Sequence number = 3085  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 09/01/2021 11:17:48  Sequence number = 7340  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 09/01/2021 09:03:55  Sequence number = 3094  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 09/01/2021 13:00:02  Sequence number = 3164  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 09/01/2021 09:24:51  Sequence number = 26494  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 09/01/2021 10:53:51  Sequence number = 3132  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 09/01/2021 10:39:49  Sequence number = 3222  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Stopped  Time event occurred on meter = 09/01/2021 10:02:30  Sequence number = 4246  User id = 1  Event argument = 00-00 ']

# %%
curated_reasons = []
for reason_i in df_3_22_12_243['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.22.12.243']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter event Test Mode Stopped

# %% [markdown]
# # '3.22.19.242'

# %%
df_3_22_19_242 = pd.read_pickle(ids_with_paths_dict['3.22.19.242'])
#-----
print(f"shape[0] = {df_3_22_19_242.shape[0]}")
print(f"# Unique reasons = {df_3_22_19_242['reason'].nunique()}")
print(df_3_22_19_242['reason'].unique())
# Out:
# shape[0] = 50
# # Unique reasons = 50
# ['Meter event Test Mode Started  Time event occurred on meter = 08/30/2021 03:31:25  Sequence number = 119  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/30/2021 03:33:55  Sequence number = 124  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/30/2021 03:34:32  Sequence number = 129  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/30/2021 03:34:34  Sequence number = 133  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/30/2021 03:34:35  Sequence number = 137  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/30/2021 19:49:09  Sequence number = 294  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/30/2021 09:26:38  Sequence number = 2441  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/30/2021 13:30:17  Sequence number = 3844  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/30/2021 10:50:18  Sequence number = 1464  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/30/2021 11:51:22  Sequence number = 1914  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/31/2021 09:05:07  Sequence number = 79  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/31/2021 09:17:54  Sequence number = 81  User id = 658  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/31/2021 12:29:57  Sequence number = 1680  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/31/2021 12:43:48  Sequence number = 1682  User id = 658  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/31/2021 12:49:35  Sequence number = 1684  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/31/2021 10:31:17  Sequence number = 104  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/31/2021 10:40:01  Sequence number = 106  User id = 658  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/25/2021 15:02:46  Sequence number = 3288  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/25/2021 07:57:32  Sequence number = 2627  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/25/2021 10:27:43  Sequence number = 7227  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/26/2021 00:41:06  Sequence number = 711  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/25/2021 11:32:03  Sequence number = 2963  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/25/2021 13:18:31  Sequence number = 2999  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/25/2021 14:22:04  Sequence number = 243  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/25/2021 14:52:34  Sequence number = 3469  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/25/2021 13:55:00  Sequence number = 2748  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/26/2021 13:17:45  Sequence number = 189  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/26/2021 13:29:04  Sequence number = 197  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/26/2021 13:36:40  Sequence number = 202  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/26/2021 08:56:08  Sequence number = 2727  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/26/2021 09:51:09  Sequence number = 19174  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/26/2021 13:17:42  Sequence number = 181  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/26/2021 13:17:43  Sequence number = 185  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/26/2021 09:02:02  Sequence number = 23934  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/26/2021 10:28:38  Sequence number = 53586  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/27/2021 07:48:19  Sequence number = 765  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/27/2021 10:31:08  Sequence number = 643  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/27/2021 09:56:38  Sequence number = 23830  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 08/27/2021 08:45:42  Sequence number = 951  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 09/01/2021 09:23:26  Sequence number = 26493  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 09/01/2021 10:33:59  Sequence number = 3221  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 09/01/2021 09:46:00  Sequence number = 4671  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 09/01/2021 10:45:06  Sequence number = 3131  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 09/01/2021 10:53:53  Sequence number = 3133  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 09/01/2021 11:16:14  Sequence number = 7339  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 09/01/2021 10:01:05  Sequence number = 4245  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 09/01/2021 12:54:47  Sequence number = 3163  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 09/01/2021 09:33:06  Sequence number = 3084  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 09/01/2021 09:02:38  Sequence number = 3093  User id = 1  Event argument = 00-00 '
#  'Meter event Test Mode Started  Time event occurred on meter = 09/01/2021 14:47:20  Sequence number = 3898  User id = 1  Event argument = 00-00 ']

# %%
curated_reasons = []
for reason_i in df_3_22_19_242['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.22.19.242']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter event Test Mode Started

# %% [markdown]
# # '3.23.17.139'

# %%
df_3_23_17_139 = pd.read_pickle(ids_with_paths_dict['3.23.17.139'])
#-----
print(f"shape[0] = {df_3_23_17_139.shape[0]}")
print(f"# Unique reasons = {df_3_23_17_139['reason'].nunique()}")
print(df_3_23_17_139['reason'].unique())
# Out:
# shape[0] = 29863
# # Unique reasons = 28303
# ['Device 00:13:50:05:ff:19:7b:be has been determined to have exceeded the max allowable trap threshold, 20, within a certain time limit, 3600 seconds.'
#  'Device 00:13:50:05:ff:20:91:89 has been determined to have exceeded the max allowable trap threshold, 20, within a certain time limit, 3600 seconds.'
#  'Device 00:13:50:05:ff:20:8f:67 has been determined to have exceeded the max allowable trap threshold, 20, within a certain time limit, 3600 seconds.'
#  ...
#  'Device 00:13:50:05:ff:2f:50:53 has been determined to have exceeded the max allowable trap threshold, 20, within a certain time limit, 3600 seconds.'
#  'Device 00:13:50:05:ff:2b:30:b1 has been determined to have exceeded the max allowable trap threshold, 20, within a certain time limit, 3600 seconds.'
#  'Device 00:13:50:05:ff:44:9c:d8 has been determined to have exceeded the max allowable trap threshold, 20, within a certain time limit, 3600 seconds.']

# %%
curated_reasons = []
for reason_i in df_3_23_17_139['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.23.17.139']
    )
#     if curated_reason_i != 'Primary Power Up occurred for meter':
#         print(curated_reason_i)
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Device exceeded the max allowable trap threshold

# %% [markdown]
# # '3.23.136.47'

# %%
df_3_23_136_47 = pd.read_pickle(ids_with_paths_dict['3.23.136.47'])
#-----
print(f"shape[0] = {df_3_23_136_47.shape[0]}")
print(f"# Unique reasons = {df_3_23_136_47['reason'].nunique()}")
print(df_3_23_136_47['reason'].unique())
# Out:
# shape[0] = 189812
# # Unique reasons = 1506
# ['Access Point 00:13:50:09:ff:00:15:a9 has lost connectivity with FHSS 900 MHz band.'
#  'Access Point 00:13:50:08:ff:00:06:f7 has lost connectivity with FHSS 900 MHz band.'
#  'Access Point 00:13:50:08:ff:00:06:8f has lost connectivity with FHSS 900 MHz band.'
#  ...
#  'Access Point 00:13:50:09:ff:00:14:c0 has lost connectivity with FHSS 900 MHz band.'
#  'Access Point 00:13:50:09:ff:00:1d:9b has lost connectivity with FHSS 900 MHz band.'
#  'Access Point 00:13:50:09:ff:00:1d:cc has lost connectivity with FHSS 900 MHz band.']

# %% [markdown]
# # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
curated_reasons = []
for reason_i in df_3_23_136_47['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.23.136.47']
    )
#     if curated_reason_i != 'Primary Power Up occurred for meter':
#         print(curated_reason_i)
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Access Point has lost connectivity with FHSS 900 MHz band.

# %% [markdown]
# # '3.23.136.85'

# %%
df_3_23_136_85 = pd.read_pickle(ids_with_paths_dict['3.23.136.85'])
#-----
print(f"shape[0] = {df_3_23_136_85.shape[0]}")
print(f"# Unique reasons = {df_3_23_136_85['reason'].nunique()}")
print(df_3_23_136_85['reason'].unique())
# Out:
# shape[0] = 2595861
# # Unique reasons = 178557
# ['NIC Link Layer Handshake Failed: Device: 00:13:50:ff:fe:70:9c:a3, Rejected neighbor Mac ID: 00:13:50:05:ff:17:77:e3, Rejection Cause: invalid birth certificate'
#  'NIC Link Layer Handshake Failed: Device: 00:13:50:03:ff:01:e0:8a, Rejected neighbor Mac ID: 00:13:50:ff:fe:11:e6:bf, Rejection Cause: invalid eblob signature'
#  'NIC Link Layer Handshake Failed: Device: 00:13:50:05:ff:1b:f5:1d, Rejected neighbor Mac ID: 00:13:50:ff:fe:11:b9:55, Rejection Cause: invalid eblob signature'
#  ...
#  'NIC Link Layer Handshake Failed: Device: 00:13:50:05:ff:01:97:87, Rejected neighbor Mac ID: 00:13:50:05:ff:05:a9:69, Rejection Cause: invalid eblob signature'
#  'NIC Link Layer Handshake Failed: Device: 00:13:50:05:ff:1f:ad:27, Rejected neighbor Mac ID: 00:13:50:05:ff:0a:75:9d, Rejection Cause: invalid eblob signature'
#  'NIC Link Layer Handshake Failed: Device: 00:13:50:05:ff:0d:0b:ce, Rejected neighbor Mac ID: 00:13:50:05:ff:04:60:74, Rejection Cause: invalid eblob signature']

# %%
curated_reasons = []
for reason_i in df_3_23_136_85['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.23.136.85']
    )
#     if curated_reason_i != 'Primary Power Up occurred for meter':
#         print(curated_reason_i)
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Device Failed: Reason: unknown (0x6)
# Device Failed: Reason: Security public key mismatch
# NIC Link Layer Handshake Failed: Rejection Cause: invalid eblob signature
# NIC Link Layer Handshake Failed: Rejection Cause: invalid birth certificate
# NIC Link Layer Handshake Failed: Rejection Cause: invalid dl chain cert
# Device Failed: Reason: unknown (0x4)
# NIC Link Layer Handshake Failed: Rejection Cause: invalid mfg cert

# %% [markdown]
# # '3.25.17.3'

# %%
df_3_25_17_3 = pd.read_pickle(ids_with_paths_dict['3.25.17.3'])
#-----
print(f"shape[0] = {df_3_25_17_3.shape[0]}")
print(f"# Unique reasons = {df_3_25_17_3['reason'].nunique()}")
print(df_3_25_17_3['reason'].unique())
# Out:
# shape[0] = 3331524
# # Unique reasons = 1
# ['Meter generated an energy polarity gyrbox call in event.']

# %%
curated_reasons = []
for reason_i in df_3_25_17_3['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.25.17.3']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter generated an energy polarity gyrbox call in event

# %% [markdown]
# # '3.26.0.47'

# %%
df_3_26_0_47 = pd.read_pickle(ids_with_paths_dict['3.26.0.47'])
#-----
print(f"shape[0] = {df_3_26_0_47.shape[0]}")
print(f"# Unique reasons = {df_3_26_0_47['reason'].nunique()}")
print(df_3_26_0_47['reason'].unique())
# Out:
# shape[0] = 3900000
# # Unique reasons = 1598399
# ['Primary Power Down occurred for meter 00:13:50:05:ff:24:1a:d2.'
#  'Primary Power Down occurred for meter 00:13:50:05:ff:19:31:63.'
#  'Primary Power Down occurred for meter 00:13:50:01:00:dd:58:40.' ...
#  'Primary Power Down occurred for meter 00:13:50:05:ff:4a:32:bc.'
#  'Primary Power Down occurred for meter 00:13:50:05:ff:48:24:47.'
#  'Primary Power Down occurred for meter 00:13:50:05:ff:47:b2:1d.']

# %%
curated_reasons = []
for reason_i in df_3_26_0_47['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.26.0.47']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter had a power outage (Unsafe power fail)
# Meter event Primary Power Down
# Primary Power Down

# %% [markdown]
# # '3.26.0.216'

# %%
df_3_26_0_216 = pd.read_pickle(ids_with_paths_dict['3.26.0.216'])
#-----
print(f"shape[0] = {df_3_26_0_216.shape[0]}")
print(f"# Unique reasons = {df_3_26_0_216['reason'].nunique()}")
print(df_3_26_0_216['reason'].unique())
# Out:
# shape[0] = 3900000
# # Unique reasons = 1651018
# ['Primary Power Up occurred for meter 00:13:50:05:ff:10:92:05.'
#  'Primary Power Up occurred for meter 00:13:50:05:ff:15:bd:c8.'
#  'Primary Power Up occurred for meter 00:13:50:05:ff:23:e4:bf.' ...
#  'Primary Power Up occurred for meter 00:13:50:05:ff:41:42:d2.'
#  'Primary Power Up occurred for meter 00:13:50:05:ff:4b:68:f2.'
#  'Primary Power Up occurred for meter 00:13:50:05:ff:40:08:a8.']

# %%
curated_reasons = []
for reason_i in df_3_26_0_216['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.26.0.216']
    )
#     if curated_reason_i != 'Primary Power Up occurred for meter':
#         print(curated_reason_i)
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Primary Power Up

# %% [markdown]
# # '3.26.17.185'

# %%
df_3_26_17_185 = pd.read_pickle(ids_with_paths_dict['3.26.17.185'])
#-----
print(f"shape[0] = {df_3_26_17_185.shape[0]}")
print(f"# Unique reasons = {df_3_26_17_185['reason'].nunique()}")
print(df_3_26_17_185['reason'].unique())
# Out:
# shape[0] = 5854
# # Unique reasons = 2412
# ['Meter had a power outage. Unsafe power fail count = 45969'
#  'Meter had a power outage. Unsafe power fail count = 415'
#  'Meter had a power outage. Unsafe power fail count = 1' ...
#  'Meter had a power outage. Unsafe power fail count = 2306'
#  'Meter had a power outage. Unsafe power fail count = 6726'
#  'Meter had a power outage. Unsafe power fail count = 1450']

# %%
curated_reasons = []
for reason_i in df_3_26_17_185['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.26.17.185']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter event Primary Power Down
# Meter had a power outage (Unsafe power fail)

# %% [markdown]
# # '3.26.17.216'

# %%
df_3_26_17_216 = pd.read_pickle(ids_with_paths_dict['3.26.17.216'])
#-----
print(f"shape[0] = {df_3_26_17_216.shape[0]}")
print(f"# Unique reasons = {df_3_26_17_216['reason'].nunique()}")
print(df_3_26_17_216['reason'].unique())
# Out:
# shape[0] = 1
# # Unique reasons = 1
# ['Meter event Primary Power Up  Time event occurred on meter = 08/31/2021 20:07:44  Sequence number = 104  User id = 0  Event argument = 00-00 ']

# %%
curated_reasons = []
for reason_i in df_3_26_17_216['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.26.17.216']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Primary Power Up

# %% [markdown]
# # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# # '3.26.38.37'

# %%
df_3_26_38_37 = pd.read_pickle(ids_with_paths_dict['3.26.38.37'])
#-----
print(f"shape[0] = {df_3_26_38_37.shape[0]}")
print(f"# Unique reasons = {df_3_26_38_37['reason'].nunique()}")
print(df_3_26_38_37['reason'].unique())
# Out:
# shape[0] = 3900000
# # Unique reasons = 89431
# ['Under Voltage cleared (CA000400) for meter 00:13:50:05:ff:0b:88:ec.'
#  'Under Voltage (CA000400) cleared for meter 00:13:50:05:ff:0c:79:88.'
#  'Under Voltage (CA000400) cleared for meter 00:13:50:01:00:e3:db:2b.' ...
#  'Low Potential cleared for meter 00:13:50:05:ff:1b:3a:81.'
#  'Under Voltage cleared (CA000400) for meter 00:13:50:05:ff:1b:68:84.'
#  'Low Potential cleared for meter 00:13:50:05:ff:1b:68:84.']

# %%
curated_reasons = []
for reason_i in df_3_26_38_37['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.26.38.37']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Low Potential cleared
# Under Voltage (Diagnostic 6) cleared
# Diag6 Condition cleared
# Under Voltage (CA000400) cleared

# %% [markdown]
# # '3.26.38.47'

# %%
df_3_26_38_47 = pd.read_pickle(ids_with_paths_dict['3.26.38.47'])
#-----
print(f"shape[0] = {df_3_26_38_47.shape[0]}")
print(f"# Unique reasons = {df_3_26_38_47['reason'].nunique()}")
print(df_3_26_38_47['reason'].unique())
# Out:
# shape[0] = 1055446
# # Unique reasons = 106912
# ['Low Potential (C1219 Table 3) occurred for meter 00:13:50:05:ff:1b:67:3b.'
#  'Low Potential (C1219 Table 3) occurred for meter 00:13:50:05:ff:15:e8:3b.'
#  'Low Potential (C1219 Table 3) occurred for meter 00:13:50:05:ff:26:2d:3f.'
#  ...
#  'Low Potential (C1219 Table 3) occurred for meter 00:13:50:03:ff:02:32:93.'
#  'Low Potential (C1219 Table 3) occurred for meter 00:13:50:03:ff:03:0b:91.'
#  'Low Potential (C1219 Table 3) occurred for meter 00:13:50:05:ff:2c:e5:72.']

# %%
curated_reasons = []
for reason_i in df_3_26_38_47['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.26.38.47']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Low Potential (C1219 Table 3)

# %% [markdown]
# # '3.26.38.73'

# %%
df_3_26_38_73 = pd.read_pickle(ids_with_paths_dict['3.26.38.73'])
#-----
print(f"shape[0] = {df_3_26_38_73.shape[0]}")
print(f"# Unique reasons = {df_3_26_38_73['reason'].nunique()}")
print(df_3_26_38_73['reason'].unique())
# Out:
# shape[0] = 3298659
# # Unique reasons = 262681
# ['Diag7 Condition cleared for meter 00:13:50:02:00:0a:ff:36.'
#  'Diag7 Condition cleared for meter 00:13:50:05:ff:1b:59:d4.'
#  'Diag7 Condition cleared for meter 00:13:50:02:00:0b:01:e4.' ...
#  'Over Voltage (Diagnostic 7) cleared for meter 00:13:50:05:ff:13:d6:97N/A.'
#  'Over Voltage (Diagnostic 7) cleared for meter 00:13:50:05:ff:20:71:d0N/A.'
#  'Over Voltage (Diagnostic 7) cleared for meter 00:13:50:05:ff:20:8a:73N/A.']

# %%
curated_reasons = []
for reason_i in df_3_26_38_73['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.26.38.73']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Diag7 Condition cleared
# Over Voltage (Diagnostic 7) cleared

# %% [markdown]
# # '3.26.38.93'

# %%
df_3_26_38_93_1 = pd.read_pickle(ids_with_paths_dict['3.26.38.93'])
df_3_26_38_93_2 = pd.read_pickle(r'C:\Users\s346557\Documents\LocalData\dovs_and_end_events_data\regex_TX\sample_dfs\df_3_26_38_93.pkl')
df_3_26_38_93 = pd.concat([df_3_26_38_93_1, df_3_26_38_93_2])
#-----
print(f"shape[0] = {df_3_26_38_93.shape[0]}")
print(f"# Unique reasons = {df_3_26_38_93['reason'].nunique()}")
print(df_3_26_38_93['reason'].unique())
# Out:
# shape[0] = 4281627
# # Unique reasons = 189383
# ['KV2c meter event Over Voltage Diagnostic flags:Phase A Voltage'
#  'Diag7: Over Voltage, Element A occurred for meter 00:13:50:ff:fe:03:4e:12.'
#  'Diag7: Over Voltage, Element A occurred for meter 00:13:50:05:ff:04:35:4a.'
#  ...
#  'Over Voltage (Diagnostic 7) occurred for meter 00:13:50:05:ff:1b:c3:31: Phase A.'
#  'Over Voltage (Diagnostic 7) occurred for meter 00:13:50:05:ff:23:94:7d: Phase A.'
#  'KV2c meter event Over Voltage Diagnostic flags: Phase A Voltage ']

# %%
curated_reasons = []
for reason_i in df_3_26_38_93['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.26.38.93']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*natsorted(curated_reasons), sep='\n')
# Out:
# Diag7: Over Voltage, Element A
# KV2c meter event Over Voltage (Diagnostic flags = Phase A Voltage)
# KV2c meter event Received kWh (Diagnostic flags = Phase A Voltage)
# KV2c meter event Received kWh Cleared
# KV2c meter event Under Voltage (Diagnostic flags = Phase B Voltage)
# KV2c meter event Voltage Out of Tolerance (Diagnostic flags = Phase A Voltage)
# Over Voltage (Diagnostic 7) : Phase A.

# %% [markdown]
# # '3.26.38.150'

# %%
df_3_26_38_150 = pd.read_pickle(ids_with_paths_dict['3.26.38.150'])
#-----
print(f"shape[0] = {df_3_26_38_150.shape[0]}")
print(f"# Unique reasons = {df_3_26_38_150['reason'].nunique()}")
print(df_3_26_38_150['reason'].unique())
# Out:
# shape[0] = 390000
# # Unique reasons = 20949
# ['Under Voltage (CA000400) for meter 00:13:50:05:ff:0b:88:ec. Phase  C Voltage out of tolerance.'
#  'Under Voltage (CA000400) for meter 00:13:50:05:ff:0b:88:ec. Phase  A Voltage out of tolerance.'
#  'Under Voltage (CA000400) occurred for meter 00:13:50:05:ff:0d:10:85: Phase A.'
#  ...
#  'Under Voltage (CA000400) occurred for meter 00:13:50:05:ff:1e:e6:d6: Phase A.'
#  'Under Voltage (CA000400) occurred for meter 00:13:50:05:ff:1f:3b:3d: Phase C.'
#  'Under Voltage (CA000400) for meter 00:13:50:05:ff:49:11:14. Phase  A Voltage out of tolerance.']

# %%
curated_reasons = []
for reason_i in df_3_26_38_150['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.26.38.150']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Under Voltage (CA000400)  Phase  C Voltage out of tolerance.
# Under Voltage (CA000400)  Phase  A, B Voltage out of tolerance.
# KV2c meter event Under Voltage  (Diagnostic flags = Phase A Voltage)
# Diag6: Under Voltage, Element A
# Under Voltage (CA000400)  Phase A.
# Under Voltage (CA000400)  Phase  B, C Voltage out of tolerance.
# Under Voltage (CA000400)  Phase  B Voltage out of tolerance.
# Under Voltage (CA000400)  Phase  A Voltage out of tolerance.
# Under Voltage (CA000400)  Phase C.
# Under Voltage (CA000400)  Phase  A, B, C Voltage out of tolerance.
# Under Voltage (CA000400)  Phase A and C.
# Under Voltage (Diagnostic 6)  Phase A.
# Under Voltage (CA000400)  Phase  A, C Voltage out of tolerance.

# %% [markdown]
# # '3.26.136.47'

# %%
df_3_26_136_47 = pd.read_pickle(ids_with_paths_dict['3.26.136.47'])
#-----
print(f"shape[0] = {df_3_26_136_47.shape[0]}")
print(f"# Unique reasons = {df_3_26_136_47['reason'].nunique()}")
print(df_3_26_136_47['reason'].unique())
# Out:
# shape[0] = 390000
# # Unique reasons = 385739
# ['Last Gasp - NIC power lost for device: 00:13:50:05:ff:0b:83:e4, Reboot Count: 11900, NIC timestamp: 2020-01-05T15:26:48.000-05:00, Received timestamp: 2020-01-05T15:26:49.534-05:00, Fail Reason: [0x49] LG_ZERO_X_DETECTOR ,LG_DIRECT_NOTIFICATION'
#  'Last Gasp - NIC power lost for device: 00:13:50:01:00:dc:37:9b, Reboot Count: 143, NIC timestamp: 2020-01-05T15:10:53.000-05:00, Received timestamp: 2020-01-05T15:10:54.921-05:00, Fail Reason: [0x40] LG_DIRECT_NOTIFICATION'
#  'Last Gasp - NIC power lost for device: 00:13:50:05:ff:0b:83:e4, Reboot Count: 11879, NIC timestamp: 2020-01-05T03:26:46.000-05:00, Received timestamp: 2020-01-05T03:26:49.286-05:00, Fail Reason: [0x49] LG_ZERO_X_DETECTOR ,LG_DIRECT_NOTIFICATION'
#  ...
#  'Last Gasp - NIC power lost for device: 00:13:50:05:ff:39:6a:77, Reboot Count: 12, NIC timestamp: 2023-03-10T22:18:22.000-05:00, Received timestamp: 2023-03-10T22:18:23.416-05:00, Fail Reason: [0x50] LG_PF_DETECTOR ,LG_DIRECT_NOTIFICATION'
#  'Last Gasp - NIC power lost for device: 00:13:50:09:ff:00:16:da, Reboot Count: 68, NIC timestamp: 2023-03-10T08:21:33.000-05:00, Received timestamp: 2023-03-10T08:21:33.535-05:00, Fail Reason: [0x10] LG_PF_DETECTOR'
#  'Last Gasp - NIC power lost for device: 00:13:50:05:ff:3a:44:a2, Reboot Count: 11, NIC timestamp: 2023-03-10T22:18:22.000-05:00, Received timestamp: 2023-03-10T22:18:24.059-05:00, Fail Reason: [0x50] LG_PF_DETECTOR ,LG_DIRECT_NOTIFICATION']

# %%
curated_reasons = []
for reason_i in df_3_26_136_47['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.26.136.47']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Last Gasp - NIC power lost for device, Fail Reason: [0x58] LG_ZERO_X_DETECTOR ,LG_PF_DETECTOR ,LG_DIRECT_NOTIFICA
# Last Gasp - NIC power lost for device, Fail Reason: [0x18] LG_ZERO_X_DETECTOR ,LG_PF_DETECTOR
# Last Gasp - NIC power lost for device, Fail Reason: [0x58] LG_ZERO_X_DETECTOR ,LG_PF_DETECTOR ,LG_DIRECT_NOTIFICATIO
# Last Gasp - NIC power lost for device, Fail Reason: [0x04]
# Last Gasp - NIC power lost for device, Fail Reason: [0x5A] LG_FLAG_FLASH_ERR ,LG_ZERO_X_DETECTOR ,LG_PF_DETECTOR ,L
# Last Gasp - NIC power lost for device, Fail Reason: [0x52] LG_FLAG_FLASH_ERR ,LG_PF_DETECTOR ,LG_DIRECT_NOTIFICATION
# Last Gasp - NIC power lost for device, Fail Reason: NIC power fail
# Last Gasp - NIC power lost for device, Fail Reason: [0x59] LG_ZERO_X_DETECTOR ,LG_PF_DETECTOR ,LG_DIRECT_NOTIFICATI
# Last Gasp - NIC power lost for device, Fail Reason: [0x51] LG_PF_DETECTOR ,LG_DIRECT_NOTIFICATION
# Last Gasp - NIC power lost for device, Fail Reason: Meter power fail
# Last Gasp - NIC power lost for device, Fail Reason: [0x58] LG_ZERO_X_DETECTOR ,LG_PF_DETECTOR ,LG_DIRECT_NOTIFICATI
# Last Gasp - NIC power lost for device, Fail Reason: [0x50] LG_PF_DETECTOR ,LG_DIRECT_NOTIFICATION
# Last Gasp - NIC power lost for device, Fail Reason: [0x49] LG_ZERO_X_DETECTOR ,LG_DIRECT_NOTIFICATION
# Last Gasp - NIC power lost for device, Fail Reason: [0x40] LG_DIRECT_NOTIFICATION
# Last Gasp - NIC power lost for device, Fail Reason: [0x00]
# Last Gasp - NIC power lost for device, Fail Reason: [0x58] LG_ZERO_X_DETECTOR ,LG_PF_DETECTOR ,LG_DIRECT_NOTIFICAT
# Last Gasp - NIC power lost for device, Fail Reason: [0xC1] LG_DIRECT_NOTIFICATION ,LG_FLAG_SIMULATE
# Last Gasp - NIC power lost for device, Fail Reason: [0x58] LG_ZERO_X_DETECTOR ,LG_PF_DETECTOR ,LG_DIRECT_NOTIFICATION
# Last Gasp - NIC power lost for device, Fail Reason: [0x48] LG_ZERO_X_DETECTOR ,LG_DIRECT_NOTIFICATION
# Last Gasp - NIC power lost for device, Fail Reason: [0x41] LG_DIRECT_NOTIFICATION
# Last Gasp - NIC power lost for device, Fail Reason: [0x10] LG_PF_DETECTOR
# Last Gasp - NIC power lost for device, Fail Reason: [0x08] LG_ZERO_X_DETECTOR
# Last Gasp - NIC power lost for device, Fail Reason: [0x59] LG_ZERO_X_DETECTOR ,LG_PF_DETECTOR ,LG_DIRECT_NOTIFICATIO
# Last Gasp - NIC power lost for device, Fail Reason: [0x01]

# %% [markdown]
# # '3.26.136.66'

# %%
df_3_26_136_66 = pd.read_pickle(ids_with_paths_dict['3.26.136.66'])
#-----
print(f"shape[0] = {df_3_26_136_66.shape[0]}")
print(f"# Unique reasons = {df_3_26_136_66['reason'].nunique()}")
print(df_3_26_136_66['reason'].unique())
# Out:
# shape[0] = 8502
# # Unique reasons = 8461
# ['Device 00:13:50:05:ff:01:3c:23, Last Gasp State: EL_EVENT_POWER_FAIL_DETECT_LG_DISABLED, Detector State: EL_EVENT_POWER_FAIL_DETECT_METER_PF_DISABLED, Reboot Count: 206'
#  'Device 00:13:50:03:ff:03:4a:ee, Last Gasp State: EL_EVENT_POWER_FAIL_DETECT_LG_DISABLED, Detector State: EL_EVENT_POWER_FAIL_DETECT_METER_PF_DISABLED, Reboot Count: 206'
#  'Device 00:13:50:05:ff:24:8a:92, Last Gasp State: EL_EVENT_POWER_FAIL_DETECT_LG_DISABLED, Detector State: EL_EVENT_POWER_FAIL_DETECT_METER_PF_DISABLED, Reboot Count: 148'
#  ...
#  'Device 00:13:50:05:ff:44:b9:86, Last Gasp State: EL_EVENT_POWER_FAIL_DETECT_LG_DISABLED, Detector State: EL_EVENT_POWER_FAIL_DETECT_NIC_ZX_DISABLED, Reboot Count: 132'
#  'Device 00:13:50:05:ff:44:bc:2c, Last Gasp State: EL_EVENT_POWER_FAIL_DETECT_LG_DISABLED, Detector State: EL_EVENT_POWER_FAIL_DETECT_NIC_ZX_DISABLED, Reboot Count: 107'
#  'Device 00:13:50:05:ff:44:cb:5b, Last Gasp State: EL_EVENT_POWER_FAIL_DETECT_LG_DISABLED, Detector State: EL_EVENT_POWER_FAIL_DETECT_NIC_ZX_DISABLED, Reboot Count: 190']

# %%
curated_reasons = []
for reason_i in df_3_26_136_66['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.26.136.66']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Last Gasp State: EL_EVENT_POWER_FAIL_DETECT_LG_DISABLED, Detector State: EL_EVENT_POWER_FAIL_ENABLED
# Last Gasp State: EL_EVENT_POWER_FAIL_DETECT_LG_ENABLED, Detector State: EL_EVENT_POWER_FAIL_ENABLED
# Last Gasp State: EL_EVENT_POWER_FAIL_DETECT_LG_DISABLED, Detector State: EL_EVENT_POWER_FAIL_DETECT_METER_PF_DISABLED
# Last Gasp State: EL_EVENT_POWER_FAIL_DETECT_LG_ENABLED, Detector State: EL_EVENT_POWER_FAIL_DETECT_METER_PF_DISABLED
# Last Gasp State: EL_EVENT_POWER_FAIL_DETECT_LG_DISABLED, Detector State: EL_EVENT_POWER_FAIL_DETECT_NIC_ZX_DISABLED

# %% [markdown]
# # '3.26.136.216'

# %%
df_3_26_136_216 = pd.read_pickle(ids_with_paths_dict['3.26.136.216'])
#-----
print(f"shape[0] = {df_3_26_136_216.shape[0]}")
print(f"# Unique reasons = {df_3_26_136_216['reason'].nunique()}")
print(df_3_26_136_216['reason'].unique())
# Out:
# shape[0] = 379187
# # Unique reasons = 376783
# ['NIC Power Restore Trap Received from device: 00:13:50:08:ff:00:01:e1, Reboot Count: 94, NIC timestamp: 2020-01-13T15:07:16.124-05:00, Received Timestamp: 2020-01-13T15:07:16.124-05:00, Power Restoration Timestamp: 2020-01-13T15:05:54.124-05:00, State: 4,p'
#  'NIC Power Restore Trap Received from device: 00:13:50:03:00:4a:73:98, Reboot Count: 193, NIC timestamp: 2020-01-13T21:31:37.000-05:00, Received Timestamp: 2020-01-13T21:31:38.794-05:00, Power Restoration Timestamp: 2020-01-13T21:31:24.000-05:00, State: 4,'
#  'NIC Power Restore Trap Received from device: 00:13:50:05:ff:0b:83:e4, Reboot Count: 12090, NIC timestamp: 2020-01-13T12:06:47.000-05:00, Received Timestamp: 2020-01-13T12:06:48.695-05:00, Power Restoration Timestamp: 2020-01-13T12:06:36.000-05:00, State:'
#  ...
#  'NIC Power Restore Trap Received from device: 00:13:50:05:ff:3b:da:72, Reboot Count: 30, NIC timestamp: 2023-03-10T10:26:26.000-05:00, Received Timestamp: 2023-03-10T10:26:30.695-05:00, Power Restoration Timestamp: 2023-03-10T10:26:10.000-05:00, State: 16'
#  'NIC Power Restore Trap Received from device: 00:13:50:05:ff:3f:7b:e7, Reboot Count: 9, NIC timestamp: 2023-03-10T10:26:25.000-05:00, Received Timestamp: 2023-03-10T10:26:30.706-05:00, Power Restoration Timestamp: 2023-03-10T10:26:11.000-05:00, State: 16'
#  'NIC Power Restore Trap Received from device: 00:13:50:05:ff:40:60:c5, Reboot Count: 46, NIC timestamp: 2023-03-10T10:26:26.000-05:00, Received Timestamp: 2023-03-10T10:26:30.945-05:00, Power Restoration Timestamp: 2023-03-10T10:26:10.000-05:00, State: 16']

# %%
curated_reasons = []
for reason_i in df_3_26_136_216['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.26.136.216']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# NIC Power Restore Trap Received from device

# %% [markdown]
# # '3.31.1.143'

# %%
df_3_31_1_143 = pd.read_pickle(ids_with_paths_dict['3.31.1.143'])
#-----
print(f"shape[0] = {df_3_31_1_143.shape[0]}")
print(f"# Unique reasons = {df_3_31_1_143['reason'].nunique()}")
print(df_3_31_1_143['reason'].unique())
# Out:
# shape[0] = 86691
# # Unique reasons = 1
# ['Meter assumed to be disconnected has reported Load side voltage indicating a potential case of tamper.']

# %%
curated_reasons = []
for reason_i in df_3_31_1_143['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.31.1.143']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter assumed to be disconnected has reported Load side voltage indicating a potential case of tamper

# %% [markdown]
# # '3.33.1.219'

# %%
df_3_33_1_219 = pd.read_pickle(ids_with_paths_dict['3.33.1.219'])
#-----
print(f"shape[0] = {df_3_33_1_219.shape[0]}")
print(f"# Unique reasons = {df_3_33_1_219['reason'].nunique()}")
print(df_3_33_1_219['reason'].unique())
# Out:
# shape[0] = 20000
# # Unique reasons = 2363
# ['Meter event Reverse Rotation Detected  Time event occurred on meter = 08/30/2021 04:25:38  Sequence number = 13124  User id = 0  Event argument = 00-00 '
#  'Meter event Reverse Rotation Detected  Time event occurred on meter = 08/30/2021 04:13:29  Sequence number = 3467  User id = 0  Event argument = 00-00 '
#  'Meter event Reverse Rotation Detected  Time event occurred on meter = 08/30/2021 04:27:33  Sequence number = 3468  User id = 0  Event argument = 00-00 '
#  ...
#  'Meter event Reverse Rotation Detected  Time event occurred on meter = 09/01/2021 18:21:05  Sequence number = 7992  User id = 0  Event argument = 00-00 '
#  'Meter event Reverse Rotation Detected  Time event occurred on meter = 09/01/2021 18:31:07  Sequence number = 89  User id = 0  Event argument = 00-00 '
#  'Meter event Reverse Rotation Detected  Time event occurred on meter = 09/01/2021 18:09:14  Sequence number = 452  User id = 0  Event argument = 00-00 ']

# %%
curated_reasons = []
for reason_i in df_3_33_1_219['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.33.1.219']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter event Reverse Rotation Detected

# %% [markdown]
# # '3.33.1.257'

# %%
df_3_33_1_257 = pd.read_pickle(ids_with_paths_dict['3.33.1.257'])
#-----
print(f"shape[0] = {df_3_33_1_257.shape[0]}")
print(f"# Unique reasons = {df_3_33_1_257['reason'].nunique()}")
print(df_3_33_1_257['reason'].unique())
# Out:
# shape[0] = 2147
# # Unique reasons = 158
# ['Meter detected a Tamper Attempt.'
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 09:35:22  Sequence number = 5881  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 10:37:31  Sequence number = 676  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 10:32:31  Sequence number = 5883  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 11:01:42  Sequence number = 677  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 12:19:13  Sequence number = 680  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 13:47:53  Sequence number = 4384  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 13:13:43  Sequence number = 682  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 13:28:01  Sequence number = 683  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 13:55:19  Sequence number = 685  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 14:00:21  Sequence number = 686  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 14:11:49  Sequence number = 687  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 14:26:04  Sequence number = 688  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 14:44:53  Sequence number = 689  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 12:33:47  Sequence number = 5887  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 13:21:35  Sequence number = 5889  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 15:14:43  Sequence number = 5199  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 16:44:19  Sequence number = 4386  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 15:56:50  Sequence number = 691  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 17:26:39  Sequence number = 13633  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 13:58:19  Sequence number = 5893  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 14:17:47  Sequence number = 5895  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 18:13:48  Sequence number = 13635  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 16:39:47  Sequence number = 5903  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 18:40:58  Sequence number = 5909  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 09:51:40  Sequence number = 785  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 11:42:00  Sequence number = 678  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 11:29:03  Sequence number = 5885  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 12:01:14  Sequence number = 679  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 13:02:56  Sequence number = 681  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 13:43:51  Sequence number = 684  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 15:08:10  Sequence number = 690  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 15:22:30  Sequence number = 5201  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 13:27:12  Sequence number = 5891  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 14:51:24  Sequence number = 5897  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 15:37:14  Sequence number = 5899  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 15:56:03  Sequence number = 5901  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 17:13:32  Sequence number = 5905  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 18:10:55  Sequence number = 5907  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 19:37:47  Sequence number = 4388  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/26/2021 22:02:14  Sequence number = 4390  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 15:35:44  Sequence number = 1244  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 16:11:22  Sequence number = 1246  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 17:21:34  Sequence number = 33279  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 18:53:07  Sequence number = 33281  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 19:11:02  Sequence number = 1252  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 20:34:04  Sequence number = 33283  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 20:11:07  Sequence number = 1254  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 21:11:33  Sequence number = 1256  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 23:47:28  Sequence number = 33287  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 14:16:49  Sequence number = 33275  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 15:49:08  Sequence number = 33277  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 17:11:02  Sequence number = 1248  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 18:10:48  Sequence number = 1250  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 22:08:08  Sequence number = 33285  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 22:11:12  Sequence number = 1258  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/30/2021 23:12:18  Sequence number = 1260  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 08:36:05  Sequence number = 1644  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 09:36:15  Sequence number = 1646  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 10:20:53  Sequence number = 342  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 11:20:35  Sequence number = 1650  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 11:50:34  Sequence number = 1652  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 12:32:03  Sequence number = 184  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 13:42:52  Sequence number = 1654  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 13:47:55  Sequence number = 1656  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 13:56:46  Sequence number = 1658  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 14:13:52  Sequence number = 1660  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 14:29:18  Sequence number = 1662  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 14:52:48  Sequence number = 1664  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 15:16:08  Sequence number = 1668  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 10:21:41  Sequence number = 1648  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 10:30:45  Sequence number = 344  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 12:08:15  Sequence number = 182  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 15:05:58  Sequence number = 1666  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 15:21:04  Sequence number = 1670  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 15:53:26  Sequence number = 1672  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/31/2021 16:23:29  Sequence number = 1674  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 08:39:03  Sequence number = 1167  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 09:29:23  Sequence number = 1169  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 10:32:35  Sequence number = 1173  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 11:08:12  Sequence number = 1175  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 11:33:04  Sequence number = 1177  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 12:22:34  Sequence number = 1183  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 14:02:40  Sequence number = 1189  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 14:33:25  Sequence number = 1193  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 14:38:07  Sequence number = 1195  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 15:24:45  Sequence number = 1199  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 15:13:12  Sequence number = 1090  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 15:32:35  Sequence number = 1201  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 15:36:07  Sequence number = 1203  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 09:35:02  Sequence number = 1171  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 12:04:19  Sequence number = 1179  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 12:14:50  Sequence number = 1181  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 12:33:32  Sequence number = 1185  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 13:36:13  Sequence number = 1187  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 14:22:20  Sequence number = 1191  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 14:59:48  Sequence number = 1088  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 15:19:21  Sequence number = 1197  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 15:39:08  Sequence number = 1092  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 16:04:00  Sequence number = 1205  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 16:35:23  Sequence number = 1094  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 16:32:48  Sequence number = 1207  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/25/2021 18:18:43  Sequence number = 1209  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/29/2021 13:45:05  Sequence number = 7309  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/29/2021 16:11:39  Sequence number = 7313  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/29/2021 16:32:42  Sequence number = 7314  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/29/2021 18:51:59  Sequence number = 9768  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/29/2021 21:39:01  Sequence number = 9770  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/29/2021 13:00:58  Sequence number = 9764  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/29/2021 14:29:22  Sequence number = 7310  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/29/2021 15:08:57  Sequence number = 7311  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/29/2021 16:00:30  Sequence number = 7312  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/29/2021 15:51:51  Sequence number = 9766  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/29/2021 17:17:13  Sequence number = 7315  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 08:45:05  Sequence number = 72  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 09:04:48  Sequence number = 74  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 12:39:00  Sequence number = 1143  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 13:41:00  Sequence number = 1149  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 13:57:17  Sequence number = 1151  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 14:30:33  Sequence number = 1153  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 15:11:39  Sequence number = 1157  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 16:12:33  Sequence number = 92  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 16:36:50  Sequence number = 1161  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 18:23:27  Sequence number = 207  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 07:56:54  Sequence number = 68  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 08:14:59  Sequence number = 70  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 09:19:13  Sequence number = 76  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 09:30:36  Sequence number = 78  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 10:31:44  Sequence number = 1135  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 10:11:49  Sequence number = 80  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 10:48:58  Sequence number = 1137  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 11:17:28  Sequence number = 1139  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 11:13:32  Sequence number = 82  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 11:40:26  Sequence number = 1141  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 12:12:07  Sequence number = 84  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 13:10:11  Sequence number = 1145  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 13:30:53  Sequence number = 1147  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 13:12:06  Sequence number = 86  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 14:12:08  Sequence number = 88  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 14:45:56  Sequence number = 1155  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 15:12:15  Sequence number = 90  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/28/2021 16:06:17  Sequence number = 1159  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/27/2021 13:40:31  Sequence number = 12548  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/27/2021 14:14:17  Sequence number = 416  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/27/2021 14:42:04  Sequence number = 12550  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/27/2021 15:47:53  Sequence number = 12552  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/27/2021 17:59:00  Sequence number = 12556  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/27/2021 17:45:52  Sequence number = 201  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/27/2021 19:18:13  Sequence number = 12558  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/27/2021 21:48:04  Sequence number = 12562  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/27/2021 05:39:51  Sequence number = 51805  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/27/2021 16:49:26  Sequence number = 12554  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/27/2021 18:07:48  Sequence number = 203  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/27/2021 18:32:44  Sequence number = 205  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/27/2021 20:31:53  Sequence number = 12560  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 08/27/2021 23:08:06  Sequence number = 12564  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 09/02/2021 02:55:25  Sequence number = 6940  User id = 0  Event argument = 00-00 '
#  'Meter event Tamper Attempt Suspected  Time event occurred on meter = 09/02/2021 03:44:30  Sequence number = 6942  User id = 0  Event argument = 00-00 ']

# %%
curated_reasons = []
for reason_i in df_3_33_1_257['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.33.1.257']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter event Tamper Attempt Suspected

# %% [markdown]
# # '3.35.0.28'

# %%
df_3_35_0_28 = pd.read_pickle(ids_with_paths_dict['3.35.0.28'])
#-----
print(f"shape[0] = {df_3_35_0_28.shape[0]}")
print(f"# Unique reasons = {df_3_35_0_28['reason'].nunique()}")
print(df_3_35_0_28['reason'].unique())
# Out:
# shape[0] = 1556
# # Unique reasons = 602
# ['Cleared: Meter 00:13:50:05:ff:1d:d8:4b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:11:69:bb detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:11:62:2a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:25:b5:ca detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:11:28:b4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:11:ab:8e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1e:ce:46 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:11:e8:cf detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1e:41:18 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:19:a6:f8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0c:a4:34 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1b:4b:c5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:17:f7:50 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1b:9c:dc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1e:53:8f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1c:16:c8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1e:56:ba detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:10:e6:18 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:17:e7:fb detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:15:1a:5c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:23:12:08 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:00:74:e5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:17:6d:b5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1e:5d:08 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:fc:1a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:18:22:3c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:25:14:68 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:b3:f3 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:13:4d:13 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:13:0d:6d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1d:b3:de detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:05:bd:85 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:04:d6:52 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:93:3e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:06:10:f0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:10:b0:7b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0f:a3:7c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:17:f9:bd detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:10:fd:7b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:03:ff:04:91:8a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:01:ba:b2 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:03:ff:03:0f:04 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:01:00:e3:db:2b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:22:97:cd detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:18:c0:28 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:17:8e:ad detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:53:50 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:7c:9d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:15:19:dc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:7a:9d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2d:1b:61 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:12:f1:ee detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:21:a8:18 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:11:8d:53 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1e:b9:0b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:c8:6e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:15:09:7a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:9a:8d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:02:00:9d:fb:eb detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:21:76:9c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:05:07:d5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:da:3e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1d:12:ab detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:25:10:b4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:24:d9:c8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1d:c9:f0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1c:fa:92 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:13:15:5a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:19:0c:e0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:13:32:b4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1c:30:53 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2b:40:22 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0e:47:82 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1b:d2:b3 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:09:6c:57 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:18:31:94 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:13:fb:53 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:00:34:8f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:01:38:0f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:27:49:e8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1d:06:bf detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1b:f5:d8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:10:09:de detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:02:00:9d:c2:dd detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:ef:2f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:13:73:3a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2d:2d:1f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:21:ed:fc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:a0:02 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:09:0a:d8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:00:07:5d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1d:b0:48 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:11:22:d4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2b:15:43 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:05:5c:4e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:13:08:83 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:19:28:13 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2d:24:08 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1b:d3:ba detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2b:3c:35 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0f:22:b7 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2d:2a:ac detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:29:e7:73 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:17:b3:2e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1f:aa:b8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:21:bc:17 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:7f:93 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1b:4b:23 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:18:f6:7b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0e:53:ea detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:21:0f:f3 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:21:7c:24 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1b:58:de detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1d:b1:cc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:15:87:2f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:01:00:d6:ba:f8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0c:81:19 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:30:4f:47 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:24:f6:04 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:24:eb:41 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:85:79 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:19:11:06 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:10:fd:51 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0e:8c:a3 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0e:30:ef detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2d:f8:f4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:01:84:2f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:31:f9:7e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:31:ff:44 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:08:77:ef detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:00:17:44 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1d:b2:ac detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0f:ef:7e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:21:ab:d9 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2f:b7:e1 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:03:ff:03:02:3d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2e:eb:ba detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:08:0c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:21:bc:61 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2e:b3:fd detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:30:70:a1 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:16:86:b7 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:24:eb:19 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1b:b9:6b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1d:94:11 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:13:04:49 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:13:78:f4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:16:53:4d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0e:3d:7a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1b:06:e1 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:31:fe:1e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:31:f7:92 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:32:7e:63 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:d3:22 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:20:0e:1e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1e:f7:73 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:11:36:bc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:fc:f6 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1e:a3:2a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:13:35:c1 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2e:b8:28 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:30:7c:f5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:12:5e:5c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2f:bb:e0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0a:77:ff detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:0e:e4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1e:d9:38 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0f:94:a6 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:01:8d:90 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:03:ff:03:33:57 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:15:66:1f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1b:48:35 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:08:ae:a7 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:ec:f1 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:15:11:82 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2b:32:ae detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:12:aa:46 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:19:53:2c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0e:ef:54 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:31:fb:85 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0d:dd:17 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0a:7a:40 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:05:d5:d5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1c:40:50 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:22:37:41 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:11:48:ae detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:ee:2f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:09:5b:fa detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:10:c7:ba detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:20:28:c2 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1d:b1:58 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:04:5d:17 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:13:39:82 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1f:41:18 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:32:84:dc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:50:41 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:12:99:46 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:29:86:ed detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2b:98:12 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:34:3b:68 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:4f:1a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2b:95:b6 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:19:b2:a9 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2a:cf:c9 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1c:2e:80 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:62:c2 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:05:0e:6f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:30:7c:b0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:15:fd:40 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0d:14:9b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:83:74 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:01:e2:29 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:30:1a:9a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:04:8b:1e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:81:ad detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1f:4a:db detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:25:62:55 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:27:58:26 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:31:ff:da detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:10:01:24 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:32:8e:8b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:24:ee:69 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:30:1b:0c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:88:18 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0e:cc:d4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2b:bd:21 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:16:43:0e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2a:99:ee detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:03:ff:01:ce:f4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:25:31:51 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:13:d3:6d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0f:99:a0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:58:a9 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:22:b6:7d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:30:20:ef detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:36:02:c5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:44:12 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3f:f8:37 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:27:a3 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:f0:5c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:a0:1c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:c9:ce detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0a:8f:93 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:03:ff:03:10:15 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:39:5d:50 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:22:3b:e7 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:24:e4:d3 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2f:bc:10 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:11:0b:93 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:03:93 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:03:ff:03:5b:f1 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:20:7d:f0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:08:c9:79 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:74:63 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:6e:8e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:8b:4a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:ad:5b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:9c:0b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:3f:a2 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:b9:64 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:5b:ec detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:9b:b9 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:7c:06 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:68:2d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3c:1f:bc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:39:04:4c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:e3:0d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:4b:c4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:f1:3d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:b2:76 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:4d:e4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:95:35 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:e3:21 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:b0:ba detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:ea:b8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:90:06 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:2a:5c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:33:9d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:ad:3c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:4e:78 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:38:71 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:30:f7 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3b:d8:eb detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:34:2b:8d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:6f:c8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:37:67:6d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:9b:8d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:97:b1 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:ea:f3 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:71:fe detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:39:3c:29 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:63:a4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:34:00:bb detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:4a:2a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:a3:60 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:39:a0:82 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3b:3a:79 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3b:3d:44 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:a3:77 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:ee:28 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:a0:56 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:f5:5b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:39:06:37 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:ca:e4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:36:29 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:4b:8d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:fe:88 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:37:04:14 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:4c:86 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2b:44:b5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:f1:d3 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:f6:be detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:71:e1 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:1c:f3 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:b9:0d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:94:a5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:80:28 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:a7:5b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:29:19 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:92:d9 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:2c:13 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:ae:d4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:8f:48 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:81:10 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:30:ce detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:fc:58 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:81:16 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:21:64:8b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:29:34 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1b:d2:0e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:a4:bc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:ca:e9 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:03:ff:04:a7:e1 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:05:7f:b1 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:05:9d:8c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:3f:5d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:38:46 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:15:23:64 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:21:3d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:32:41:41 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:13:4d:aa detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:01:50:d0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:24:f7:31 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:12:1e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:32:7f:ad detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3b:8b:c5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:32:7c:04 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:32:8c:57 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2e:b7:39 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:02:00:9b:c9:01 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:31:f5:7b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:09:4e:45 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:15:0a:64 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:32:76:7c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1b:aa:bc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:01:9f:51 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:08:a2:0c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0a:86:cb detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2b:ae:5d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2b:cd:6b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1b:0e:60 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:13:52 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:ba:63 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:d1:2d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:d1:1a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:e3:0e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:bd:15 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:d1:29 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:61:ce detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:42:33 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:be:10 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:36:00:69 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:e2:26 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:d1:bc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:37:03:7a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3f:6f:78 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:85:45 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:8f:89 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:d1:03 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:7c:23 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:2c:18 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:e3:01 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:7b:19 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:d0:f7 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:9d:da detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:75:5d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:f2:36 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:f2:85 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:e1:89 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:a6:06 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:9a:e9 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:fb:4a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:ea:5c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:d5:8f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:e9:ca detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:2b:55 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:3c:bc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:e9:6d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:89:47 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:93:c3 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:3d:f3 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:3c:4d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:d6:d8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:e9:17 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:75:be detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:37:04:59 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:d1:23 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:3f:62 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:ea:2e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:74:2d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:ec:b4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:6b:45 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:37:06:8b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:e9:17 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:86:7b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:e8:40 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:8f:30 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:ab:5a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:a5:e0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:46:a8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:6c:0e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:d6:d5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:bd:08 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:48:13 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:e9:de detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:81:4c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:ea:1e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:37:04:37 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:33:b6 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:33:f8:ea detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:11:1b:cb detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1e:3c:23 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:b5:8c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1e:55:ff detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1e:a1:0e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:32:79:47 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3f:67:62 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:dc:ba detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:89:59 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:39:3e:31 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:31:0d:93 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:19:2f:6a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:12:ea:c0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:22:38:19 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:36:05:84 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:00:d0:74 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:30:70:39 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:67:41 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1f:28:b0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:83:bd detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:39:02:00 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:d5:8c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:29:ba detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:29:ad detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:64:a4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:12:b7:5a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:52:e8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:18:4e:10 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:03:ff:03:57:6e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:24:fe:91 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:b9:d0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:84:20 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:d7:12 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:27:f3:79 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:25:74:d8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2d:2d:72 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3b:87:d4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:90:23 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:31:fa:9c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:d4:f0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:24:39:aa detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3b:f5:e0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:03:ff:03:63:49 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:31:f8:e2 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:05:a3:ae detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:23:56:59 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:11:89:72 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:04:d9:46 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:01:01:67:a4:fa detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:31:fa:8b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:06:42:50 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0b:60:79 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:04:d8:6e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:3c:db detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0a:61:17 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:01:84:f8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:f3:35 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:32:78:a4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:d9:fc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:12:f5:04 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3b:87:95 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:05:79:c4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:32:6b:d5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2e:cf:62 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:03:ff:04:a4:9a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0a:8d:cb detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:03:ff:02:fb:b2 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:09:27:53 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:50:6b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:18:ce detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:ba:08 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:39:9a:95 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:86:c3 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:fb:a8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:37:7c:10 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:6e:e5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:32:72:64 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:d1:0e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:c3:37 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:33:3b:71 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:25:38:01 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:92:75 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:39:1d:86 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:84:d5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:d5:38 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:5f:d7 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:5d:cd detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:2a:16 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:48:5f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:35:58 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1c:44:46 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:39:9c:c5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:19:d1:3a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3e:53:43 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:37:5e:73 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:21:e7:63 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:29:72 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:21:da:f8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3b:71:5b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:19:2e:0c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:29:ce:72 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0a:b1:e0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:39:42:ce detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:9f:cb detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1c:53:de detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2e:d8:c7 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0d:9d:2f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:25:14:37 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:19:f5:22 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:30:66:bd detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:32:79:e9 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2f:b6:a9 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:00:09:87 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:31:f8:79 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:03:00:4e:bc:be detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:03:ff:02:e7:d2 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:31:a9 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:fa:fc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:39:b2:ae detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:8f:66 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:b6:1b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:ef:46 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:fe:0d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:e9:46 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:ea:10 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:ea:0e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:73:76 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:34:00:63 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:69:70 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:ba:a0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:20:f4:33 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:fb:94 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:44:89:3d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:d1:78 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:39:8c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:85:5e detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:fe:96 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:67:6c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:01:a0:0d detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:11:6a:e5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1c:3b:fc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3b:c5:ed detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:98:b5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:44:65:6b detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:19:4a:e9 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:37:ce:a4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0f:2e:4c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:48:99:60 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:38:61:b6 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:41:b1:3f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:21:6e:29 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:a0:cc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1a:b6:d5 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:18:4e:a8 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3a:16:80 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0a:a4:a7 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:47:cb:47 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:37:d4:3a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:13:07:3a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:24:6c:cc detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:47:c7:c4 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:0a:89:8a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:16:39:71 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:4b:00:e6 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:32:6b:e0 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:40:90:26 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:3c:1e:80 detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:29:a7:2a detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:2d:ca:8f detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:31:ff:4c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:14:92:6c detected a high temperature condition. (C1219 Table 3)'
#  'Cleared: Meter 00:13:50:05:ff:1d:72:84 detected a high temperature condition. (C1219 Table 3)']

# %%
curated_reasons = []
for reason_i in df_3_35_0_28['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.35.0.28']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Cleared: detected a high temperature condition. (C1219 Table 3)

# %% [markdown]
# # '3.35.0.40'

# %%
df_3_35_0_40_1 = pd.read_pickle(ids_with_paths_dict['3.35.0.40'])
df_3_35_0_40_2 = pd.read_pickle(r'C:\Users\s346557\Documents\LocalData\dovs_and_end_events_data\regex_TX\sample_dfs\df_3_35_0_40.pkl')
df_3_35_0_40 = pd.concat([df_3_35_0_40_1, df_3_35_0_40_2])
#-----
print(f"shape[0] = {df_3_35_0_40.shape[0]}")
print(f"# Unique reasons = {df_3_35_0_40['reason'].nunique()}")
print(df_3_35_0_40['reason'].unique())
# Out:
# shape[0] = 3723
# # Unique reasons = 1694
# ['Meter 00:13:50:05:ff:11:62:2a detected a high temperature condition. (C1219 Table 3)'
#  'Meter 00:13:50:05:ff:1d:d8:4b detected a high temperature condition. (C1219 Table 3)'
#  'Meter 00:13:50:05:ff:11:69:bb detected a high temperature condition. (C1219 Table 3)'
#  ...
#  'Meter event S4TemperatureThreshold  Time event occurred on meter = 06/09/2023 18:13:50  Sequence number = 69  User id = 0  Event argument = 00-00-00-00-00-00 '
#  'Meter event S4TemperatureThreshold  Time event occurred on meter = 06/09/2023 18:22:50  Sequence number = 647  User id = 0  Event argument = 00-00-00-00-00-00 '
#  'Meter event S4TemperatureThreshold  Time event occurred on meter = 06/09/2023 18:22:50  Sequence number = 283  User id = 0  Event argument = 00-00-00-00-00-00 ']

# %%
curated_reasons = []
for reason_i in df_3_35_0_40['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.35.0.40']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter's temperature threshold exceeded
# Meter event S4TemperatureThreshold
# Meter detected a high temperature condition (C1219 Table 3)
# Meter event AX Temp Threshold Exceeded

# %% [markdown]
# # '3.36.0.79'

# %%
df_3_36_0_79 = pd.read_pickle(ids_with_paths_dict['3.36.0.79'])
#-----
print(f"shape[0] = {df_3_36_0_79.shape[0]}")
print(f"# Unique reasons = {df_3_36_0_79['reason'].nunique()}")
print(df_3_36_0_79['reason'].unique())
# Out:
# shape[0] = 18573
# # Unique reasons = 11
# ['Meter detected a clock error.'
#  'Meter event Clock Error Detected  Time event occurred on meter = 04/18/2020 10:00:10  Sequence number = 332  User id = 0  Event argument = 00-00'
#  'Meter event Clock Error Detected  Time event occurred on meter = 05/11/2020 21:48:35  Sequence number = 35792  User id = 0  Event argument = 00-00'
#  'Meter event Clock Error Detected  Time event occurred on meter = 07/24/2021 01:57:34  Sequence number = 39646  User id = 0  Event argument = 00-00 '
#  'Meter event Clock Error Detected  Time event occurred on meter = 07/24/2021 01:57:44  Sequence number = 39650  User id = 0  Event argument = 00-00 '
#  'Meter event Clock Error Detected  Time event occurred on meter = 07/24/2021 01:57:53  Sequence number = 39654  User id = 0  Event argument = 00-00 '
#  'Meter event Clock Error Detected  Time event occurred on meter = 07/24/2021 01:57:29  Sequence number = 39644  User id = 0  Event argument = 00-00 '
#  'Meter event Clock Error Detected  Time event occurred on meter = 07/24/2021 01:57:48  Sequence number = 39652  User id = 0  Event argument = 00-00 '
#  'Meter event Clock Error Detected  Time event occurred on meter = 07/24/2021 01:57:39  Sequence number = 39648  User id = 0  Event argument = 00-00 '
#  'Meter event Clock Error Detected  Time event occurred on meter = 07/24/2021 01:57:57  Sequence number = 39656  User id = 0  Event argument = 00-00 '
#  'Meter event Clock Error Detected  Time event occurred on meter = 12/16/2022 10:37:33  Sequence number = 6  User id = 0  Event argument = 00-00-00-00-00-03 ']

# %%
curated_reasons = []
for reason_i in df_3_36_0_79['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.36.0.79']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter event Clock Error Detected

# %% [markdown]
# # '3.36.1.29'

# %%
df_3_36_1_29 = pd.read_pickle(ids_with_paths_dict['3.36.1.29'])
#-----
print(f"shape[0] = {df_3_36_1_29.shape[0]}")
print(f"# Unique reasons = {df_3_36_1_29['reason'].nunique()}")
print(df_3_36_1_29['reason'].unique())
# Out:
# shape[0] = 94
# # Unique reasons = 1
# ['Meter detected a clock error.']

# %%
curated_reasons = []
for reason_i in df_3_36_1_29['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.36.1.29']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter detected a clock error

# %% [markdown]
# # '3.36.114.73'

# %%
df_3_36_114_73 = pd.read_pickle(ids_with_paths_dict['3.36.114.73'])
#-----
print(f"shape[0] = {df_3_36_114_73.shape[0]}")
print(f"# Unique reasons = {df_3_36_114_73['reason'].nunique()}")
print(df_3_36_114_73['reason'].unique())
# Out:
# shape[0] = 270000
# # Unique reasons = 205447
# ['Meter 00:13:50:05:ff:2d:e1:c6, detected loss of time (C1219 Table 3)'
#  'Meter 00:13:50:05:ff:1c:9b:0a, detected loss of time (C1219 Table 3)'
#  'Meter 00:13:50:05:ff:21:3f:ae, detected loss of time (C1219 Table 3)'
#  ...
#  'Meter 00:13:50:05:ff:49:fe:25, detected loss of time (C1219 Table 3)'
#  'Meter 00:13:50:05:ff:41:5b:20, detected loss of time (C1219 Table 3)'
#  'Meter 00:13:50:05:ff:40:7c:81, detected loss of time (C1219 Table 3)']

# %%
curated_reasons = []
for reason_i in df_3_36_114_73['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.36.114.73']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Meter detected loss of time (C1219 Table 3)

# %% [markdown]
# # '3.36.114.159'

# %%
df_3_36_114_159 = pd.read_pickle(ids_with_paths_dict['3.36.114.159'])
#-----
print(f"shape[0] = {df_3_36_114_159.shape[0]}")
print(f"# Unique reasons = {df_3_36_114_159['reason'].nunique()}")
print(df_3_36_114_159['reason'].unique())
# Out:
# shape[0] = 270000
# # Unique reasons = 185143
# ['Ignoring Interval Read data for device 00:13:50:05:ff:0c:80:da as it has time in the future 2021-01-18 03:15:00.0'
#  'Ignoring Interval Read data for device 00:13:50:05:ff:0c:80:da as it has time in the future 2021-01-18 06:00:00.0'
#  'Ignoring Interval Read data for device 00:13:50:05:ff:0c:80:da as it has time in the future 2021-01-18 15:45:00.0'
#  ...
#  'Ignoring Interval Read data for device 00:13:50:01:01:3d:7a:5d as it has time in the future 2066-01-22 11:34:00.0'
#  'Ignoring Interval Read data for device 00:13:50:01:01:6b:56:43 as it has time in the future 2074-01-22 09:51:00.0'
#  'Ignoring Interval Read data for device 00:13:50:01:01:03:4b:69 as it has time in the future 2063-01-23 08:02:00.0']

# %%
curated_reasons = []
for reason_i in df_3_36_114_159['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.36.114.159']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Ignoring Register Read data for device as it has time in the future
# Ignoring Interval Read data for device as it has time in the future

# %% [markdown]
# # '3.36.136.73'

# %%
df_3_36_136_73 = pd.read_pickle(ids_with_paths_dict['3.36.136.73'])
#-----
print(f"shape[0] = {df_3_36_136_73.shape[0]}")
print(f"# Unique reasons = {df_3_36_136_73['reason'].nunique()}")
print(df_3_36_136_73['reason'].unique())
# Out:
# shape[0] = 270000
# # Unique reasons = 266216
# ['Meter 00:13:50:05:ff:24:1b:21 needs explicit time sync. Drift: 1759020 s, Encountered Problems:  TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_DAY_BX [0x4C], Meter_Time: 14:54:04'
#  'Meter 00:13:50:05:ff:2c:ed:eb needs explicit time sync. Drift: -3595 s, Encountered Problems:  TS_ERR_NEAR_LP_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT [0x46], Meter_Time: 04:45:14'
#  'Meter 00:13:50:05:ff:23:aa:d8 needs explicit time sync. Drift: -3607 s, Encountered Problems:  TS_ERR_LP_BX, TS_ERR_BIG_DRIFT [0x44], Meter_Time: 01:21:54'
#  ...
#  'Meter 00:13:50:05:ff:45:92:ce needs explicit time sync. Drift: 3601 s, Encountered Problems:  TS_ERR_NEAR_LP_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT [0x46], Meter_Time: 01:28:20'
#  'Meter 00:13:50:05:ff:45:8e:24 needs explicit time sync. Drift: 3601 s, Encountered Problems:  TS_ERR_LP_BX, TS_ERR_BIG_DRIFT [0x44], Meter_Time: 01:46:48'
#  'Meter 00:13:50:05:ff:45:16:91 needs explicit time sync. Drift: 3603 s, Encountered Problems:  TS_ERR_NEAR_LP_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT [0x46], Meter_Time: 03:29:51']

# %%
curated_reasons = []
for reason_i in df_3_36_136_73['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.36.136.73']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*sorted(curated_reasons), sep='\n')
# Out:
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_LP_BX, TS_ERR_BIG_DRIFT [0x44]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_DAY_BX [0x4C]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_DAY_BX, TS_ERR_DST_BX [0x6C]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_DAY_BX, TS_ERR_NEAR_DST_BND [0x5C]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_DST_BX [0x64]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_NEAR_DST_BND [0x54]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_NEAR_DAY_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT [0x45]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_NEAR_DAY_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_DAY_BX [0x4D]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_NEAR_DAY_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_DAY_BX, TS_ERR_DST_BX [0x6D]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_NEAR_DAY_BND, TS_ERR_NEAR_LP_BND, TS_ERR_BIG_DRIFT [0x43]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_NEAR_DAY_BND, TS_ERR_NEAR_LP_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT [0x47]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_NEAR_DAY_BND, TS_ERR_NEAR_LP_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_DAY_BX [0x4F]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_NEAR_DAY_BND, TS_ERR_NEAR_LP_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_DAY_BX, TS_ERR_DST_BX [0x6F]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_NEAR_LP_BND, TS_ERR_BIG_DRIFT [0x42]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_NEAR_LP_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT [0x46]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_NEAR_LP_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_DAY_BX [0x4E]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_NEAR_LP_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_DAY_BX, TS_ERR_DST_BX [0x6E]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_NEAR_LP_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_DAY_BX, TS_ERR_NEAR_DST_BND [0x5E]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_NEAR_LP_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_DST_BX [0x66]
# Meter needs explicit time sync. Encountered Problems:  TS_ERR_NEAR_LP_BND, TS_ERR_LP_BX, TS_ERR_BIG_DRIFT, TS_ERR_NEAR_DST_BND [0x56]

# %% [markdown]
# # '3.36.136.79'

# %%
df_3_36_136_79 = pd.read_pickle(ids_with_paths_dict['3.36.136.79'])
#-----
print(f"shape[0] = {df_3_36_136_79.shape[0]}")
print(f"# Unique reasons = {df_3_36_136_79['reason'].nunique()}")
print(df_3_36_136_79['reason'].unique())
# Out:
# shape[0] = 270000
# # Unique reasons = 12052
# ['Error occurred when attempting to synch meter time with NIC time for device 00:13:50:05:ff:29:e1:20'
#  'Error occurred when attempting to synch meter time with NIC time for device 00:13:50:03:ff:04:74:f2'
#  'Error occurred when attempting to synch meter time with NIC time for device 00:13:50:05:ff:04:60:b6'
#  ...
#  'Error occurred when attempting to synch meter time with NIC time for device 00:13:50:05:ff:3a:67:11'
#  'Error occurred when attempting to synch meter time with NIC time for device 00:13:50:05:ff:3b:72:77'
#  'Error occurred when attempting to synch meter time with NIC time for device 00:13:50:05:ff:44:a8:e1']

# %%
curated_reasons = []
for reason_i in df_3_36_136_79['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.36.136.79']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# Error occurred when attempting to synch meter time with NIC time for device

# %% [markdown]
# # '3.38.1.139'

# %%
df_3_38_1_139 = pd.read_pickle(ids_with_paths_dict['3.38.1.139'])
#-----
print(f"shape[0] = {df_3_38_1_139.shape[0]}")
print(f"# Unique reasons = {df_3_38_1_139['reason'].nunique()}")
print(df_3_38_1_139['reason'].unique())
# Out:
# shape[0] = 136
# # Unique reasons = 9
# ['KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase C Current '
#  'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase C Voltage '
#  'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase A Current '
#  'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase B Current '
#  'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase B Voltage, Phase C Voltage '
#  'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase B Voltage '
#  'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase A Current, Phase C Current '
#  'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase B Current, Phase C Current, Phase B Voltage, Phase C Voltage '
#  'KV2c meter event Polarity, Cross Phase, Reverse Energy Flow Diagnostic flags:Phase B Current, Phase B Voltage, Phase C Voltage ']

# %%
curated_reasons = []
for reason_i in df_3_38_1_139['reason'].unique().tolist():
    curated_reason_i = AMIEndEvents.reduce_end_event_reason(
        reason=reason_i, 
        patterns=std_patterns_to_replace['3.38.1.139']
    )
    curated_reasons.append(curated_reason_i)
curated_reasons = list(set(curated_reasons))
print(*curated_reasons, sep='\n')
# Out:
# KV2c meter event Polarity, Cross Phase, Reverse Energy Flow
